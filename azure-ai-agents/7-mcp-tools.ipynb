# %% [markdown]
# # 🔌 Agents with Foundry MCP Server
#
# Welcome to our **Foundry MCP Server** tutorial! In this notebook, we'll demonstrate how to:
#
# 1. **Understand** the Foundry MCP Server and its capabilities
# 2. **Configure** an MCP tool connection in Microsoft Foundry
# 3. **Create an Agent** with MCP tools to access Foundry capabilities
# 4. **Handle MCP approval requests** for secure tool access
#
# ### 🔌 What is Foundry MCP Server?
# > [Foundry MCP Server](https://learn.microsoft.com/azure/ai-foundry/mcp/get-started) is a **cloud-hosted MCP service** at `https://mcp.ai.azure.com` that provides:
# > - **Model Discovery**: Explore and compare models from the Foundry catalog
# > - **Model Deployment**: Check quotas and deploy models
# > - **Agent Management**: Create and manage AI agents
# > - **Evaluation**: Run evaluations and quality assessments
# > - **Knowledge Integration**: Work with Azure AI Search indexes
#
# ### 🌟 Why Foundry MCP Server?
# | Feature | Benefit |
# |---------|---------|
# | **Cloud-hosted** | No local server setup required |
# | **Entra ID Authentication** | Secure OAuth 2.0 with user-specific permissions |
# | **Curated Tools** | Pre-built tools for common Foundry operations |
# | **Scalable** | Built with cloud-scale reliability |
#
# ## Prerequisites
# - Microsoft Foundry project with appropriate permissions
# - **Foundry MCP Server connection** configured in your project (see setup below)
# - A `.env` file in the parent directory containing:
#   ```bash
#   AI_FOUNDRY_PROJECT_ENDPOINT=<your-ai-foundry-project-endpoint>
#   AZURE_AI_MODEL_DEPLOYMENT_NAME=<supported-model>
#   TENANT_ID=<your-azure-tenant-id>
#   FOUNDRY_MCP_CONNECTION_ID=<connection-id-from-foundry-portal>  # See setup below
#   ```
#
# ## ⚙️ Setting up Foundry MCP Server Connection
#
# **Important**: Before using MCP tools in code, you must create a connection in the Foundry portal:
#
# ### Step 1: Navigate to Foundry Tools
# 1. Go to [Microsoft Foundry portal](https://ai.azure.com)
# 2. Select your project
# 3. Navigate to **Build** → **Tools**
#
# ### Step 2: Add Foundry MCP Server
# 1. Click **Add tool** → **Catalog**
# 2. Search for "Foundry MCP Server (preview)"
# 3. Select it and click **Create**
# 4. The connection will be created with OAuth authentication
#
# ### Step 3: Get Connection ID
# 1. After creating the connection, click on it to view details
# 2. Copy the **Project connection ID** from the details page
# 3. Add it to your `.env` file as `FOUNDRY_MCP_CONNECTION_ID`
#
# <img src="seq-diagrams/foundry-mcp-connection-id.png" width="80%"/>
#
# > **Note**: The Project connection ID follows this format:
# > `/subscriptions/{subscription-id}/resourceGroups/{rg}/providers/Microsoft.CognitiveServices/accounts/{account}/projects/{project}/connections/FoundryMCPServerpreview`
#
# ## Architecture Overview
# ```
# ┌─────────────────┐     ┌──────────────────┐     ┌─────────────────────────┐
# │   User Query    │────▶│   Agent + MCP    │────▶│  Foundry MCP Server     │
# │                 │     │     Tool         │     │  (mcp.ai.azure.com)     │
# └─────────────────┘     └──────────────────┘     └─────────────────────────┘
#                               │                           │
#                               ▼                           ▼
#                     ┌──────────────────┐       ┌─────────────────────────┐
#                     │  Connection ID   │       │  - Model Catalog        │
#                     │  (from portal)   │       │  - Deployments          │
#                     └──────────────────┘       │  - Evaluations          │
#                                                │  - Agent Service        │
#                                                └─────────────────────────┘
# ```
#
# ## Available Tool Categories
#
# | Category | Tools | Description |
# |----------|-------|-------------|
# | **Models** | `model_catalog_list`, `model_deploy` | Explore and deploy models |
# | **Evaluation** | `evaluation_create`, `evaluation_get` | Run and review evaluations |
# | **Agents** | `agent_update`, `agent_list` | Manage AI agents |
# | **Knowledge** | `index_list`, `query_index` | Work with AI Search |
#
# 📚 **Learn More**: [Foundry MCP Server Documentation](https://learn.microsoft.com/azure/ai-foundry/mcp/get-started)

# %% [markdown]
# ## 🔐 Authentication Setup
#
# Before running the next cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login --use-device-code
# ```
#
# This will provide you with a device code and URL to authenticate in your browser, which is useful for:
# - Remote development environments
# - Systems without a default browser
# - Corporate environments with strict security policies
#
# After successful authentication, you can proceed with the notebook cells below.

# %% [markdown]
# ## 1. Initial Setup
# We'll load environment variables from `.env` and initialize our **AIProjectClient** to manage agents with MCP tools.

# %%
import os
from pathlib import Path

from dotenv import load_dotenv
from azure.identity import AzureCliCredential
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import (
    PromptAgentDefinition,
    MCPTool,
)
from openai.types.responses.response_input_param import (
    McpApprovalResponse,
    ResponseInputParam,
)

# Load environment variables from parent .env
notebook_path = Path().absolute()
parent_dir = notebook_path.parent
load_dotenv(parent_dir.parent / '.env')

# Get configuration
tenant_id = os.environ.get("TENANT_ID")
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")
model_deployment = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o")

# Foundry MCP Server connection ID (configured in Foundry portal)
foundry_mcp_connection_id = os.environ.get("FOUNDRY_MCP_CONNECTION_ID")

print("🔌 Foundry MCP Server Notebook")
print("=" * 60)
print(f"🔑 Tenant ID: {tenant_id}")
print(f"📍 Project Endpoint: {project_endpoint}")
print(f"🤖 Model Deployment: {model_deployment}")
print("")
print("🔌 Foundry MCP Server: https://mcp.ai.azure.com")
print(f"✅ Connection ID: {foundry_mcp_connection_id}")
# Out:
# 🔌 Foundry MCP Server Notebook
# ============================================================
# 🔑 Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3
# 📍 Project Endpoint: https://demopocaifoundry.services.ai.azure.com/api/projects/demoproject
# 🤖 Model Deployment: gpt-4o
#
# 🔌 Foundry MCP Server: https://mcp.ai.azure.com
# ✅ Connection ID: /subscriptions/93c5449c-bbb2-4249-9461-ddf749e03430/resourceGroups/demoaifoundry/providers/Microsoft.CognitiveServices/accounts/demopocaifoundry/projects/demoproject/connections/FoundryMCPServerpreview

# %% [markdown]
# ## 2. Initialize the AI Project Client
# Create the AIProjectClient with Azure CLI-based authentication.

# %%
# Initialize AIProjectClient with Azure CLI authentication
print("🔐 Using Azure CLI authentication...")
print("   Make sure you've run 'az login' in your terminal first!")
print("")

credential = AzureCliCredential(tenant_id=tenant_id)

# Create the project client
project_client = AIProjectClient(
    endpoint=project_endpoint,
    credential=credential
)

# Get the OpenAI client for conversations
openai_client = project_client.get_openai_client()

print("✅ AIProjectClient initialized with AzureCliCredential")
print("✅ OpenAI client ready for conversations")
# Out:
# 🔐 Using Azure CLI authentication...
#    Make sure you've run 'az login' in your terminal first!
#
# ✅ AIProjectClient initialized with AzureCliCredential
# ✅ OpenAI client ready for conversations

# %% [markdown]
# ## 3. Define the Foundry MCP Tool
#
# The **Foundry MCP Server** is hosted at `https://mcp.ai.azure.com` and provides a curated set of tools for interacting with Microsoft Foundry services.
#
# ### Key Parameters:
# - **server_label**: Identifies the MCP server (e.g., `"foundry-mcp"`)
# - **server_url**: `https://mcp.ai.azure.com/sse` - the cloud-hosted Foundry MCP SSE endpoint
# - **require_approval**: Controls approval flow (`"always"`, `"never"`) - use `"never"` for simpler workflows
# - **project_connection_id**: **Required** - Connection configured in Foundry portal
#
# ### 🔐 Authentication Flow:
# 1. You configure the MCP connection in Microsoft Foundry portal
# 2. The portal stores authentication (OAuth/Entra ID)
# 3. Your code references the connection via `project_connection_id`
# 4. The agent uses the stored credentials for secure access
#
# ### Foundry MCP Server Tools:
#
# | Tool | Description |
# |------|-------------|
# | `model_catalog_list` | List models from Microsoft Foundry catalog |
# | `model_deploy` | Deploy a model to Azure AI Services |
# | `model_quota_list` | Check quota availability |
# | `evaluation_create` | Create an evaluation run |
# | `agent_update` | Create or update an agent |
# | `index_list` | List Azure AI Search indexes |

# %%
# Define Foundry MCP Server tool configuration
print("🔌 Configuring Foundry MCP Server tool...")
print("")

# Configure MCP tool with the portal connection
# The server_url should match the "Remote MCP server endpoint" from your connection
mcp_tool = MCPTool(
    server_label="foundry-mcp",
    server_url="https://mcp.ai.azure.com/sse",  # SSE endpoint for MCP protocol
    require_approval="never",  # Skip approval flow for simpler demo
    project_connection_id=foundry_mcp_connection_id,  # Connection for auth
)

print(f"✅ Foundry MCP Tool configured:")
print(f"   Server Label: {mcp_tool.server_label}")
print(f"   Server URL: {mcp_tool.server_url}")
print(f"   Require Approval: {mcp_tool.require_approval}")
print(f"   Connection ID: {mcp_tool.project_connection_id}")
# Out:
# 🔌 Configuring Foundry MCP Server tool...
#
# ✅ Foundry MCP Tool configured:
#    Server Label: foundry-mcp
#    Server URL: https://mcp.ai.azure.com/sse
#    Require Approval: never
#    Connection ID: /subscriptions/93c5449c-bbb2-4249-9461-ddf749e03430/resourceGroups/demoaifoundry/providers/Microsoft.CognitiveServices/accounts/demopocaifoundry/projects/demoproject/connections/FoundryMCPServerpreview

# %% [markdown]
# ## 4. Create an Agent with MCP Tools
#
# Now we'll create an agent that can use MCP tools to access Foundry capabilities.

# %%
# Define agent instructions for using Foundry MCP Server
agent_name = "foundry-mcp-assistant"

agent_instructions = """
You are an AI Development Assistant with access to Microsoft Foundry capabilities via MCP tools.

Your capabilities include:
1. 📊 Exploring AI models from the Foundry catalog
2. 🚀 Helping with model deployment and quota management
3. 📈 Running evaluations on AI applications
4. 🤖 Managing AI agents in the Foundry ecosystem
5. 🔍 Working with Azure AI Search indexes

When helping users:
- Recommend appropriate models for their use cases (e.g., GPT-4o for complex reasoning, Phi-4 for edge deployments)
- Explain model capabilities, benchmarks, and licensing
- Guide through deployment processes
- Help set up evaluations for quality and safety
- Assist with knowledge base integrations

⚠️ IMPORTANT NOTES:
- Model deployments may require appropriate quota allocations
- Evaluations consume compute resources
- Always verify permissions before making changes
"""

print(f"📝 Agent Name: {agent_name}")
print(f"📋 Instructions length: {len(agent_instructions)} characters")
# Out:
# 📝 Agent Name: foundry-mcp-assistant
# 📋 Instructions length: 861 characters

# %%
# Create the agent with MCP tool
print(f"Creating Foundry MCP Assistant Agent...")

# Create agent with Foundry MCP Server tool
agent_definition = PromptAgentDefinition(
    model=model_deployment,
    instructions=agent_instructions,
    tools=[mcp_tool],
)

# Create the agent version
agent = project_client.agents.create_version(
    agent_name=agent_name,
    definition=agent_definition,
)

print(f"✅ Agent created: {agent.name} (Version: {agent.version})")
print("🔌 Agent configured with Foundry MCP Server tool")
print("")
print("🎯 This agent can now access Foundry MCP Server capabilities:")
print("   • Model exploration and recommendations")
print("   • Deployment management")
print("   • Evaluation orchestration")
print("   • Agent management")
# Out:
# Creating Foundry MCP Assistant Agent...
# AzureCliCredential.get_token_info failed: Failed to invoke the Azure CLI
# ---------------------------------------------------------------------------
# TimeoutExpired                            Traceback (most recent call last)
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\identity\_credentials\azure_cli.py:281, in _run_command(command_args, timeout)
#     280     _LOGGER.debug("Executing subprocess with the following arguments %s", args)
# --> 281     return subprocess.check_output(args, **kwargs)
#     282 except subprocess.CalledProcessError as ex:
#     283     # non-zero return from shell
#     284     # Fallback check in case the executable is not found while executing subprocess.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:472, in check_output(timeout, *popenargs, **kwargs)
#     470     kwargs['input'] = empty
# --> 472 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     473            **kwargs).stdout
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     555 try:
# --> 556     stdout, stderr = process.communicate(input, timeout=timeout)
#     557 except TimeoutExpired as exc:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1222, in Popen.communicate(self, input, timeout)
#    1221 try:
# -> 1222     stdout, stderr = self._communicate(input, endtime, timeout)
#    1223 except KeyboardInterrupt:
#    1224     # https://bugs.python.org/issue25942
#    1225     # See the detailed comment in .wait().
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1665, in Popen._communicate(self, input, endtime, orig_timeout)
#    1664     if self.stdout_thread.is_alive():
# -> 1665         raise TimeoutExpired(self.args, orig_timeout)
#    1666 if self.stderr is not None:
#
# TimeoutExpired: Command '['C:\\Program Files\\Microsoft SDKs\\Azure\\CLI2\\wbin\\az.cmd', 'account', 'get-access-token', '--output', 'json', '--resource', 'https://ai.azure.com', '--tenant', '16b3c013-d300-468d-ac64-7eda0820b6d3']' timed out after 10 seconds
#
# The above exception was the direct cause of the following exception:
#
# CredentialUnavailableError                Traceback (most recent call last)
# Cell In[10], line 12
#       5 agent_definition = PromptAgentDefinition(
#       6     model=model_deployment,
#       7     instructions=agent_instructions,
#       8     tools=[mcp_tool],
#       9 )
#      11 # Create the agent version
# ---> 12 agent = project_client.agents.create_version(
#      13     agent_name=agent_name,
#      14     definition=agent_definition,
#      15 )
#      17 print(f"✅ Agent created: {agent.name} (Version: {agent.version})")
#      18 print("🔌 Agent configured with Foundry MCP Server tool")
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\tracing\decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\ai\projects\operations\_operations.py:2818, in AgentsOperations.create_version(self, agent_name, body, definition, metadata, description, **kwargs)
#    2816 _decompress = kwargs.pop("decompress", True)
#    2817 _stream = kwargs.pop("stream", False)
# -> 2818 pipeline_response: PipelineResponse = self._client._pipeline.run(  # pylint: disable=protected-access
#    2819     _request, stream=_stream, **kwargs
#    2820 )
#    2822 response = pipeline_response.http_response
#    2824 if response.status_code not in [200]:
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\_base.py:242, in Pipeline.run(self, request, **kwargs)
#     240 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     241 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 242 return first_node.send(pipeline_request)
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 98 (2 times)]
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\policies\_redirect.py:205, in RedirectPolicy.send(self, request)
#     203 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     204 while retryable:
# --> 205     response = self.next.send(request)
#     206     redirect_location = self.get_redirect_location(response)
#     207     if redirect_location and redirect_settings["allow"]:
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py:545, in RetryPolicy.send(self, request)
#     543 self._configure_timeout(request, absolute_timeout, is_response_error)
#     544 request.context["retry_count"] = len(retry_settings["history"])
# --> 545 response = self.next.send(request)
#     546 if self.is_retry(retry_settings, response):
#     547     retry_active = self.increment(retry_settings, response=response)
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:159, in BearerTokenCredentialPolicy.send(self, request)
#     151 def send(self, request: PipelineRequest[HTTPRequestType]) -> PipelineResponse[HTTPRequestType, HTTPResponseType]:
#     152     """Authorize request with a bearer token and send it to the next policy
#     153
#     154     :param request: The pipeline request object
#    (...)    157     :rtype: ~azure.core.pipeline.PipelineResponse
#     158     """
# --> 159     self.on_request(request)
#     160     try:
#     161         response = self.next.send(request)
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:134, in BearerTokenCredentialPolicy.on_request(self, request)
#     131 self._enforce_https(request)
#     133 if self._token is None or self._need_new_token:
# --> 134     self._request_token(*self._scopes)
#     135 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     136 self._update_headers(request.http_request.headers, bearer_token)
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:110, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     103 def _request_token(self, *scopes: str, **kwargs: Any) -> None:
#     104     """Request a new token from the credential.
#     105
#     106     This will call the credential's appropriate method to get a token and store it in the policy.
#     107
#     108     :param str scopes: The type of access needed.
#     109     """
# --> 110     self._token = self._get_token(*scopes, **kwargs)
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:100, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#      97         if key in TokenRequestOptions.__annotations__:  # pylint: disable=no-member
#      98             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# --> 100     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#     101 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\identity\_internal\decorators.py:23, in log_get_token.<locals>.wrapper(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def wrapper(*args, **kwargs):
#      22     try:
# ---> 23         token = fn(*args, **kwargs)
#      24         _LOGGER.log(
#      25             logging.DEBUG if within_credential_chain.get() else logging.INFO,
#      26             "%s succeeded",
#      27             fn.__qualname__,
#      28         )
#      29         if _LOGGER.isEnabledFor(logging.DEBUG):
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\identity\_credentials\azure_cli.py:153, in AzureCliCredential.get_token_info(self, options, *scopes)
#     132 @log_get_token
#     133 def get_token_info(self, *scopes: str, options: Optional[TokenRequestOptions] = None) -> AccessTokenInfo:
#     134     """Request an access token for `scopes`.
#     135
#     136     This is an alternative to `get_token` to enable certain scenarios that require additional properties
#    (...)    151       receive an access token.
#     152     """
# --> 153     return self._get_token_base(*scopes, options=options)
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\identity\_credentials\azure_cli.py:191, in AzureCliCredential._get_token_base(self, options, *scopes, **kwargs)
#     189 if self.subscription:
#     190     command_args += ["--subscription", self.subscription]
# --> 191 output = _run_command(command_args, self._process_timeout)
#     193 token = parse_token(output)
#     194 if not token:
#
# File c:\src\agentic-ai-immersion\.venv\Lib\site-packages\azure\identity\_credentials\azure_cli.py:307, in _run_command(command_args, timeout)
#     304 except Exception as ex:
#     305     # could be a timeout, for example
#     306     error = CredentialUnavailableError(message="Failed to invoke the Azure CLI")
# --> 307     raise error from ex
#
# CredentialUnavailableError: Failed to invoke the Azure CLI

# %% [markdown]
# ## 5. Create a Conversation
#
# Create a conversation thread to maintain context across interactions.

# %%
# Create a conversation for the chat session
print("Creating conversation for the chat session...")

conversation = openai_client.conversations.create()

print(f"✅ Conversation created: {conversation.id}")
# Out:
# Creating conversation for the chat session...
# ✅ Conversation created: conv_0d186185c79cf72c006q5g0MZ7OOb9cM3X4Ed2ez71ql6oWfbi

# %% [markdown]
# ## 6. Query the Agent with Foundry MCP Tools
#
# When the agent uses Foundry MCP tools, you may receive **approval requests**. This is a security feature of the Foundry MCP Server that ensures users approve operations before they execute.
#
# ### MCP Approval Flow:
# 1. Send a query to the agent (e.g., "What models are available?")
# 2. Agent calls Foundry MCP Server tool (e.g., `model_catalog_list`)
# 3. Server returns an `mcp_approval_request`
# 4. Client sends back an `mcp_approval_response` (approve/deny)
# 5. Agent receives data and responds to user
#
# ### Example Prompts for Foundry MCP Server:
# - "What OpenAI models are available in Microsoft Foundry?"
# - "Compare Phi models and explain their differences"
# - "What models are good for reasoning tasks?"
# - "Help me understand model quotas for my subscription"

# %%
def process_mcp_response(openai_client, agent, initial_response, auto_approve=True):
    """
    Process a response that may contain MCP approval requests.
    
    Args:
        openai_client: The OpenAI client instance
        agent: The agent being used
        initial_response: The initial response from the agent
        auto_approve: Whether to automatically approve MCP requests
    
    Returns:
        The final response after processing any approvals
    """
    response = initial_response
    
    # Check for MCP approval requests
    approval_requests = []
    for item in response.output:
        if item.type == "mcp_approval_request":
            print(f"\n🔐 MCP Approval Request Received:")
            print(f"   Server: {item.server_label}")
            print(f"   Request ID: {item.id}")
            
            if auto_approve and item.id:
                print(f"   ✅ Auto-approving request...")
                approval_requests.append(
                    McpApprovalResponse(
                        type="mcp_approval_response",
                        approve=True,
                        approval_request_id=item.id,
                    )
                )
            else:
                print(f"   ❌ Request denied or missing ID")
    
    # If we have approvals to send, send them
    if approval_requests:
        print(f"\n📤 Sending {len(approval_requests)} approval response(s)...")
        
        response = openai_client.responses.create(
            input=approval_requests,
            previous_response_id=response.id,
            extra_body={"agent_reference": {"name": agent.name, "type": "agent_reference"}},
        )
        
        print("✅ Approval response sent")
    
    return response

print("✅ MCP response processing function defined")
# Out:
# ✅ MCP response processing function defined

# %%
# Sample queries that leverage Foundry MCP Server capabilities
queries = [
    "What AI models would you recommend for document analysis use cases?",
    "Explain how the Foundry MCP Server helps with AI development workflows.",
    "What security features does the Foundry MCP Server provide for enterprise use?",
]

print("💬 Foundry MCP Server Assistant Session")
print("=" * 60)

for i, query in enumerate(queries, 1):
    print(f"\n📝 Query {i}: {query}")
    print("-" * 50)
    
    # Send the query
    response = openai_client.responses.create(
        conversation=conversation.id,
        input=query,
        extra_body={"agent_reference": {"name": agent.name, "type": "agent_reference"}},
    )
    
    # Process any MCP approval requests
    response = process_mcp_response(openai_client, agent, response)
    
    # Display the response
    print(f"\n🤖 Agent Response:")
    print(response.output_text if response.output_text else "No response text")
    print("\n" + "=" * 60)
# Out:
# 💬 Foundry MCP Server Assistant Session
# ============================================================
#
# 📝 Query 1: What AI models would you recommend for document analysis use cases?
# --------------------------------------------------
#
# 🤖 Agent Response:
# For document analysis use cases, here are some recommended AI models from Microsoft Foundry:
#
# ### High-Quality Language Models:
# 1. **GPT-4o** (General-purpose capabilities for document analysis):
#    - Tasks: Chat completion, responses
#    - Publisher: OpenAI
#    - Suitable for summarization, entity extraction, and document comprehension.
#
# 2. **Mistral-document-ai-2512**:
#    - Tasks: Image-to-text for document parsing
#    - Publisher: Mistral AI
#    - Good for PDF or image-based document extraction.
#
# 3. **GPT-4.1**:
#    - Tasks: Chat completion, responses
#    - Publisher: OpenAI
#    - High throughput and accuracy for deep document insights.
#
# 4. **Cohere-rerank-v4.0-pro**:
#    - Tasks: Text classification and ranking
#    - Publisher: Cohere
#    - Ideal for managing large archives and prioritizing information.
#
# ---
#
# ### Multimodal Capabilities:
# 1. **Mistral-ocr-2503**:
#    - Tasks: Image-to-text
#    - Publisher: Mistral AI
#    - Perfect for text extraction from scanned documents or forms.
#
# 2. **Mistral-medium-2505**:
#    - Tasks: Chat completion, image classification
#    - Publisher: Mistral AI
#    - Useful for multimodal inference involving both text and images.
#
# ---
#
# ### Specialized Use Cases:
# 1. **Financial-reports-analysis-v2**:
#    - Tasks: Chat completion
#    - Publisher: Microsoft
#    - Tailored for financial document insights and report analysis.
#
# 2. **Supply-chain-trade-regulations-v2**:
#    - Tasks: Chat completion
#    - Publisher: Microsoft
#    - Focused on regulatory documentation related to supply chains.
#
# ---
#
# ### Free-Playground Options (Prototyping):
# For prototyping, models tagged as **"Free Playground"** may also be relevant, such as:
# - **GPT-5.4-pro**
# - **FW-MiniMax-M2.5**
#
# Would you like assistance with deploying any of these models or exploring their specific capabilities?
#
# ============================================================
#
# 📝 Query 2: Explain how the Foundry MCP Server helps with AI development workflows.
# --------------------------------------------------
#
# 🤖 Agent Response:
# The Foundry MCP Server is a robust tool in the Azure ecosystem that facilitates streamlined AI development workflows. It provides developers with centralized access, management, and optimization capabilities for deploying and operating AI models, agents, datasets, and evaluations. Here's how it helps:
#
# ---
#
# ### 🧠 **Model Management**
# 1. **Accessing Model Catalogs**:
#    - Browse a wide variety of models, including OpenAI, Hugging Face, and Cohere models.
#    - Explore capabilities such as multilingual embeddings, document analysis, chat generation, and advanced summarization.
#    - Identify models suited to specific tasks like text generation, image-to-text analysis, or regulatory insight extraction.
#
# 2. **Model Deployment**:
#    - Deploy models to the Azure cloud for testing or production use.
#    - Specify parameters like scale type, SKU capacity, and regions for efficient deployment.
#    - Obtain deprecation warnings or switch recommendations for finding replacement models.
#
# 3. **Benchmark Analysis**:
#    - Compare models based on metrics such as cost, accuracy, latency, throughput, and safety.
#    - Access detailed benchmark data to assess model performance for specific workflows.
#
# ---
#
# ### 🤖 **Agent Workflow**
# 1. **Creating AI Agents**:
#    - Build versatile agents powered by language models (e.g., GPT-4).
#    - Support both simple prompt-based (static LLM-powered) and hosted container-based agents (dynamic and scalable).
#
# 2. **Agent Operations**:
#    - Start, stop, or manage container lifecycles for hosted agents.
#    - Invoke agents to test and deploy responses for complex use cases like conversational interfaces or expert systems.
#
# 3. **Agent Customization**:
#    - Customize tools, datasets, and prompts for specific applications.
#    - Integrate external connections like Azure OpenAI or custom API services.
#
# ---
#
# ### 📊 **Evaluation Controls**
# 1. **Performance Evaluations**:
#    - Run batch evaluations across datasets to measure accuracy, coherence, relevance, and groundedness.
#    - Optimize safety and quality using prebuilt evaluators (e.g., violence, sexual harm, code vulnerability).
#
# 2. **Synthetic Data Generation**:
#    - Automatically generate test sets using powerful language models.
#    - Ideal for applications requiring dynamic and robust testing.
#
# 3. **Evaluator Catalog**:
#    - Define custom evaluators (e.g., specific grading metrics) for workflows.
#    - Enhance trust by building tailored metrics.
#
# ---
#
# ### 🔍 **Integration with Data**:
# 1. **Dataset Management**:
#    - Upload, curate, and manage dataset versions.
#    - Support JSONL, image files, or grounding/context data for specific applications.
#
# 2. **External Connections**:
#    - Integrate external services like Azure Cognitive Search, containers, or API-based endpoints.
#    - Manage authentication and metadata for seamless integration.
#
# ---
#
# ### 🚀 **Optimization and Monitoring**
# 1. **Prompt Optimization**:
#    - Craft and optimize system messages for language models, improving task adherence and efficiency.
#
# 2. **Quota Monitoring**:
#    - Track usage and quotas for model deployments to avoid overages.
#    - Get alerts for nearing subscription limits or regions with capacity concerns.
#
# 3. **AI Recommendations**:
#    - Receive suggestions for switching to better-performing or cost-efficient models.
#    - Ensure long-term sustainability by adapting to new capabilities or deprecated models.
#
# ---
#
# ### 🛡️ **Safety and Compliance**
# 1. **Content Moderation**:
#    - Employ safety evaluation tools to flag harmful or biased content.
#
# 2. **License Management**:
#    - Simplify compliance tracking for publisher-specific terms and licenses.
#
# ---
#
# The Foundry MCP Server enables end-to-end automation and streamlines workflows ranging from experiment initiation to production readiness. Developers benefit from faster iteration, thoughtful model comparisons, and integrated management tools.
#
# Would you like guidance optimizing a specific workflow or deploying an AI model?
#
# ============================================================
#
# 📝 Query 3: What security features does the Foundry MCP Server provide for enterprise use?
# --------------------------------------------------
#
# 🤖 Agent Response:
# The Foundry MCP Server offers several robust security features designed for enterprise-grade AI development and deployment. These features ensure data protection, user access control, compliance adherence, and safe operations of AI models and agents in the Azure ecosystem. Here’s an overview:
#
# ---
#
# ### 🔑 **Authentication and Access Control**
# 1. **Role-Based Access Control (RBAC)**:
#    - Fine-grained access management to restrict access based on roles (e.g., Administrator, Developer, Viewer).
#    - Streamlines permissions for managing models, agents, datasets, and evaluations.
#
# 2. **Secure Authentication Methods**:
#    - Supports various authentication types, including **API keys**, **Azure Active Directory (AAD)**, **Managed Identity**, and **Custom Keys**.
#    - Use AAD for single sign-on (SSO) and unified identity management across Azure services.
#
# 3. **Connection Security**:
#    - Enforces secure connections (HTTPS) for all endpoints.
#    - Configurable authentication protocols for external connections like Azure Cognitive Search or REST APIs.
#
# ---
#
# ### 🔒 **Data Security**
# 1. **Encryption**:
#    - Data encryption in transit (via SSL/TLS) and at rest ensures protection against unauthorized access.
#    - Azure Blob Storage with SAS (Shared Access Signature) facilitates secure uploading and retrieval of datasets.
#
# 2. **Secure Data Storage**:
#    - Support for storing sensitive datasets securely in Azure Blob Storage or other managed data stores.
#    - Metadata tagging and categorization help maintain control over dataset accessibility.
#
# 3. **Content Moderation and Filtering**:
#    - Built-in evaluators for **violence**, **self-harm**, **hate**, or **sexual content filtering**.
#    - Essential for ensuring content safety in enterprise operations.
#
# 4. **Model-Specific Safeguards**:
#    - Safety metrics (e.g., SafetyIndex for models) provide insights into potential bias or harmful tendencies.
#    - Recommended secure models, such as OpenAI's GPT OSS Safeguard series, designed for minimizing risk in sensitive use cases.
#
# ---
#
# ### 🔍 **Compliance and Auditability**
# 1. **Audit Trails**:
#    - Comprehensive activity logging for all operations, including model deployments, agents, evaluations, and dataset changes.
#    - Facilitate accountability and compliance reporting for stakeholders.
#
# 2. **Compliance with Azure Standards**:
#    - Ensure adherence to GDPR and other regulatory requirements with Azure's built-in compliance tools.
#    - Access certifications for compliance such as ISO 27001, SOC 2, HIPAA, and FedRAMP.
#
# 3. **Content Safety Evaluators**:
#    - Evaluate and grade content according to enterprise compliance guidelines.
#    - Helpful for applications involving sensitive information, moderation, or public use cases.
#
# ---
#
# ### 🛡️ **Safe Development and Deployment**
# 1. **Container Security for Hosted Agents**:
#    - Containerized agents operate in isolated environments, reducing risk and preventing unauthorized access.
#    - Options to configure autoscaling within secure limits to manage workloads efficiently.
#
# 2. **System Message Safety**:
#    - Prompt optimization includes a focus on reducing potential for harmful or biased system prompts.
#    - Improve adherence to ethical standards in AI outputs.
#
# 3. **User-Specific Quotas**:
#    - Enforce usage quotas and limits for enterprise accounts to prevent abuse or unintended costs.
#    - Monitor utilization in real time to track resource consumption.
#
# ---
#
# ### 🚨 **Runtime and Operational Safety**
# 1. **Monitoring and Alerts**:
#    - Continuous runtime monitoring to identify anomalies, performance issues, or potential breaches.
#    - Notification systems for threshold breaches, model deprecation, or quota overages.
#
# 2. **Protection Against Adverse AI Outputs**:
#    - Ensures enterprise production deployments are safeguarded against harmful or inappropriate model outputs.
#    - Evaluator thresholds can be customized for sensitive use cases to enforce stronger safety measures.
#
# ---
#
# ### 🤝 **Managed Enterprise Features**
# 1. **Managed Compute Options**:
#    - Dedicated Azure Virtual Machines (VMs) for secure and isolated compute environments.
#    - Enhanced control for resource and user activity.
#
# 2. **Serverless Endpoints**:
#    - Automatically scale resources up or down without exposing the underlying infrastructure.
#    - Ideal for enterprises focused on agility and operational efficiency.
#
# 3. **Integration with Enterprise Systems**:
#    - Easily integrate with other Azure enterprise systems like Azure Active Directory, Cognitive Services, and Data Factory.
#    - Use APIs to securely integrate with third-party systems.
#
# ---
#
# ### Security Recommendations for Enterprise Users
# 1. Implement strict RBAC policies for sensitive operations like deploying hosted agents or creating connections.
# 2. Regularly audit usage logs and evaluator outcomes to ensure compliance.
# 3. Use specialized models with safety certifications for risk-prone use cases.
# 4. Leverage encryption standards for datasets and model-related data at all stages.
# 5. Configure alerts for quota, resource utilization, and content safety for visibility into operations.
#
# Would you like to learn more about implementing these security features or securing a specific workflow in your enterprise?
#
# ============================================================

# %% [markdown]
# ## 7. Interactive MCP Query (Optional)
#
# Try your own queries with the MCP-enabled agent.

# %%
# Interactive query - try Foundry MCP Server prompts
# Example prompts you can try:
# - "What are the most popular models in Microsoft Foundry?"
# - "Show me models with MIT license"
# - "What models from Meta are available?"
# - "Compare GPT-4o and Phi-4 for my use case"

custom_query = "What capabilities does the Foundry MCP Server provide for building AI agents?"

print(f"📝 Custom Query: {custom_query}")
print("-" * 50)

# Send the query
response = openai_client.responses.create(
    conversation=conversation.id,
    input=custom_query,
    extra_body={"agent_reference": {"name": agent.name, "type": "agent_reference"}},
)

# Process any MCP approval requests
response = process_mcp_response(openai_client, agent, response)

# Display the response
print(f"\n🤖 Agent Response:")
print(response.output_text if response.output_text else "No response text")
# Out:
# 📝 Custom Query: What capabilities does the Foundry MCP Server provide for building AI agents?
# --------------------------------------------------
#
# 🤖 Agent Response:
# The Foundry MCP Server is an exceptional platform for building robust and intelligent AI agents. It provides powerful tools and features that support simple and complex agent development for various use cases like conversational AI, task automation, chatbot deployment, and more. Here's how the Foundry MCP Server enables AI agent creation:
#
# ---
#
# ### **Types of AI Agents**
# 1. **Prompt-Based Agents**:
#    - Use a language model with a predefined system prompt to generate responses.
#    - Requires minimal setup and ideal for conversational AI, Q&A systems, summarization tasks, etc.
#
# 2. **Hosted Agents**:
#    - Container-based agents featuring customizable code and configurations.
#    - Suitable for applications that require more complex workflows, tool integrations, or hosted runtime flexibility.
#
# ---
#
# ### 📜 **Agent Creation and Management**
# 1. **Agent Definition Schema**:
#    - Foundry MCP provides a comprehensive schema for defining agents, including capabilities, tools, configurations, and prompts.
#    - Supports customization of agents to meet specific business scenarios.
#    - Agents can leverage prebuilt tools or custom tools.
#
# 2. **Agent Updates and Cloning**:
#    - Update existing agents to refine behavior and improve response quality.
#    - Clone agents to duplicate configurations and switch seamlessly between models or workflows.
#
# 3. **Agent Version Control**:
#    - Maintain multiple versions of agents for testing or production environments.
#    - Ensure safe updates and rollbacks when needed.
#
# ---
#
# ### 🤖 **Integrating Agents with Tools**
# 1. **Tool Integration**:
#    - Embed tools for knowledge base querying, document extraction, external API calls, web search, and cognitive services.
#    - Create custom tools as Python modules or APIs and integrate them seamlessly.
#
# 2. **Multi-Modal Integration**:
#    - Include tools for image processing, text-to-speech, transcription, and sentiment analysis to enhance multimodal capabilities.
#
# ---
#
# ### 💬 **Agent Invocation**
# 1. **User Interaction**:
#    - Invoke agents by sending input text for chat-like interactions or task execution.
#    - Support for multi-turn conversations using session IDs or conversation IDs.
#
# 2. **Dynamic Responsiveness**:
#    - Agents can generate responses using real-time context or grounding data provided during invocation.
#
# ---
#
# ### ⚙️ **Hosted Agent Features**
# 1. **Containerized Deployment**:
#    - Deploy agents in secure and isolated hosted environments.
#    - Configure container parameters like CPU, memory allocation, and auto-scaling limits.
#
# 2. **Lifecycle Management**:
#    - Start, stop, and monitor container operations using lifecycle control tools.
#    - Ideal for scaling resources based on agent activity and demand.
#
# ---
#
# ### 📊 **Agent Evaluation and Optimization**
# 1. **Performance Evaluation**:
#    - Use built-in evaluators to test agents for fluency, relevance, coherence, groundedness, and task adherence.
#    - Assess behavior and optimize for high-performance output.
#
# 2. **Safety Monitoring**:
#    - Evaluate agents using safety metrics like violence, sexual harm, bias, or code vulnerability detection.
#    - Mitigate risks before deploying for public or sensitive use cases.
#
# 3. **Prompt Optimization**:
#    - Fine-tune agent system messages for adhering to desired goals and minimizing bias or inefficiencies.
#
# ---
#
# ### 🛠️ **Customization Capabilities**
# 1. **Custom Systems and Behaviors**:
#    - Define tailored workflows with specific prompts, tools, or configurations to match unique business needs.
#
# 2. **Integration with Enterprise Systems**:
#    - Connect agents with external data sources or endpoints like Azure OpenAI, Cognitive Services, or API-based tools.
#    - Leverage metadata and authentication for secure interactions.
#
# 3. **Agent Scaling**:
#    - Scale hosted agents dynamically with configurable autoscaling parameters to handle high workloads.
#
# ---
#
# ### 👌 **Example Use Cases for AI Agents**
# 1. Conversational Interfaces for Customer Service:
#    - Prompt-based or hosted agents that answer customer queries or provide troubleshooting guidance.
#
# 2. Knowledge Base Extraction:
#    - Agents retrieving and summarizing information from large document repositories.
#
# 3. Automated Task Delegation:
#    - Agents integrated with APIs to execute workflows (e.g., scheduling meetings, handling forms).
#
# 4. Content Moderation:
#    - Agents capable of flagging harmful or biased outputs across enterprise applications.
#
# 5. Multimodal Applications:
#    - Hosted agents with capabilities like transcription, text-to-image, or document scanning.
#
# ---
#
# ### ⚡ **Advantages of Foundry MCP Server for Agents**
# 1. Scalability: Hosted container agents scale with demand.
# 2. Extensibility: Easily integrate external tools or APIs.
# 3. Security: Use secure authentication methods like AAD or Managed Identity.
# 4. Custom Evaluations: Build agents tailored to enterprise standards with performance evaluation.
# 5. Optimization: Improve agent performance with prompt and tool updates.
#
# Would you like assistance creating an AI agent or exploring configuration templates?

# %% [markdown]
# ## 8. Cleanup
#
# Delete the agent when done to clean up resources.

# %%
# Cleanup: Delete the agent
print("🧹 Cleaning up resources...")

try:
    project_client.agents.delete_version(
        agent_name=agent.name,
        agent_version=agent.version
    )
    print(f"✅ Agent deleted: {agent.name} (Version: {agent.version})")
except Exception as e:
    print(f"⚠️ Error during cleanup: {e}")

print("\n🎉 MCP Tools notebook completed!")
# Out:
# 🧹 Cleaning up resources...
# ✅ Agent deleted: foundry-mcp-assistant (Version: 1)
#
# 🎉 MCP Tools notebook completed!

# %% [markdown]
# ## 📚 Summary
#
# In this notebook, we learned how to use the **Foundry MCP Server** to enhance AI agents with Foundry capabilities.
#
# ### Key Setup Steps:
#
# 1. **Configure in Portal**: Create MCP connection in Microsoft Foundry portal
# 2. **Get Connection ID**: Copy the connection ID from the portal
# 3. **Add to .env**: Set `FOUNDRY_MCP_CONNECTION_ID` in your environment
# 4. **Create Agent**: Use `MCPTool` with `project_connection_id`
#
# ### Key Concepts:
#
# | Concept | Description |
# |---------|-------------|
# | **Foundry MCP Server** | Cloud-hosted MCP service at `https://mcp.ai.azure.com` |
# | **MCPTool** | Tool configuration for connecting to the server |
# | **project_connection_id** | **Required** - Connection configured in Foundry portal |
# | **Entra ID Auth** | Secure authentication with user-specific permissions |
# | **Approval Flow** | Security feature requiring user consent |
#
# ### Foundry MCP Server Tool Categories:
#
# | Category | Example Tools | Use Cases |
# |----------|--------------|-----------|
# | **Models** | `model_catalog_list`, `model_deploy`, `model_quota_list` | Explore, compare, and deploy AI models |
# | **Evaluations** | `evaluation_create`, `evaluation_get` | Quality and safety assessments |
# | **Agents** | `agent_update`, `agent_list` | Agent lifecycle management |
# | **Knowledge** | `index_list`, `query_index` | Azure AI Search integration |
#
# ### Example Prompts for Foundry MCP Server:
#
# ```
# # Model Exploration
# "What OpenAI models are available in Microsoft Foundry?"
# "Compare Phi models and explain their differences"
# "What models are good for reasoning tasks?"
#
# # Deployment
# "What quota do I have available for GPT-4o?"
# "Help me deploy a model for my project"
#
# # Evaluation
# "How do I evaluate my agent's quality?"
# "What evaluators are available for text generation?"
#
# # General Use Cases
# "Recommend models for document analysis"
# "What models have appropriate licensing for enterprise use?"
# ```
#
# ### 🔐 Security Best Practices:
#
# - ✅ Foundry MCP Server uses **Entra ID authentication**
# - ✅ All operations run under **user's Azure RBAC permissions**
# - ✅ Every activity is **logged for auditing**
# - ✅ Use `require_approval="never"` for simpler demos, or `"always"` for production with manual approval
# - ✅ Tenant admins can enforce access via **Azure Policy**
#
# ### 🚀 Using Foundry MCP Server in VS Code
#
# You can also use Foundry MCP Server directly in VS Code with GitHub Copilot:
#
# 1. Open VS Code with GitHub Copilot enabled
# 2. Add to `.vscode/mcp.json`:
# ```json
# {
#   "servers": {
#     "foundry-mcp-remote": {
#       "type": "http",
#       "url": "https://mcp.ai.azure.com"
#     }
#   }
# }
# ```
# 3. Start chatting with Copilot using Foundry tools!
#
# ### 📚 Resources:
#
# - [Foundry MCP Server Documentation](https://learn.microsoft.com/azure/ai-foundry/mcp/get-started)
# - [Available Tools Reference](https://learn.microsoft.com/azure/ai-foundry/mcp/available-tools)
# - [Security Best Practices](https://learn.microsoft.com/azure/ai-foundry/mcp/security-best-practices)
# - [Microsoft Foundry Blog - MCP Announcement](https://devblogs.microsoft.com/foundry/announcing-foundry-mcp-server-preview-speeding-up-ai-dev-with-microsoft-foundry/)
# - [GitHub: mcp-foundry (legacy reference)](https://github.com/microsoft-foundry/mcp-foundry)
