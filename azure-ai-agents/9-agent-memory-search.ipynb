# %% [markdown]
# # 🧠 Agent Memory Search: Personalized Banking Assistant
#
# Welcome to our **Agent Memory Search** tutorial! This notebook demonstrates how to build an AI banking assistant that **remembers customer preferences** across conversations using the **Memory Search Tool**.
#
# ## What You'll Build
#
# A **Personalized Banking Advisor** that:
# - 🧠 **Remembers** customer preferences (risk tolerance, account types, communication preferences)
# - 💬 **Recalls** past interactions in new conversations
# - 🏦 **Provides personalized** financial guidance based on stored memories
# - 📊 **Maintains context** across multiple banking sessions
#
# ## Why Memory Matters in Banking
#
# | Without Memory | With Memory |
# |----------------|-------------|
# | Customer repeats preferences every call | Agent recalls "You prefer low-risk investments" |
# | Generic product recommendations | Personalized suggestions based on history |
# | No context from previous sessions | Seamless continuation of past discussions |
# | Impersonal experience | "Welcome back! Last time we discussed..." |
#
# ## Architecture Overview
#
# ```
# ┌──────────────────────────────────────────────────────────────────────┐
# │                    MEMORY-ENABLED BANKING AGENT                       │
# ├──────────────────────────────────────────────────────────────────────┤
# │                                                                       │
# │   Conversation 1                    Conversation 2                    │
# │   ┌─────────────┐                  ┌─────────────┐                   │
# │   │ "I prefer   │                  │ "What should│                   │
# │   │  low-risk   │                  │  I invest   │                   │
# │   │  investments"│                 │  in?"       │                   │
# │   └──────┬──────┘                  └──────┬──────┘                   │
# │          │                                │                          │
# │          ▼                                ▼                          │
# │   ┌─────────────┐                  ┌─────────────┐                   │
# │   │   Memory    │◄────────────────►│   Memory    │                   │
# │   │   Store     │   Automatic      │   Search    │                   │
# │   │  (Extract)  │   Retrieval      │  (Recall)   │                   │
# │   └──────┬──────┘                  └──────┬──────┘                   │
# │          │                                │                          │
# │          ▼                                ▼                          │
# │   ┌──────────────────────────────────────────────┐                   │
# │   │           Azure AI Memory Store               │                   │
# │   │  • User Profile (preferences, risk tolerance) │                   │
# │   │  • Chat Summary (conversation highlights)     │                   │
# │   │  • Semantic Search (find relevant memories)   │                   │
# │   └──────────────────────────────────────────────┘                   │
# │                                                                       │
# └──────────────────────────────────────────────────────────────────────┘
# ```
#
# ## Prerequisites
#
# - Microsoft Foundry project with appropriate permissions
# - **Chat model deployment** (e.g., `gpt-4o`)
# - **Embedding model deployment** (e.g., `text-embedding-3-large`)
# - A `.env` file in the project root containing (uses existing variables):
#   ```bash
#   AI_FOUNDRY_PROJECT_ENDPOINT=<your-ai-foundry-project-endpoint>
#   AZURE_AI_MODEL_DEPLOYMENT_NAME=gpt-4o
#   EMBEDDING_MODEL_DEPLOYMENT_NAME=text-embedding-3-large
#   TENANT_ID=<your-azure-tenant-id>
#   ```
#
# ## Key Concepts
#
# | Concept | Description |
# |---------|-------------|
# | **Memory Store** | Persistent storage for extracted memories from conversations |
# | **Memory Search Tool** | Agent tool that retrieves relevant memories during conversations |
# | **Scope** | User identifier to isolate memories per customer |
# | **User Profile** | Automatically extracted preferences and traits |
# | **Chat Summary** | Condensed highlights from past conversations |
#
# ### ⚠️ Important Financial Disclaimer
# > **The financial information provided by this notebook is for general educational and demonstration purposes only.** Always consult with qualified financial advisors before making financial decisions.
#
# 📚 **Reference**: [Azure AI Agent Memory Documentation](https://learn.microsoft.com/azure/ai-services/agents/concepts/memory)

# %% [markdown]
# ---
#
# ## 🔐 Authentication Setup
#
# Before running the next cell, make sure you're authenticated with Azure CLI:
#
# ```bash
# az login --use-device-code
# ```
#
# This provides device code authentication, useful for:
# - Remote development environments
# - Systems without a default browser
# - Corporate environments with strict security policies

# %% [markdown]
# ---
#
# ## 📦 Step 1: Install Required Packages
#
# The required packages should already be installed via the `requirements.txt` file at the project root:
#
# ```bash
# pip install -r requirements.txt
# ```
#
# If packages are not installed, uncomment and run the cell below.

# %%
# Packages should be installed via requirements.txt at project root
# If not installed, uncomment the line below and run this cell:

# %pip install azure-ai-projects>=2.0.0b1 azure-identity openai python-dotenv --quiet

print("✅ Packages ready (installed via requirements.txt)")
# Out:
# ✅ Packages ready (installed via requirements.txt)

# %% [markdown]
# ---
#
# ## 🔧 Step 2: Load Configuration and Initialize Clients
#
# Load environment variables and establish connections to Microsoft Foundry.

# %%
import os
import time
from pathlib import Path
from dotenv import load_dotenv
from azure.identity import AzureCliCredential
from azure.core.exceptions import ResourceNotFoundError
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import (
    MemoryStoreDefaultDefinition,
    MemorySearchPreviewTool,
    PromptAgentDefinition,
    MemoryStoreDefaultOptions,
)

# Load environment variables from parent .env
notebook_path = Path().absolute()
parent_dir = notebook_path.parent
load_dotenv(parent_dir.parent / '.env')

# Get configuration - using existing .env variables
tenant_id = os.environ.get("TENANT_ID")
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")
model_deployment = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o")
embedding_deployment = os.environ.get("EMBEDDING_MODEL_DEPLOYMENT_NAME", "text-embedding-3-large")

# Memory store uses the same models as the rest of the project
memory_chat_model = model_deployment
memory_embedding_model = embedding_deployment

print("🧠 Agent Memory Search - Personalized Banking Assistant")
print("=" * 60)
print(f"🔑 Tenant ID: {tenant_id}")
print(f"📍 Project Endpoint: {project_endpoint[:50]}..." if project_endpoint else "❌ Missing")
print(f"🤖 Agent Model: {model_deployment}")
print(f"🧠 Memory Chat Model: {memory_chat_model}")
print(f"📊 Memory Embedding Model: {memory_embedding_model}")
# Out:
# 🧠 Agent Memory Search - Personalized Banking Assistant
# ============================================================
# 🔑 Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3
# 📍 Project Endpoint: https://demopocaifoundry.services.ai.azure.com/api...
# 🤖 Agent Model: gpt-4o
# 🧠 Memory Chat Model: gpt-4o
# 📊 Memory Embedding Model: text-embedding-3-large

# %%
# Initialize AIProjectClient with Azure CLI authentication
print("🔐 Initializing clients with AzureCliCredential...")
print("   Make sure you've run 'az login' in your terminal first!")
print("")

credential = AzureCliCredential(tenant_id=tenant_id)

# Create the project client (allow_preview needed for memory stores)
project_client = AIProjectClient(
    endpoint=project_endpoint,
    credential=credential,
    allow_preview=True
)

# Get the OpenAI client for conversations
openai_client = project_client.get_openai_client()

print("✅ AIProjectClient initialized (preview features enabled)")
print("✅ OpenAI client ready for conversations")
# Out:
# 🔐 Initializing clients with AzureCliCredential...
#    Make sure you've run 'az login' in your terminal first!
#
# ✅ AIProjectClient initialized (preview features enabled)
# ✅ OpenAI client ready for conversations

# %% [markdown]
# ---
#
# ## 🗄️ Step 3: Create a Memory Store
#
# The **Memory Store** is where customer memories are persisted. It uses:
# - A **chat model** to extract meaningful memories from conversations
# - An **embedding model** to enable semantic search across memories
#
# ### Memory Store Options:
# | Option | Description |
# |--------|-------------|
# | `user_profile_enabled` | Extract and maintain user preferences/traits |
# | `chat_summary_enabled` | Create summaries of past conversations |

# %%
# Memory store configuration for banking assistant
memory_store_name = "banking-customer-memory-store"

# Delete existing memory store if it exists (for clean demo)
print("🧹 Cleaning up existing memory store (if any)...")
try:
    project_client.beta.memory_stores.delete(memory_store_name)
    print(f"   🗑️ Deleted existing memory store '{memory_store_name}'")
    time.sleep(2)
except ResourceNotFoundError:
    print(f"   ℹ️ No existing memory store found (OK)")

# Define memory store with chat and embedding models
print("\n🏗️ Creating memory store...")

memory_definition = MemoryStoreDefaultDefinition(
    chat_model=memory_chat_model,
    embedding_model=memory_embedding_model,
    options=MemoryStoreDefaultOptions(
        user_profile_enabled=True,   # Extract user preferences
        chat_summary_enabled=True    # Summarize conversations
    )
)

# Create the memory store
memory_store = project_client.beta.memory_stores.create(
    name=memory_store_name,
    description="Memory store for personalized banking assistant - stores customer preferences, risk tolerance, and conversation history",
    definition=memory_definition
)

print("\n" + "=" * 60)
print("✅ Memory Store Created")
print("=" * 60)
print(f"📦 Name: {memory_store.name}")
print(f"🆔 ID: {memory_store.id}")
print(f"📝 Description: {memory_store.description}")
print(f"\n🧠 Memory Capabilities:")
print(f"   • User Profile Extraction: ✅ Enabled")
print(f"   • Chat Summarization: ✅ Enabled")
print(f"   • Semantic Search: ✅ Ready")
# Out:
# 🧹 Cleaning up existing memory store (if any)...
#    🗑️ Deleted existing memory store 'banking-customer-memory-store'
#
# 🏗️ Creating memory store...
#
# ============================================================
# ✅ Memory Store Created
# ============================================================
# 📦 Name: banking-customer-memory-store
# 🆔 ID: memstore_1f1044f6d1beface00HU9WxLaxjsMPgg2c2RXqSTuvxZqC6kmy
# 📝 Description: Memory store for personalized banking assistant - stores customer preferences, risk tolerance, and conversation history
#
# 🧠 Memory Capabilities:
#    • User Profile Extraction: ✅ Enabled
#    • Chat Summarization: ✅ Enabled
#    • Semantic Search: ✅ Ready

# %% [markdown]
# ---
#
# ## 🔧 Step 4: Configure the Memory Search Tool
#
# The **Memory Search Tool** allows the agent to:
# 1. **Search** for relevant memories during conversations
# 2. **Update** memories after periods of inactivity
#
# ### Key Parameters:
# | Parameter | Description |
# |-----------|-------------|
# | `memory_store_name` | The memory store to search |
# | `scope` | User identifier (e.g., customer ID) to isolate memories |
# | `update_delay` | Seconds of inactivity before extracting new memories |

# %%
# Define customer scope - in production, this would be the customer's unique ID
# You can also use "{{$userId}}" to automatically use the authenticated user's ID
customer_id = "customer_john_doe_12345"

# Configure Memory Search Tool
memory_tool = MemorySearchPreviewTool(
    memory_store_name=memory_store.name,
    scope=customer_id,
    update_delay=5  # Wait 5 seconds of inactivity before updating memories
    # In production, use a higher value like 300 (5 minutes)
)

print("🔧 Memory Search Tool Configured")
print("=" * 60)
print(f"📦 Memory Store: {memory_tool.memory_store_name}")
print(f"👤 Customer Scope: {memory_tool.scope}")
print(f"⏱️ Update Delay: {memory_tool.update_delay} seconds")
print("\n💡 How it works:")
print("   1. Agent automatically searches memories when responding")
print("   2. After inactivity, new memories are extracted and stored")
print("   3. Memories are scoped to this specific customer")
# Out:
# 🔧 Memory Search Tool Configured
# ============================================================
# 📦 Memory Store: banking-customer-memory-store
# 👤 Customer Scope: customer_john_doe_12345
# ⏱️ Update Delay: 5 seconds
#
# 💡 How it works:
#    1. Agent automatically searches memories when responding
#    2. After inactivity, new memories are extracted and stored
#    3. Memories are scoped to this specific customer

# %% [markdown]
# ---
#
# ## 🤖 Step 5: Create the Memory-Enabled Banking Agent
#
# Create a personalized banking assistant that uses memory to provide contextual, personalized financial guidance.

# %%
# Agent name for the banking assistant
agent_name = "personalized-banking-advisor"

# Detailed instructions for the banking agent
agent_instructions = """
You are a Personalized Banking Advisor with memory capabilities. You remember customer preferences and past interactions to provide tailored financial guidance.

## YOUR CAPABILITIES:

🧠 **Memory-Enabled Personalization**
- You remember customer preferences shared in previous conversations
- You recall risk tolerance, investment preferences, and financial goals
- You reference past discussions to provide continuity

🏦 **Banking Services**
- Savings and checking account guidance
- Certificate of Deposit (CD) recommendations
- Money market account information
- General loan and mortgage information

📊 **Investment Guidance**
- Risk assessment discussions
- Portfolio diversification concepts
- Retirement planning basics (401k, IRA)
- Investment product education

## HOW TO RESPOND:

1. **Use Memory**: Reference what you remember about the customer:
   - "Based on your preference for low-risk investments..."
   - "Since you mentioned you're saving for retirement..."
   - "Given your conservative risk tolerance..."

2. **Ask About Preferences**: If you don't have relevant memories:
   - "What's your risk tolerance for investments?"
   - "What are your primary financial goals?"
   - "Do you prefer aggressive or conservative strategies?"

3. **Personalize Recommendations**: Tailor advice to stored preferences:
   - Match products to risk tolerance
   - Align suggestions with stated goals
   - Reference past discussions when relevant

## IMPORTANT DISCLAIMERS:

⚠️ Always include appropriate disclaimers:
- You are not a licensed financial advisor
- Recommendations are for educational purposes only
- Customers should consult qualified professionals for personalized advice
- Past performance does not guarantee future results

## EXAMPLE INTERACTIONS:

**First Conversation:**
Customer: "I'm looking to invest but I'm risk-averse"
You: Store this preference and suggest conservative options like bonds, CDs, high-yield savings

**Later Conversation:**
Customer: "What should I invest in?"
You: "Based on your conservative risk profile from our previous discussion, you might consider..."
"""

print(f"📝 Creating agent: {agent_name}")
print(f"   Instructions: {len(agent_instructions)} characters")
# Out:
# 📝 Creating agent: personalized-banking-advisor
#    Instructions: 2107 characters

# %%
# Create the agent with Memory Search Tool
print("🤖 Creating Memory-Enabled Banking Agent...")

agent = project_client.agents.create_version(
    agent_name=agent_name,
    definition=PromptAgentDefinition(
        model=model_deployment,
        instructions=agent_instructions,
        tools=[memory_tool]  # Attach the memory search tool
    )
)

print("\n" + "=" * 60)
print("✅ Agent Created with Memory Capabilities")
print("=" * 60)
print(f"🤖 Name: {agent.name}")
print(f"🆔 ID: {agent.id}")
print(f"📌 Version: {agent.version}")
print(f"🧠 Model: {model_deployment}")
print(f"🔧 Tools: Memory Search Tool")
print(f"\n🎯 Agent Capabilities:")
print(f"   • Remember customer preferences across conversations")
print(f"   • Recall past financial discussions")
print(f"   • Provide personalized banking guidance")
# Out:
# 🤖 Creating Memory-Enabled Banking Agent...
#
# ============================================================
# ✅ Agent Created with Memory Capabilities
# ============================================================
# 🤖 Name: personalized-banking-advisor
# 🆔 ID: personalized-banking-advisor:1
# 📌 Version: 1
# 🧠 Model: gpt-4o
# 🔧 Tools: Memory Search Tool
#
# 🎯 Agent Capabilities:
#    • Remember customer preferences across conversations
#    • Recall past financial discussions
#    • Provide personalized banking guidance

# %% [markdown]
# ---
#
# ## 💬 Step 6: Establish Customer Preferences (Conversation 1)
#
# In this first conversation, the customer will share their financial preferences. The agent will:
# 1. Respond helpfully
# 2. Store these preferences in memory for future use

# %%
# Helper function to chat with the agent
def chat_with_agent(conversation_id, message, agent_ref):
    """Send a message to the agent and get a response."""
    print(f"\n👤 Customer: {message}")
    print("⏳ Agent thinking...")
    
    response = openai_client.responses.create(
        input=message,
        conversation=conversation_id,
        extra_body={
            "agent_reference": {
                "name": agent_ref.name,
                "version": agent_ref.version,
                "type": "agent_reference"
            }
        }
    )
    
    print(f"\n🤖 Advisor: {response.output_text}")
    return response

print("✅ Chat helper function defined")
# Out:
# ✅ Chat helper function defined

# %%
# Create first conversation - establishing preferences
print("📞 Starting Conversation 1: Establishing Customer Preferences")
print("=" * 70)

conversation1 = openai_client.conversations.create()
print(f"✅ Conversation created (ID: {conversation1.id})")

# Customer shares their preferences
preference_messages = [
    "Hi, I'm a new customer. I'm 45 years old and I prefer conservative, low-risk investments. I'm saving for retirement in about 20 years.",
    "I also want to set up an emergency fund. I prefer to keep about 6 months of expenses in liquid savings.",
    "My annual income is around $120,000 and I can invest about $1,500 per month."
]

for msg in preference_messages:
    chat_with_agent(conversation1.id, msg, agent)
    print("\n" + "-" * 70)

print("\n" + "=" * 70)
print("✅ Conversation 1 Complete - Preferences Shared")
print("=" * 70)
# Out:
# 📞 Starting Conversation 1: Establishing Customer Preferences
# ======================================================================
# ✅ Conversation created (ID: conv_261b4d2a81363845006vW1sF9iBKNn6sLXWc3kljNI6OTUO1uW)
#
# 👤 Customer: Hi, I'm a new customer. I'm 45 years old and I prefer conservative, low-risk investments. I'm saving for retirement in about 20 years.
# ⏳ Agent thinking...
#
# 🤖 Advisor: Welcome! Thank you for sharing that helpful information. Here's what I'll keep in mind going forward:
#
# - You're 45 years old.
# - Your retirement timeline is about 20 years from now.
# - You prefer conservative, low-risk investments.
#
# Based on your goals and risk tolerance, here are a few suggestions to start planning for retirement:
#
# ### 1. **Maximize Retirement Accounts**
#    - If you have access to a **401(k)** through work, consider contributing enough to take full advantage of employer matching contributions (if offered). This is essentially free money toward your retirement.
#    - Consider opening an **IRA (Individual Retirement Account)** if you don’t already have one. A **Traditional IRA** may help you lower your taxable income now, while a **Roth IRA** provides tax-free withdrawals in retirement (depending on your income level and if you expect to be in a higher tax bracket later).
#
# ### 2. **Conservative Investment Options**
#    - Given your risk-averse approach, you could allocate a significant portion of your retirement portfolio to **bonds** (government or high-grade corporate bonds), which tend to be more stable than stocks.
#    - **Target-Date Funds** are an all-in-one option designed to adjust their asset allocation as you approach retirement. Look for funds designed for those retiring in about 20 years (e.g., target date 2045 funds).
#    - **Certificates of Deposit (CDs)** offer guaranteed returns with virtually no risk. They are good for short- to medium-term savings and can complement your long-term strategy.
#    - **High-Yield Savings Accounts** or **Money Market Accounts** are also options for safely growing emergency or short-term funds.
#
# ### 3. **Diversify for Stability**
#    - Even as a conservative investor, having a small portion of your portfolio in low-risk **dividend-paying stocks** or a blended fund (mix of stocks and bonds) could help you keep pace with inflation.
#    - Diversification is key to managing risk while still achieving some growth over a 20-year horizon.
#
# ### 4. **Consider Financial Planning Tools**
#    - A professional financial planner can help set up a specific plan tailored to you.
#    - Assess your retirement income needs and whether you’re on track using calculators or retirement planning software.
#
# Would you like me to elaborate on any of these options or assist you in choosing specific products for any of these recommendations? Let me know!
#
# ----------------------------------------------------------------------
#
# 👤 Customer: I also want to set up an emergency fund. I prefer to keep about 6 months of expenses in liquid savings.
# ⏳ Agent thinking...
#
# 🤖 Advisor: Got it! I'll add this detail to your profile:
#
# - You want to establish an **emergency fund** equal to about 6 months' worth of expenses.
# - You prefer **liquid savings** for your emergency fund.
#
# ### Emergency Fund Recommendations:
# To build and maintain your emergency fund while keeping your savings liquid and accessible, here are a few suggestions:
#
# 1. **High-Yield Savings Account (HYSA):**
#    - A high-yield savings account is a great place to store your emergency fund. These accounts often offer much higher interest rates than traditional savings accounts, which can help your savings grow over time while staying accessible.
#    - Look for accounts with no monthly fees and no withdrawal penalties.
#
# 2. **Money Market Accounts (MMAs):**
#    - Similar to an HYSA, a money market account balances competitive interest rates with easy access to funds. Some MMAs may come with check-writing privileges or debit cards.
#
# 3. **Laddered Short-Term CDs:**
#    - If you'd like to earn higher returns without sacrificing too much liquidity, you could consider a **CD ladder strategy** for part of your emergency fund. For example, divide your emergency fund into 3- or 6-month term CDs that mature at different times, ensuring you still have access to the money as needed.
#
# 4. **Maintain Accessibility:**
#    - Consider keeping smaller portions of your emergency fund in a regular savings account at your primary bank or credit union. That way, you can access some cash instantly in case of immediate emergencies.
#
# ### Next Steps:
# 1. Do you already have a high-yield savings account or money market account set up, or would you like help choosing one?
# 2. Would you like guidance on how to calculate exactly how much you need to save for your emergency fund?
#
# Let me know how I can assist you!
#
# ----------------------------------------------------------------------
#
# 👤 Customer: My annual income is around $120,000 and I can invest about $1,500 per month.
# ⏳ Agent thinking...
#
# 🤖 Advisor: Thank you for sharing your income and investment capacity. I'll add this to your profile:
#
# - **Annual income:** $120,000
# - **Available to invest monthly:** $1,500
#
# ### Here's how we can prioritize your financial goals:
#
# #### 1. **Building Your Emergency Fund**
#    - Start by determining how much you need for 6 months of expenses. For example, if your monthly fixed expenses (like rent, utilities, groceries, insurance, etc.) are $3,000, your goal would be $18,000.
#    - You can allocate part of your $1,500 monthly contribution to the emergency fund. For example:
#      - **$800/month to emergency savings** in a high-yield savings or money market account.
#      - You'll meet your goal in approximately **23 months** ($800 x 23 = $18,400).
#      - Once you’ve funded the emergency fund, you can redirect the $800 toward other goals or investments.
#
# #### 2. **Saving for Retirement**
#    - Since you have around 20 years until retirement, investing the balance of your monthly contribution—roughly **$700/month**—in a retirement account is a solid approach.
#    - If your employer offers a **401(k)** with company matching, start by contributing enough to maximize that match (e.g., a 5% contribution would be $6,000/year or $500/month).
#    - The remaining monthly amount can go into an **IRA** (Traditional or Roth depending on your tax situation and preferences). For 2023, the annual IRA contribution limit is $6,500 (or $541/month).
#
# #### 3. **Conservative Investment Allocation**
#    - For your retirement contributions, consider:
#      - **40% to bonds:** Government or corporate bonds provide steady returns with low risk.
#      - **30% to dividend-paying stocks or ETFs:** These generate income while still offering some growth potential.
#      - **20% to cash equivalents:** For example, high-yield savings or short-term CDs, which align with your low-risk preference.
#      - **10% to other diversified options:** Consider a balanced or target-date fund as a hassle-free choice to align with your 20-year goal.
#
# ### Adjustments Based on Preferences
# 1. Let me know how much of your monthly $1,500 you'd like to allocate toward the emergency fund versus retirement or other goals.
# 2. Are you already contributing to a 401(k), or do you need recommendations to open an IRA or other accounts?
# 3. Would you like me to help you estimate your retirement income needs?
#
# Let me know how you'd like to shape this plan! I'm here to help tailor it further. 🙂
#
# ----------------------------------------------------------------------
#
# ======================================================================
# ✅ Conversation 1 Complete - Preferences Shared
# ======================================================================

# %% [markdown]
# ---
#
# ## ⏳ Step 7: Wait for Memory Extraction
#
# After a period of inactivity (defined by `update_delay`), the agent automatically extracts memories from the conversation and stores them.
#
# **In this demo**: We wait a short time for memories to be extracted.
# **In production**: The `update_delay` would be longer (e.g., 5 minutes) to avoid extracting during active typing.

# %%
# Wait for memories to be extracted
wait_time = 30  # seconds

print("⏳ Waiting for memories to be extracted from Conversation 1...")
print(f"   This simulates the inactivity period ({wait_time} seconds)")
print("")

for i in range(wait_time, 0, -5):
    print(f"   🕐 {i} seconds remaining...")
    time.sleep(5)

print("\n🧠 Memories should now be extracted and stored!")
print("   The agent has learned:")
print("   • Customer is 45 years old")
print("   • Prefers conservative, low-risk investments")
print("   • Planning for retirement in 20 years")
print("   • Wants 6-month emergency fund")
print("   • Income: ~$120,000, can invest $1,500/month")
# Out:
# ⏳ Waiting for memories to be extracted from Conversation 1...
#    This simulates the inactivity period (30 seconds)
#
#    🕐 30 seconds remaining...
#    🕐 25 seconds remaining...
#    🕐 20 seconds remaining...
#    🕐 15 seconds remaining...
#    🕐 10 seconds remaining...
#    🕐 5 seconds remaining...
#
# 🧠 Memories should now be extracted and stored!
#    The agent has learned:
#    • Customer is 45 years old
#    • Prefers conservative, low-risk investments
#    • Planning for retirement in 20 years
#    • Wants 6-month emergency fund
#    • Income: ~$120,000, can invest $1,500/month

# %% [markdown]
# ---
#
# ## 🔄 Step 8: Test Memory Recall (Conversation 2)
#
# Now we'll start a **brand new conversation**. The agent should recall the customer's preferences from the memory store and provide personalized responses.

# %%
# Create a NEW conversation - testing memory recall
print("📞 Starting Conversation 2: Testing Memory Recall")
print("=" * 70)
print("🧠 This is a NEW conversation - the agent should remember preferences!")
print("=" * 70)

conversation2 = openai_client.conversations.create()
print(f"✅ New conversation created (ID: {conversation2.id})")

# Ask questions that should trigger memory recall
recall_messages = [
    "Hi, I spoke with someone earlier. Can you recommend some investment options for me?",
    "What about my emergency fund? How should I set that up?",
    "Given my situation, should I max out my 401k contributions?"
]

for msg in recall_messages:
    chat_with_agent(conversation2.id, msg, agent)
    print("\n" + "-" * 70)

print("\n" + "=" * 70)
print("✅ Conversation 2 Complete - Memory Recall Tested")
print("=" * 70)
print("\n🎯 Observe how the agent:")
print("   • Referenced the customer's conservative risk profile")
print("   • Remembered the retirement timeline (~20 years)")
print("   • Recalled the emergency fund preference (6 months)")
print("   • Considered the income and investment capacity")
# Out:
# 📞 Starting Conversation 2: Testing Memory Recall
# ======================================================================
# 🧠 This is a NEW conversation - the agent should remember preferences!
# ======================================================================
# ✅ New conversation created (ID: conv_688de5534ce97fa5000QvCpNDPmaCE8kQuAVUYAp4VprGFFPpr)
#
# 👤 Customer: Hi, I spoke with someone earlier. Can you recommend some investment options for me?
# ⏳ Agent thinking...
#
# 🤖 Advisor: Thank you for reaching out again! Based on our previous discussions, you're aiming to build an emergency fund of approximately $18,000 (six months of expenses) and prioritize conservative, low-risk investments for your retirement in 20 years. Here's an updated set of recommendations tailored to your goals:
#
# ---
#
# ### **1. Emergency Fund (Focus on Liquidity)**
# Since you’ve decided to allocate $800 per month to building your emergency fund, you’ll be able to reach your $18,000 goal in about 23 months. For now, I recommend the following options for storing your emergency fund with easy access and decent returns:
#
# - **High-Yield Savings Account:** Keep the majority of your emergency funds in a high-yield savings account offering competitive interest (currently around 4%-5% APY with some banks).
# - **Money Market Account:** For slightly higher interest rates, consider parking a portion of your savings in a money market account. These also offer liquidity and safety.
# - **Laddered Short-Term CDs:** Once you build a portion of your emergency fund, you might want to consider laddering short-term CDs (3-6 months) to earn slightly higher returns for funds you don't immediately need.
#
# Would you like help comparing high-yield savings accounts or CDs to find the best rates?
#
# ---
#
# ### **2. Retirement Investments (Conservative Approach)**
# With the remaining $700 per month, the focus should be on maximizing your retirement savings while staying aligned with your low-risk strategy. Here’s what I recommend:
#
# #### **a. Retirement Accounts**
# - **Employer 401(k):** Maximize any contributions that are matched by your employer, as this is essentially free money. Ensure your asset allocation within this account includes conservative funds like bond funds, stable value funds, or target-date funds (e.g., 2040 funds aligned with your retirement timeline).
# - **Roth IRA or Traditional IRA:** Depending on your tax situation, you might also contribute to a Roth IRA (post-tax contributions) or a Traditional IRA (pre-tax contributions). You can contribute up to $6,500 annually ($7,500 if you’re over 50).
#   *Do you qualify to contribute to a Roth IRA?* If you’d like, I can help you check.
#
# #### **b. Conservative Portfolio Allocation**
# You mentioned favoring low risk, so here’s a conservative portfolio allocation tailored to long-term retirement goals and your comfort level:
#
# - **40% Bonds:** Include U.S. Treasury bonds, municipal bonds, or high-quality corporate bonds, or invest via bond ETFs.
# - **30% Dividend-Paying Stocks/ETFs:** These provide a balance of low-risk capital growth and consistent returns.
# - **20% Cash Equivalents:** Include money market funds or other liquid investments for stability and capital preservation.
# - **10% Balanced/Target-Date Funds:** These funds automatically adjust their asset mix over time, aligning with your retirement horizon while prioritizing conservative options.
#
# Would you like specific fund or ETF suggestions for these categories?
#
# ---
#
# ### **3. Investment Options Outside of Retirement Accounts**
# If you find your retirement accounts are maxed out and you still have funds to invest, consider the following:
#
# - **Conservative ETFs or Mutual Funds:** Options like Vanguard Wellesley Income Fund (VWIAX) or Schwab Total Bond Market Index Fund (SWAGX) are designed for low-to-moderate risk investors.
# - **Laddered Bonds or CDs:** Diversify maturities and risk by purchasing bonds and/or CDs that mature over different timeframes.
# - **Robo-Advisors with Conservative Settings:** Platforms like Betterment or Wealthfront can structure a low-risk investment portfolio with minimal effort on your part.
#
# ---
#
# ### **Next Steps**
# 1. Would you like me to compare high-yield savings accounts or help set up your emergency fund?
# 2. Do you need help ensuring you’ve maxed out your employer 401(k) contributions or understanding IRA eligibility?
# 3. Should we narrow down some specific investments for your portfolio, like particular bonds, dividend stocks, or target-date funds?
#
# Let me know how you'd like to proceed!
#
# ----------------------------------------------------------------------
#
# 👤 Customer: What about my emergency fund? How should I set that up?
# ⏳ Agent thinking...
#
# 🤖 Advisor: To set up your emergency fund, let’s stick to your plan of saving $18,000 (six months of expenses) while prioritizing liquidity and safety. Here’s a clear step-by-step guide tailored to your situation:
#
# ---
#
# ### **1. Decide on the Structure**
# You’re allocating $800 per month to this goal, which is excellent. Based on that, you’ll reach your $18,000 goal in roughly **23 months**.
#
# Here’s how you can structure your emergency fund:
#
# **Immediate Access Funds:**
# - **$5,000–$8,000** in a **regular savings account or high-yield savings account.** This ensures you can quickly access money during an unexpected event, like a medical expense or job loss, without delays.
#
# **Short-Term Lock for Extra Returns:**
# - For the remaining amount, use **laddered short-term Certificates of Deposit (CDs):**
#   - A CD ladder means splitting funds into 3-month, 6-month, and 12-month CDs. As each matures, decide whether to reinvest into a new CD or keep it liquid.
#   - Current rates for short-term CDs are around **4%-5% APY**, better than typical savings accounts, while maintaining a high degree of safety.
#
# **Contingency Buffer:**
# - If you want, you could also keep around **$1,000** in a checking account as an immediate no-penalty buffer for emergencies.
#
# ---
#
# ### **2. Choose Where to Save**
#
# Here are a few options for the liquid portion and the CDs:
#
# #### **High-Yield Savings Accounts (APYs ~4%)**
# - **Ally Bank High Yield Savings Account**: No monthly fees, competitive rates, easy online banking access.
# - **Marcus by Goldman Sachs**: High APY with no fee, strict online-only access.
# - **Discover Online Savings Account**: High APY, no minimum balance requirement.
#
# #### **Money Market Account Options (APY ~4%-4.5%)**
# - **CIT Bank Money Market Account**: Offers competitive interest with checks or debit access.
# - **Capital One 360 Performance MMA**: No fees and no minimum opening deposit.
#
# #### **CDs for Short-Term Ladder (APYs ~4.5%-5.5%)**
# - **Ally Bank High-Yield CD**: 3-month, 6-month, or 12-month options with high flexibility and no penalty.
# - **Synchrony Bank CDs**: Competitive rates for short-term maturities, no monthly fees.
# - **Capital One 360 CDs**: No minimum balance, with a varied selection of term lengths.
#
# ---
#
# ### **3. Automate Savings**
# - Set up a **direct deposit or recurring transfer** for your goal. Allocate $800 monthly from your paycheck to your preferred savings account so the funds grow consistently.
#
# ---
#
# ### **4. Reassess Regularly**
# - Six months' worth of expenses may shift as your living costs increase. It’s good practice to reassess and adjust your savings every 1-2 years to ensure it matches your current needs.
#
# ---
#
# ### Next Steps
# 1. Would you like help finding the best high-yield savings or CD rates for your emergency fund? I can provide specific comparisons or walk you through account setup options.
# 2. Do you want to discuss whether splitting your emergency fund between accounts (savings and CDs) fits your preferences?
# 3. Is the $18,000 goal still accurate, or do we need to reassess your expenses?
#
# Let me know how you'd like to proceed!
#
# ----------------------------------------------------------------------
#
# 👤 Customer: Given my situation, should I max out my 401k contributions?
# ⏳ Agent thinking...
#
# 🤖 Advisor: Given your income ($120,000 annually), ability to invest $1,500 monthly, and conservative investment preferences, maxing out your 401(k) contributions could be a great choice, but there are a few key factors to consider given your current financial priorities:
#
# ---
#
# ### **1. Employer Match is the Top Priority**
# First, ensure you’re contributing enough to get the **full employer match** on your 401(k). Employer contributions are essentially “free money,” and not taking full advantage is leaving money on the table. For example, if your employer matches 50% of your contributions up to 6% of your salary, you’d want to contribute at least **6% of your $120,000 salary** ($7,200 annually, or $600 per month).
#
# Since we discussed allocating **$700 per month toward retirement**, the first $600 should go toward maximizing this match.
#
# ---
#
# ### **2. Consider the Annual Maximum Contribution Limit**
# For 2023, the 401(k) contribution limit is **$22,500** annually (or **$30,000** if you’re over 50). While maxing out your 401(k) is ideal, your current financial goals—like building an emergency fund ($18,000, with $800/month)—need to be balanced with your retirement goals. Since you're dividing $1,500 monthly across these priorities, fully maxing out your 401(k) might not align with your current cash flow.
#
# Instead, consider setting a middle-ground target, contributing about **$700/month** to your 401(k) for now, and increasing contributions toward your 401(k) after you’ve fully funded your emergency fund in 23 months.
#
# ---
#
# ### **3. Evaluate Tax Considerations**
# Maxing out your 401(k) allows you to lower your taxable income, so you’ll pay less in income tax today. For your income level, you may be in the **24% federal tax bracket**, meaning every dollar put into your 401(k) reduces your taxable income by 24 cents. However, because your employer 401(k) contributions are pre-tax, you will owe taxes when you withdraw funds in retirement.
#
# Alternatively, once you’ve gotten the maximum employer match, you could contribute additional funds to a **Roth IRA** (if you qualify). Contributions to a Roth are made with after-tax dollars, but your withdrawals in retirement will be tax-free.
#
# For 2023, the Roth IRA contribution limit is $6,500 (**$7,500 if you’re over 50**), but there are income caps to qualify. Since your salary is $120,000, you qualify if your modified adjusted gross income (MAGI) is less than $138,000. If you qualify, a Roth IRA could add balance to your tax diversification in retirement.
#
# ---
#
# ### **4. Diversify Outside the 401(k) Once You Max Out**
# Once you’ve maxed out your emergency fund and fully benefited from your employer’s 401(k) match, you might also consider opening a **taxable brokerage account** to invest in low-risk options like bonds and dividend-paying ETFs. This would allow more flexibility in terms of withdrawals before retirement.
#
# ---
#
# ### **Simplified Plan for Your Situation**
# Here’s what I recommend specifically for your situation considering your $1,500 per month to invest:
#
# 1. **Step One: Emergency Fund**
#    - Continue allocating **$800/month** to your emergency fund for the next ~23 months to meet your $18,000 goal.
#
# 2. **Step Two: 401(k) Contributions to Meet Employer Match**
#    - Allocate **$600/month** to your 401(k) to ensure you’re getting the full employer match.
#
# 3. **Step Three (After Emergency Fund is Fully Funded): Redirect Savings to Retirement**
#    - Once your emergency fund is complete, redirect the freed-up $800/month to either max out your 401(k) or contribute to a Roth IRA (if you qualify) or a Traditional IRA.
#    - Use a mix of retirement accounts and other investment options like taxable accounts for further diversification.
#
# ---
#
# ### **Final Thoughts**
# While maxing out your 401(k) is an excellent goal, at the moment, splitting your contributions ensures that you’re achieving both short-term security (emergency fund) and long-term growth (retirement).
#
# To adjust this strategy or explore options in more detail:
# 1. Would you like help calculating your potential employer match or reviewing your 401(k) plan options?
# 2. Do you know if you’re eligible for a Roth IRA or need to check eligibility?
# 3. Should I suggest investment options to align with your long-term retirement objectives?
#
# Let me know how I can assist further!
#
# ----------------------------------------------------------------------
#
# ======================================================================
# ✅ Conversation 2 Complete - Memory Recall Tested
# ======================================================================
#
# 🎯 Observe how the agent:
#    • Referenced the customer's conservative risk profile
#    • Remembered the retirement timeline (~20 years)
#    • Recalled the emergency fund preference (6 months)
#    • Considered the income and investment capacity

# %% [markdown]
# ---
#
# ## 🔄 Step 9: Update Preferences (Conversation 3)
#
# Customers' preferences can change over time. Let's test how the agent handles updated preferences.

# %%
# Create conversation to update preferences
print("📞 Starting Conversation 3: Updating Customer Preferences")
print("=" * 70)

conversation3 = openai_client.conversations.create()
print(f"✅ Conversation created (ID: {conversation3.id})")

# Customer updates their preferences
update_messages = [
    "I've been thinking, and I'd like to be a bit more aggressive with my investments. I can handle moderate risk now.",
    "I also got a raise! My income is now $140,000 and I can invest $2,000 per month."
]

for msg in update_messages:
    chat_with_agent(conversation3.id, msg, agent)
    print("\n" + "-" * 70)

print("\n" + "=" * 70)
print("✅ Conversation 3 Complete - Preferences Updated")
print("=" * 70)

# Wait for new memories to be stored
print("\n⏳ Waiting for updated memories to be stored (15 seconds)...")
time.sleep(15)
print("✅ Updated memories should be stored!")
# Out:
# 📞 Starting Conversation 3: Updating Customer Preferences
# ======================================================================
# ✅ Conversation created (ID: conv_a67d1f01b083b37800J8TEgkIBMqQkYhecXRV9Z8s6E32PGG5u)
#
# 👤 Customer: I've been thinking, and I'd like to be a bit more aggressive with my investments. I can handle moderate risk now.
# ⏳ Agent thinking...
#
# 🤖 Advisor: It's great to hear that you're ready to take on a bit more risk for potential higher returns! Shifting to a moderate-risk approach while still remaining thoughtful about your goals is a sound move. Let’s adjust your financial strategy accordingly.
#
# ### Emergency Fund (Ongoing Plan)
# Your progress here remains critical, so we’ll keep your current plan of saving $800/month to reach your $18,000 goal over the next 23 months. Since you’re already considering high-yield savings accounts and laddered CDs, you may want to look at some higher-yield CD options with slightly longer terms (e.g., 18-24 months) to complement your more aggressive investment strategy elsewhere. You can reserve about $5,000–$7,000 of this fund in a high-yield savings account for liquidity while maximizing CD yields on the rest of the emergency fund.
#
# ### Retirement Savings (Adjusting for Moderate Risk)
# Currently, you’re contributing $700/month toward retirement with a conservative allocation of 40% bonds, 30% dividend-paying stocks, 20% cash equivalents, and 10% target-date or balanced funds. If you’re open to taking on moderate risk, you could shift to a more growth-oriented allocation while still staying within a moderate risk profile.
#
# Here’s a potential revamped allocation to align with a moderate approach:
# - **30% bonds and fixed income:** Opt for a mix of intermediate-term and corporate bonds (e.g., Vanguard Total Bond Market ETF [BND]).
# - **40% in growth equities or ETFs:** Increase the allocation to U.S. and international stock markets through ETFs like Vanguard Total Stock Market ETF (VTI) and the Vanguard FTSE Developed Markets ETF (VEA).
# - **20% dividend-paying stocks/ETFs:** Focus on reliable, income-generating assets like the Vanguard Dividend Appreciation ETF (VIG) or Schwab U.S. Dividend Equity ETF (SCHD).
# - **10% balanced/target-date funds or alternative investments:** Funds like Vanguard Target Retirement 2045 or Fidelity Freedom Index 2045 can help maintain diversification.
#
# Since you’re planning for retirement about 20 years from now, this slight pivot towards riskier investments could give your portfolio more growth potential while still incorporating conservative elements like bonds and dividend payers.
#
# ### Broader Investment Opportunities
# Since you have approximately $1,500/month allocated toward savings and investments—with $700 for retirement and $800 for the emergency fund—you can continue that until your emergency fund is fully funded (in 23 months). After that, you may want to use the $800 for additional investments. Some moderate-risk options include:
#
# - **Index Funds/ETFs:** Look into funds like the S&P 500 index funds or a total stock market index, which are known for providing diversification and solid long-term returns.
# - **Actively Managed Funds:** Now that your risk tolerance has shifted slightly, you may explore actively managed funds that target higher growth, such as ARK funds or Fidelity’s growth-oriented mutual funds (e.g., Fidelity Contrafund).
# - **REITs (Real Estate Investment Trusts):** REITs can provide exposure to real estate without the need to own physical property, with funds like Vanguard Real Estate ETF (VNQ) offering a moderate-risk way to grow wealth over time.
#
# ### Key Steps Moving Forward
# 1. **Max Out Tax-Advantaged Accounts:** Continue contributing to your employer’s 401(k), ensuring you take full advantage of any employer matches. Additionally, you can consider a Roth IRA or Traditional IRA (if eligible) to increase tax-advantaged retirement savings.
#    - The current (2023) annual IRA contribution limit is $6,500 ($7,500 if over age 50).
# 2. **Consider Automated Robo-Advisors:** Since you’ve expressed interest in them, platforms like Betterment or Wealthfront can be customized for moderate-risk portfolios. They’re cost-effective and useful if you prefer hands-off investing.
# 3. **Track Asset Allocation Regularly:** As your investments grow, your portfolio will naturally shift. Rebalancing annually can help ensure you stick to your new risk profile.
#
# ### Reminder: Consider a Financial Advisor
# Since moderate risk is a new approach for you compared to your previous conservative strategy, it might be worth consulting with a financial advisor to review this adjusted allocation and ensure it’s in line with your long-term goals. They can provide personalized advice tailored to your unique circumstances.
#
# How does this plan sound to you? Would you like recommendations for specific funds or additional information about robo-advisors?
#
# ----------------------------------------------------------------------
#
# 👤 Customer: I also got a raise! My income is now $140,000 and I can invest $2,000 per month.
# ⏳ Agent thinking...
#
# 🤖 Advisor: Congratulations on the raise! Increasing your income to $140,000 gives you more flexibility to accelerate your financial goals and explore new investment opportunities. Based on your updated ability to invest $2,000 per month, here’s how we can revise your plan:
#
# ---
#
# ### 1. **Emergency Fund Update**
# Since you’re still working on building your $18,000 emergency fund and previously allocated $800/month to this goal, we can consider increasing that allocation to $1,000–$1,200 per month. At this rate:
# - **$1,000/month**: You’ll finish your emergency fund in 13 months (cutting your time goal nearly in half).
# - **$1,200/month**: Fully funded in about **10-11 months**, giving you the freedom to redirect those funds towards investments sooner.
#
# You can continue to prioritize liquid investments like:
# - **High-Yield Savings Accounts**: For immediate access to a portion of the funds.
# - **Short-Term CDs**: Consider 6-12 month CDs with competitive APYs for funds you aren’t immediately reliant on.
#
# Would you prefer to accelerate your emergency fund contributions to free up cash flow sooner, or keep them at $800/month?
#
# ---
#
# ### 2. **Retirement Savings Plan**
# With $700/month previously earmarked for retirement, your higher income means you can comfortably increase this amount. I recommend boosting it to **$1,000–$1,200/month**, depending on whether you'd like to keep additional funds for other goals and investments.
#
# #### Steps to Maximize Tax-Advantaged Retirement Savings:
# 1. **Maximize 401(k)**:
#    - The 2023 contribution limit for 401(k)s is **$22,500** per year (or $30,000 if you're 50+). With a $140,000 salary, it’s worth increasing your contributions to take advantage of tax-deferred savings and any employer matches.
#    - If you contribute $1,200/month, you’d save $14,400/year—well within the limit.
#
# 2. **Contribute to an IRA**:
#    - You can contribute up to **$6,500** annually (or $7,500 for those 50+). With your income, ensure you meet eligibility for a **Roth IRA** (phaseout for contributions: $138,000–$153,000 single or $218,000–$228,000 married filing jointly). If your income exceeds Roth limits, consider a **Backdoor Roth** contribution or a **Traditional IRA**.
#
# 3. **Revised Moderate-Risk Allocations**:
#    Since you mentioned you’re open to a moderate-risk portfolio now, here’s an updated retirement allocation:
#    - **25% Bonds/Fixed Income**: Keep this portion to moderate risk but consider adding corporate bonds or international bond ETFs (e.g., iShares Core Global Aggregate Bond ETF [IAGG]).
#    - **50% Stock ETFs/Index Funds**: More focus on equities for growth.
#      - U.S. Total Stock Market ETF (VTI)
#      - International ETFs for diversification (VEA or VXUS)
#    - **15% Dividend-Paying Funds**: These provide a mix of growth and income. Keep using ETFs like Vanguard Dividend Appreciation ETF (VIG) and Schwab U.S. Dividend Equity ETF (SCHD).
#    - **10% Alternatives**: Consider REITs, managed funds, or emerging markets for further diversification.
#
# ---
#
# ### 3. **Additional Investments**
# Once your emergency fund is fully funded (in 10–13 months or as you prefer), you could redirect the additional $800+ towards moderate-risk investments. Here are some suggestions:
#
# #### A. **Tax-Efficient Brokerage Account Investments**
#    Use the extra cash to invest in:
#    - **Index Funds/ETFs**: Continue with S&P 500 or Total Market funds for growth. Options include:
#      - Fidelity ZERO Total Market Index Fund (FZROX) or Vanguard Total Stock Market ETF (VTI)
#    - **Sector-Focused ETFs**: Allocate 5–10% into growth sectors like technology or healthcare.
#      - Example: Invesco QQQ Trust (QQQ) for Nasdaq-100 exposure.
#    - **International Market Exposure**: Balance your portfolio with funds like the Vanguard FTSE Emerging Markets ETF (VWO).
#
# #### B. **Robo-Advisors**
#    Platforms like Betterment or Wealthfront, as we discussed previously, can help you automate investments with a moderate-risk strategy. Set a monthly deposit and let the platform maintain your target allocations.
#
# #### C. **Real Estate Crowdfunding or REITs**
#    With your improved cash flow, consider **Real Estate Investment Trusts (REITs)** for moderate-risk exposure to real estate, which can diversify your portfolio:
#    - Publicly traded REITs like Vanguard Real Estate ETF (VNQ) or Fidelity Real Estate Investment ETF (FREL).
#    - Crowdfunding platforms like Fundrise or RealtyMogul for more direct real estate exposure.
#
# #### D. **Taxable Brokerage Savings for Future Goals**
#    If you’d like to save for medium-term goals, put some funds into a taxable brokerage account:
#    - Moderate risk can be managed with a 60% equities/40% bonds split.
#    - Favor tax-efficient investments like ETFs or index funds to minimize taxes on dividends and capital gains.
#
# ---
#
# ### 4. **Budget Adjustment with Increased Income**
# Let’s also consider how the additional income fits into your budget and goals. Based on your previous annual income of $120,000 and now earning $140,000:
# - Your after-tax income will depend on your filing status and deductions, but at $140,000 your approximate monthly take-home pay (post-tax) is now **$8,100–$8,800** (depending on deductions).
# - Subtracting your $2,000/month investment plan (emergency fund and retirement), you still have significant disposable income remaining.
#
# #### Options for Extra Income After Investments:
# - **High-Interest Debt Payoff**: If you have any remaining debts (e.g., credit card balances), this new income could clear them off faster.
# - **Increased Retirement Contributions**: You could gradually increase contributions to max out retirement accounts.
# - **Vacation Fund or Discretionary Goals**: Redirect some funds to short-term savings for future travel or lifestyle upgrades.
# - **Education or Certifications:** Consider using your raise to fund professional growth or personal skill-building.
#
# ---
#
# ### 5. **Next Steps and Action Items**
# 1. **Accelerate Emergency Fund:** Confirm if you’d like to increase contributions to $1,000–$1,200/month to shorten your savings time.
# 2. **Adjust Retirement Contributions:** Increase 401(k) contributions and/or set up a Roth IRA or Traditional IRA if you haven’t already.
# 3. **Rebalance Portfolio:** Shift toward a more moderate risk profile for retirement investments. I can suggest additional funds if needed.
# 4. **Plan for Extra Income:** Decide how you’d like to allocate the additional ~$6,000 annually after maxing your investments.
#
# How does this revised plan sound? Would you like to dive deeper into any particular area, such as fund recommendations, robo-advisors, or tax strategy optimization? Let me know!
#
# ----------------------------------------------------------------------
#
# ======================================================================
# ✅ Conversation 3 Complete - Preferences Updated
# ======================================================================
#
# ⏳ Waiting for updated memories to be stored (15 seconds)...
# ✅ Updated memories should be stored!

# %% [markdown]
# ---
#
# ## 🧪 Step 10: Verify Updated Memory (Conversation 4)
#
# Let's verify that the agent remembers the **updated** preferences.

# %%
# Create final conversation to verify updated memories
print("📞 Starting Conversation 4: Verifying Updated Preferences")
print("=" * 70)
print("🧠 The agent should now remember the UPDATED preferences!")
print("=" * 70)

conversation4 = openai_client.conversations.create()
print(f"✅ Conversation created (ID: {conversation4.id})")

# Ask about investment recommendations with updated profile
verify_message = "Based on everything you know about me, what's your top investment recommendation right now?"

chat_with_agent(conversation4.id, verify_message, agent)

print("\n" + "=" * 70)
print("✅ Memory Verification Complete")
print("=" * 70)
print("\n🎯 The agent should have referenced:")
print("   • Updated risk tolerance: moderate (not conservative)")
print("   • Updated income: $140,000 (not $120,000)")
print("   • Updated investment capacity: $2,000/month (not $1,500)")

# %% [markdown]
# ---
#
# ## 🧹 Step 11: Cleanup Resources
#
# Delete all created resources to clean up.

# %%
# Cleanup resources
print("🧹 Cleaning up resources...")
print("=" * 60)

# Delete conversations
conversations_to_delete = [conversation1, conversation2, conversation3, conversation4]
for i, conv in enumerate(conversations_to_delete, 1):
    try:
        openai_client.conversations.delete(conv.id)
        print(f"✅ Deleted conversation {i}: {conv.id}")
    except Exception as e:
        print(f"⚠️ Could not delete conversation {i}: {e}")

# Delete agent
try:
    project_client.agents.delete_version(
        agent_name=agent.name,
        agent_version=agent.version
    )
    print(f"✅ Deleted agent: {agent.name} (v{agent.version})")
except Exception as e:
    print(f"⚠️ Could not delete agent: {e}")

# Delete memory store
try:
    project_client.beta.memory_stores.delete(memory_store.name)
    print(f"✅ Deleted memory store: {memory_store.name}")
except Exception as e:
    print(f"⚠️ Could not delete memory store: {e}")

print("\n" + "=" * 60)
print("🎉 Cleanup complete!")

# %% [markdown]
# ---
#
# ## 📚 Summary
#
# In this notebook, you learned how to build a **memory-enabled banking assistant** that provides personalized financial guidance by remembering customer preferences.
#
# ### What You Built
#
# | Component | Description |
# |-----------|-------------|
# | **Memory Store** | Persistent storage for customer preferences and conversation summaries |
# | **Memory Search Tool** | Agent tool that retrieves and updates memories |
# | **Banking Agent** | AI assistant that uses memories for personalization |
#
# ### Key Concepts Demonstrated
#
# 1. **Memory Extraction** - Automatically extract preferences from conversations
# 2. **Memory Recall** - Retrieve relevant memories in new conversations
# 3. **Memory Updates** - Handle changing customer preferences over time
# 4. **Scoped Memories** - Isolate memories per customer for privacy
#
# ### Industry Use Cases for Agent Memory
#
# | Use Case | Memory Benefit |
# |----------|----------------|
# | **Wealth Management** | Remember risk tolerance, investment preferences, financial goals |
# | **Customer Service** | Recall past issues, preferred communication channels, account history |
# | **Loan Processing** | Remember document submissions, employment history, property details |
# | **Insurance** | Recall policy preferences, claims history, coverage requirements |
# | **Fraud Detection** | Remember customer behavior patterns, typical transaction types |
#
# ### Production Considerations
#
# | Consideration | Recommendation |
# |---------------|----------------|
# | **Update Delay** | Set to 300+ seconds (5 min) to avoid extraction during active conversations |
# | **Scope Strategy** | Use customer IDs or `{{$userId}}` for automatic user isolation |
# | **Memory Retention** | Consider data retention policies and GDPR compliance |
# | **Sensitive Data** | Avoid storing PII or sensitive financial data in memories |
#
# ---
#
# **🎉 Congratulations!** You've successfully built a personalized banking assistant with memory capabilities!
#
# *Note: This is for educational purposes. Production deployments require proper error handling, security, and compliance features.*
