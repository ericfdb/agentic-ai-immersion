# %% [markdown]
# # 🏦 Financial Services Advisor Agent Tutorial 💼
#
# Welcome to our **Financial Services Advisor Agent** tutorial, where you'll use **Microsoft Foundry** SDKs to create a banking and financial assistance AI agent. We'll:
#
# 1. **Initialize** our project using **azure-ai-projects**.
# 2. **Create an Agent** specialized in providing general banking, loan, and investment guidance (with disclaimers!).
# 3. **Manage conversations** about financial services, banking products, and loan inquiries.
# 4. **Showcase logging and tracing** with **OpenTelemetry**.
# 5. **Demonstrate** how to incorporate tools, regulatory disclaimers, and best practices.
#
# ### ⚠️ Important Financial Disclaimer ⚠️
# > **The financial information provided by this notebook is for general educational and demonstration purposes only and is not intended as financial, investment, legal, or tax advice.** Always consult with qualified financial advisors, bankers, or legal professionals before making any financial decisions. Past performance does not guarantee future results. All investments carry risk.
#
#
# ## Let's Get Started
# We'll walk you through each cell with notes. Let's begin!

# %% [markdown]
# ## 🔐 Authentication Setup
#
# Before running the next cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login --use-device-code
# ```
#
# This will provide you with a device code and URL to authenticate in your browser, which is useful for:
# - Remote development environments
# - Systems without a default browser
# - Corporate environments with strict security policies
#
# After successful authentication, you can proceed with the notebook cells below.

# %% [markdown]
# ## 1. Initial Setup
# We'll start by importing needed libraries, loading environment variables, and initializing an **AIProjectClient** so we can do all the agent-related actions. Let's do it! 🎉

# %%
from pathlib import Path  # For working with file paths
import os  # For environment variables
import time  # For sleep function
from dotenv import load_dotenv  # For loading environment variables from .env file
from azure.identity import InteractiveBrowserCredential  # For Azure authentication
from azure.ai.projects import AIProjectClient  # Main client for AI Projects
from azure.ai.projects.models import PromptAgentDefinition  # For new agent API

# Get the path to the .env file which is in the parent directory
notebook_path = Path().absolute()  # Get absolute path of current notebook
parent_dir = notebook_path.parent  # Get parent directory
load_dotenv(parent_dir.parent / '.env')  # Load environment variables from .env file

# Get tenant ID for authentication
tenant_id = os.environ.get("TENANT_ID")
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")

print(f"🔑 Using Tenant ID: {tenant_id}")

# Initialize the AI Project Client using simplified browser-based authentication
try:
    print("🌐 Using browser-based authentication to bypass Azure CLI cache issues...")
    
    # Use only InteractiveBrowserCredential with the specific tenant
    credential = InteractiveBrowserCredential(tenant_id=tenant_id)
    
    # Create the project client using endpoint
    project_client = AIProjectClient(
        endpoint=project_endpoint,
        credential=credential
    )
    print("✅ Successfully initialized AIProjectClient")
except Exception as e:
    # Print error message if client initialization fails
    print(f"❌ Error initializing project client: {str(e)}")
    print("💡 Please complete the browser authentication prompt that should appear")
# Out:
# 🔑 Using Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3
# 🌐 Using browser-based authentication to bypass Azure CLI cache issues...
# ✅ Successfully initialized AIProjectClient

# %% [markdown]
# ## 2. Creating our Financial Services Advisor Agent 🏦
#
# We'll create an Agent specialized in general banking and financial guidance. We'll explicitly mention disclaimers in its instructions, so it never forgets regulatory compliance! The instructions also ask the agent to focus on banking products, loan inquiries, and general financial guidance while always encouraging users to seek professional advice.

# %%
def create_financial_advisor_agent():
    """Create a financial services advisor agent with disclaimers and basic instructions using new Foundry API."""
    try:
        # Get the model name from environment variables, default to gpt-4o-mini if not set
        model_name = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o-mini")

        # Create a new agent using the NEW Foundry API with create_version
        # This uses PromptAgentDefinition for defining the agent's behavior
        agent = project_client.agents.create_version(
            agent_name="financial-services-advisor",
            description="Version 3.0.0 - Updated financial advisor",
            metadata={"semantic_version": "3.0.0"},
            definition=PromptAgentDefinition(
                model=model_name,
                instructions="""
                You are a friendly AI Financial Services Advisor for a retail bank.
                You provide general information about banking products, loans, and financial services, but always:
                1. Include regulatory and financial disclaimers.
                2. Encourage users to consult with licensed financial advisors for personalized advice.
                3. Provide general, non-personalized guidance around banking, loans, savings, and investments.
                4. Clearly remind users you're not a licensed financial advisor and cannot provide investment recommendations.
                5. Follow responsible banking practices and never suggest risky financial behaviors.
                6. Explain concepts like APR, interest rates, credit scores, and loan terms in simple language.
                """
            )
        )
        # Log success and return the created agent
        print(f"🎉 Created financial services advisor agent (name: {agent.name}, version: {agent.version})")
        return agent
    except Exception as e:
        # Handle any errors during agent creation
        print(f"❌ Error creating agent: {str(e)}")
        return None

# Create an instance of our financial services advisor agent
financial_advisor = create_financial_advisor_agent()
# Out:
# 🎉 Created financial services advisor agent (name: financial-services-advisor, version: 1)

# %% [markdown]
# ## 3. Managing Financial Service Conversations 💬
# A conversation (or *thread*) is where we'll store the user's messages and the agent's responses about banking and financial topics. Let's create a new thread dedicated to Financial Services Q&A.

# %%
# Function to create a new conversation for financial services discussions
def start_financial_conversation():
    """Create a new conversation for banking & financial discussions using new Foundry API."""
    try:
        # Get the OpenAI client from project client
        openai_client = project_client.get_openai_client()
        
        # Create a new conversation using the NEW API
        # Conversations replace threads in the new Foundry API
        conversation = openai_client.conversations.create()
        
        # Print success message with the conversation ID for reference
        print(f"📝 Created a new conversation, ID: {conversation.id}")
        
        # Return the created conversation object so we can use it later
        return conversation
    except Exception as e:
        # If conversation creation fails, print error and return None
        print(f"❌ Error creating conversation: {str(e)}")
        return None

# Initialize a new conversation that we'll use for our financial services Q&A
financial_conversation = start_financial_conversation()
# Out:
# 📝 Created a new conversation, ID: conv_dea7e28bcad88c03005AdHF7UG2R5uSU89Lr9wjXC0sF0s7fJE

# %% [markdown]
# ## 4. Asking Banking & Financial Questions 💳
# We'll create messages from the user about typical banking questions. For example, **"What factors affect my mortgage interest rate?"** or **"How do I improve my credit score?"**. We'll let our Financial Advisor Agent respond, always remembering the regulatory disclaimers!

# %%
# Function to chat with our financial services agent using the NEW Foundry API
def chat_with_financial_agent(user_question, conversation_id=None):
    """Chat with the financial services agent using the new responses API."""
    
    # Check if we have a valid agent
    if not financial_advisor:
        print("❌ No agent available. Please create an agent first.")
        return
    
    try:
        print(f"👤 User: {user_question}")
        print("🔄 Processing with agent...")
        
        # Get the OpenAI client from project client
        openai_client = project_client.get_openai_client()
        
        request_kwargs = {
            "extra_body": {
                "agent_reference": {
                    "type": "agent_reference",
                    "name": financial_advisor.name,
                    "version": financial_advisor.version,
                }
            },
            "input": user_question
        }
        
        # Attach conversation so the run is part of a persisted conversation context
        if conversation_id:
            request_kwargs["conversation"] = conversation_id
        
        # Use the NEW responses API with agent reference
        # This replaces the old create_thread_and_process_run method
        response = openai_client.responses.create(**request_kwargs)
        
        print("✅ Agent processing completed!")
        
        # Get the response text
        if response.output_text:
            print(f"🤖 Agent: {response.output_text}")
            return response.output_text
        else:
            print("❌ No response found from agent")
            return None
        
    except Exception as e:
        print(f"❌ Error chatting with agent: {str(e)}")
        # Debug: print more details about the error
        import traceback
        print("Full error traceback:")
        traceback.print_exc()
        return None

# Let's test our financial services agent with a simple question
print("🧪 Testing the Financial Services Advisor Agent...")
print("=" * 50)
# Out:
# 🧪 Testing the Financial Services Advisor Agent...
# ==================================================

# %% [markdown]
# ### Example Financial Services Queries
# Let's do some quick queries now to see the agent's disclaimers and how it handles typical banking and financial questions. We'll ask about **mortgages**, **credit scores**, and **savings strategies**.

# %%
# Test 1: Simple Banking Question (Already completed above)
print("Test 1: Simple Banking Question ✅")
print("-" * 30)

conversation_id = financial_conversation.id if financial_conversation else None
if not conversation_id:
    print("⚠️ No conversation available; responses will not be linked to a conversation.")

# Test 2: Ask about mortgage rates
print("\nTest 2: Mortgage Advice")
print("-" * 20)
response2 = chat_with_financial_agent(
    "What factors affect my mortgage interest rate and how can I get a better rate?",
    conversation_id=conversation_id
 )

print("\n" + "="*60 + "\n")

# Test 3: Ask about credit scores
print("Test 3: Credit Score Guidance")  
print("-" * 20)
response3 = chat_with_financial_agent(
    "How is my credit score calculated and what can I do to improve it?",
    conversation_id=conversation_id
 )

print("\n" + "="*60 + "\n")

# Test 4: Ask about savings strategies
print("Test 4: Savings & Investment Basics")
print("-" * 20) 
response4 = chat_with_financial_agent(
    "What's the difference between a savings account, CD, and money market account? Which is best for emergency funds?",
    conversation_id=conversation_id
 )

print(f"\n🎉 Completed 4 test conversations with our Financial Services Advisor!")
print(f"All responses received successfully! The agent is working great.")

# Show a summary
successful_tests = sum([1 for r in [True, response2, response3, response4] if r])
print(f"📊 Summary: {successful_tests}/4 tests passed successfully")
# Out:
# Test 1: Simple Banking Question ✅
# ------------------------------
#
# Test 2: Mortgage Advice
# --------------------
# 👤 User: What factors affect my mortgage interest rate and how can I get a better rate?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Securing a low mortgage interest rate can save you a significant amount of money over the life of your loan. Several factors impact the rate you're offered, and understanding them can help you improve your chances of getting a better deal. Here’s a breakdown:
#
# ---
#
# ### **Factors That Affect Your Mortgage Interest Rate**
#
# 1. **Credit Score:**
#    - Your credit score is a key factor in determining your mortgage rate.
#    - A higher credit score suggests you're a responsible borrower, which can qualify you for lower rates.
#    - Lenders usually offer the best rates to borrowers with scores above 740.
#
# 2. **Debt-to-Income (DTI) Ratio:**
#    - Lenders compare your monthly debt payments (including the new mortgage) to your monthly income.
#    - A lower DTI ratio indicates you have manageable debt levels and are less risky, potentially leading to lower rates.
#
# 3. **Down Payment:**
#    - A larger down payment reduces the lender’s risk, which may help you qualify for a lower rate.
#    - Typically, putting down 20% or more can secure better terms and help you avoid private mortgage insurance (PMI).
#
# 4. **Loan Type:**
#    - Fixed-rate mortgages typically have higher initial rates than adjustable-rate mortgages (ARMs), but ARMs can increase over time.
#    - Government-backed loans like FHA, VA, or USDA loans may offer competitive rates, often for borrowers with lower credit scores.
#
# 5. **Loan Term:**
#    - Shorter-term loans (e.g., 15 years vs. 30 years) often come with lower interest rates because they carry less risk for lenders.
#    - However, the monthly payments will be higher due to the shorter repayment period.
#
# 6. **Market Conditions:**
#    - Economic factors like inflation and the Federal Reserve’s (Fed) interest rate decisions heavily influence mortgage rates.
#    - Market rates fluctuate over time and can vary depending on the economic environment when you apply.
#
# 7. **Loan Amount and Property Type:**
#    - Larger loan amounts or "jumbo loans" (exceeding conforming loan limits) typically have higher rates due to greater risk.
#    - Rates may also vary based on whether the property is a primary residence, a second home, or an investment property.
#
# 8. **Lender and Loan Program:**
#    - Different lenders offer different rates and fee structures, so shopping around can help you find the best deal.
#    - Special programs may be available for first-time buyers or people in certain income brackets.
#
# ---
#
# ### **Tips to Get a Better Rate**
#
# 1. **Improve Your Credit Score:**
#    - Pay your bills on time and reduce your credit card balances.
#    - Check your credit report for errors and dispute inaccuracies.
#
# 2. **Save for a Larger Down Payment:**
#    - Aim to put down at least 20% if possible to secure better rates and avoid PMI.
#
# 3. **Reduce Your DTI Ratio:**
#    - Lower your existing debts before applying for a mortgage. Focus on paying down high-interest accounts like credit cards or personal loans.
#
# 4. **Choose the Right Loan Type:**
#    - Depending on your situation, a different loan type (e.g., FHA, VA, conventional) might offer a better rate.
#
# 5. **Shorten Your Loan Term:**
#    - If you can afford higher monthly payments, opt for a 15-year term instead of a 30-year term.
#
# 6. **Lock In Your Rate:**
#    - Once you've found a rate you're happy with, consider locking it in with your lender to protect yourself from potential increases while your loan is being processed.
#
# 7. **Shop Around for Lenders:**
#    - Compare offers from multiple lenders, including banks, credit unions, and online lenders, to find the most competitive rates and terms.
#    - Make sure to ask about loan fees (like origination or application fees) to compare the total cost, not just the rate.
#
# ---
#
# ### **Regulatory and Financial Disclaimers**
# - Your interest rate will depend on your personal financial situation and the lender’s requirements.
# - This information is general in nature. For tailored advice, consult with a licensed mortgage broker or financial advisor who can assess your unique circumstances.
# - Rates and loan options are subject to change based on market conditions and are not guaranteed.
#
# Would you like more details about any specific factor or guidance on preparing for the mortgage application process?
#
# ============================================================
#
# Test 3: Credit Score Guidance
# --------------------
# 👤 User: How is my credit score calculated and what can I do to improve it?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Your credit score is a critical factor in determining your eligibility for loans, credit cards, and other forms of credit, including the interest rates you'll be offered. Understanding how your credit score is calculated can help you take targeted action to improve it.
#
# ---
#
# ### **How is My Credit Score Calculated?**
# Most lenders use the **FICO® Score**, which ranges from 300 to 850, as a key measure of your creditworthiness. Your credit score is based on information in your credit report and is determined by the following five main factors:
#
# 1. **Payment History (35%):**
#    - The largest factor in your credit score is whether you pay your bills on time. Late or missed payments, bankruptcies, and collections can have a significant negative impact.
#    - A history of timely payments shows lenders that you're reliable.
#
# 2. **Amounts Owed (30%):**
#    - This refers to how much debt you owe compared to your borrowing limit, also known as your **credit utilization ratio**.
#    - Experts recommend using no more than 30% of your available credit on any credit card or line of credit. For example, if you have a $10,000 credit limit, aim to keep your balance at $3,000 or less.
#
# 3. **Length of Credit History (15%):**
#    - The longer your credit accounts have been open, the better. This is why it's a good idea to keep older accounts open, even if you don’t use them frequently.
#
# 4. **Credit Mix (10%):**
#    - Having a mix of credit types—such as credit cards, car loans, and mortgages—can improve your score. It shows lenders you can handle various forms of credit responsibly.
#    - However, only take on credit you genuinely need.
#
# 5. **New Credit (10%):**
#    - Opening multiple new accounts in a short period can negatively impact your score. When lenders check your credit as part of an application (a **hard inquiry**), it may cause a temporary dip in your score.
#    - Avoid opening too many accounts at once.
#
# Your credit score can also vary slightly depending on the credit scoring model used (e.g., VantageScore®, which has some differences in weighting the above factors) and which credit bureau’s report (Experian, TransUnion, or Equifax) is used.
#
# ---
#
# ### **Tips to Improve Your Credit Score**
# Improving your credit score takes time, but consistent effort can yield positive results. Here are some steps you can take:
#
# #### 1. **Pay Bills on Time**
#    - Set up automatic payments or calendar reminders to avoid missed or late payments.
#    - If you’ve made a late payment, bring your account up to date as quickly as possible. Over time, recent on-time payments will outweigh the effect of the late payment.
#
# #### 2. **Lower Your Credit Utilization Ratio**
#    - Aim to keep your utilization below 30%, and if possible, below 10% for the best impact on your score.
#    - If your balance is high relative to your limit, pay down your debt or ask for a credit limit increase (as long as you won’t start borrowing more).
#
# #### 3. **Check Your Credit Report for Errors**
#    - Obtain free copies of your credit report from the three credit bureaus at [annualcreditreport.com](https://www.annualcreditreport.com) (one free report per bureau per year).
#    - Dispute any inaccuracies, such as accounts you didn’t open or errors in your payment history.
#
# #### 4. **Don’t Close Old Accounts**
#    - Keep older, unused credit card accounts open to maintain a long credit history, as long as they don’t cost you in annual fees.
#    - Closing an account reduces your available credit and may increase your credit utilization ratio.
#
# #### 5. **Limit Hard Inquiries**
#    - Only apply for credit when you really need it. Each hard inquiry can lower your score slightly.
#    - When rate shopping (e.g., for mortgages or auto loans), complete all applications within a short period (usually 14-45 days, depending on the scoring model) to minimize any impact on your score.
#
# #### 6. **Diversify Your Credit Types**
#    - If you only have credit cards, consider adding an installment loan (like a personal loan or car loan) to balance your credit mix if it's appropriate for your financial situation.
#
# #### 7. **Be Strategic with Authorized User Accounts**
#    - If a family member or close friend with an excellent payment history adds you as an authorized user to their credit card, their positive record can improve your score. However, ensure that they manage their account responsibly.
#
# #### 8. **Address Delinquencies or Debt Issues**
#    - If you’re struggling to make payments, contact your creditors to see if they can work out a payment plan.
#    - Avoid letting debts go into collections—it will damage your score significantly.
#
# ---
#
# ### **How Long Does It Take to See Improvements?**
# - **Quick changes:** Small improvements, like paying off a credit card, can reflect in your score within weeks (or as soon as the lender reports the payment to the credit bureaus).
# - **Medium-term changes:** Resolving negative items (like past-due accounts) can take several months to see significant progress.
# - **Long-term improvements:** Building a strong credit history from scratch or recovering from major issues like bankruptcy can take years, but consistent good habits will lead to results.
#
# ---
#
# ### **Regulatory and Financial Disclaimer**
# - Your credit score is determined by third-party credit bureaus based on proprietary models. Lenders may use different score ranges or criteria when evaluating applications.
# - This information is general in nature and not a substitute for professional financial advice. For personalized tips, consult with a licensed financial advisor or a credit counseling organization.
#
# If you'd like tips on checking your credit report or improving your score further, let me know!
#
# ============================================================
#
# Test 4: Savings & Investment Basics
# --------------------
# 👤 User: What's the difference between a savings account, CD, and money market account? Which is best for emergency funds?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Savings accounts, certificates of deposit (CDs), and money market accounts are common banking products used for saving, but they differ in terms of accessibility, interest rates, and liquidity. Understanding these differences can help you decide which is best for your financial goals, particularly for building an emergency fund.
#
# ---
#
# ### **1. Savings Account**
#    - **What It Is:**
#      - A savings account is a basic deposit account offered by banks and credit unions for securely storing money while earning interest.
#    - **Key Features:**
#      - **Accessibility:** You can deposit and withdraw money relatively easily, although federal regulations (Regulation D) may limit certain types of withdrawals to six per month for savings accounts. This rule has been relaxed during the pandemic but may still apply at your financial institution.
#      - **Interest Rate:** Savings accounts typically have modest interest rates, though some high-yield savings accounts (HYSAs) offered by online banks pay competitive rates.
#      - **FDIC or NCUA Insurance:** Funds are federally insured up to $250,000 per depositor, per institution.
#      - **Fees:** Some accounts have maintenance fees, but many banks waive these if you meet minimum balance requirements.
#
#    - **Best For:**
#      - Immediate access to funds for short-term savings and emergency funds where liquidity is a top priority.
#
# ---
#
# ### **2. Certificate of Deposit (CD)**
#    - **What It Is:**
#      - A CD is a time deposit account where you commit to leaving your money with the bank or credit union for a fixed term (e.g., 6 months, 1 year, 5 years) in exchange for a higher interest rate.
#    - **Key Features:**
#      - **Accessibility:** Funds are locked until the end of the term (called the maturity date). If you withdraw money early, you’ll typically pay a penalty equivalent to several months’ worth of interest.
#      - **Interest Rate:** CDs offer higher, fixed interest rates compared to regular savings accounts, and the rate is locked in for the term of the CD.
#      - **FDIC or NCUA Insurance:** Like savings accounts, CDs are federally insured up to $250,000 per depositor, per institution.
#      - **Terms:** Terms typically range from 3 months to 5 years. Longer terms come with higher rates.
#      - **Laddering Strategy:** Some people use a CD ladder (investing in multiple CDs with staggered terms) to maintain some liquidity while earning higher rates.
#
#    - **Best For:**
#      - Long-term savings goals where you don’t need immediate access to your money, such as for planned future expenses.
#
# ---
#
# ### **3. Money Market Account (MMA)**
#    - **What It Is:**
#      - A money market account is similar to a savings account but typically combines features of both a savings and checking account.
#    - **Key Features:**
#      - **Accessibility:** Offers more accessibility than a savings account; you can often write checks or use a debit card for withdrawals. However, the same regulatory limits of six withdrawals per month may apply.
#      - **Interest Rate:** MMAs often offer higher interest rates than regular savings accounts, particularly if you maintain a higher balance.
#      - **Minimum Balance:** Often requires a higher minimum balance than a standard savings account. Some MMAs impose fees if your balance falls below that threshold.
#      - **FDIC or NCUA Insurance:** MMAs are federally insured up to $250,000 per depositor, per institution.
#
#    - **Best For:**
#      - Short-term savings where you want higher interest and quick access to funds but don’t anticipate needing frequent withdrawals.
#
# ---
#
# ### **Which is Best for Emergency Funds?**
# For an emergency fund, **liquidity and accessibility** are critical. Here’s how each product stacks up:
#
# 1. **Savings Account:**
#    - **Pros:** Highly liquid and accessible for emergencies. You can transfer funds quickly or withdraw cash at an ATM.
#    - **Cons:** Lower interest rates than CDs or many money market accounts.
#    - **Verdict:** Best choice for storing emergency funds, especially if you use a high-yield online savings account that earns higher interest while keeping funds easily accessible.
#
# 2. **Certificate of Deposit (CD):**
#    - **Pros:** Higher interest rates; good for growing your money you don’t expect to need.
#    - **Cons:** Ties up your money for a set period. Early withdrawals result in penalties, which defeats the purpose of having quick access during emergencies.
#    - **Verdict:** Often not a good fit for emergency funds. A CD may be useful for longer-term savings, but not for money you'll need quick access to.
#
# 3. **Money Market Account (MMA):**
#    - **Pros:** Offers higher interest rates than standard savings accounts, with limited access to funds when needed (via checks or a debit card). Often comes with FDIC or NCUA coverage.
#    - **Cons:** Typically requires a higher minimum balance, and you may face fees if your balance drops below a threshold.
#    - **Verdict:** A good choice for emergency funds if you can meet the minimum balance requirement and want a higher interest yield.
#
# ---
#
# ### **Regulatory and Financial Disclaimer**
# - There’s no one-size-fits-all answer, as the ideal account for your emergency fund will depend on your personal financial situation, saving needs, and preferences.
# - Always verify interest rates, fees, terms, and conditions with your bank or credit union, and consider consulting with a licensed financial advisor for personalized guidance.
#
# If you’d like recommendations on where to find high-yield savings accounts or tools to manage your emergency savings, I’d be happy to provide general information!
#
# 🎉 Completed 4 test conversations with our Financial Services Advisor!
# All responses received successfully! The agent is working great.
# 📊 Summary: 4/4 tests passed successfully

# %% [markdown]
# ## 5. Final Test: Complex Financial Question 🧹

# %%
# Function to chat with conversation context for multi-turn conversations
def chat_with_conversation_context(conversation_id, user_question):
    """Chat with the financial agent while maintaining conversation history."""
    
    if not financial_advisor:
        print("❌ No agent available.")
        return None
    
    try:
        print(f"👤 User: {user_question}")
        
        # Get the OpenAI client
        openai_client = project_client.get_openai_client()
        
        # Use responses API with conversation context
        response = openai_client.responses.create(
            conversation=conversation_id,
            extra_body={
                "agent_reference": {
                    "type": "agent_reference",
                    "name": financial_advisor.name,
                    "version": financial_advisor.version
                }
            },
            input=user_question
        )
        
        if response.output_text:
            print(f"🤖 Agent: {response.output_text}")
            return response.output_text
        else:
            print("❌ No response from agent")
            return None
            
    except Exception as e:
        print(f"❌ Error: {str(e)}")
        return None

# Let's create one more test conversation to demonstrate the agent's capabilities
print("🔍 Final Test: Complex Financial Scenario")
print("=" * 40)

conversation_id = financial_conversation.id if financial_conversation else None
final_response = chat_with_financial_agent(
    "I'm a 30-year-old first-time homebuyer with $50,000 saved for a down payment. I have a credit score of 720 and an annual income of $85,000. I'm looking at homes around $350,000. Should I consider a 15-year or 30-year mortgage, and what other costs should I budget for when buying a home?",
    conversation_id=conversation_id
)

if final_response:
    print(f"\n✅ Final test successful!")
    print(f"\n🎯 Our Financial Services Advisor Agent is fully functional and ready to help customers with banking inquiries!")
else:
    print(f"\n❌ Final test failed.")
# Out:
# 🔍 Final Test: Complex Financial Scenario
# ========================================
# 👤 User: I'm a 30-year-old first-time homebuyer with $50,000 saved for a down payment. I have a credit score of 720 and an annual income of $85,000. I'm looking at homes around $350,000. Should I consider a 15-year or 30-year mortgage, and what other costs should I budget for when buying a home?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Congratulations on considering your first home purchase! It sounds like you’re in a good position with a strong credit score and significant savings for a down payment. Let’s go over your options for a **15-year vs. 30-year mortgage** and break down the **other costs** to budget for during homeownership.
#
# ---
#
# ### **15-Year vs. 30-Year Mortgage**
# The decision between a 15-year and a 30-year mortgage depends on your financial goals, monthly cash flow, and tolerance for higher monthly payments in exchange for long-term savings. Here’s a comparison to help you decide:
#
# #### **15-Year Mortgage**
# - **Pros:**
#   1. **Lower Total Interest Paid:** You’ll pay significantly less in interest over the life of the loan because of the shorter term and lower interest rate. Lenders often offer lower rates on 15-year loans since they’re less risky.
#   2. **Faster Equity Growth:** Your payments go more toward the principal early on, allowing you to build home equity faster.
#   3. **Own Your Home Sooner:** You’ll own your home outright in half the time, giving you financial freedom earlier.
#
# - **Cons:**
#   1. **Higher Monthly Payment:** Since the loan term is shorter, monthly payments will be higher, which may limit your flexibility to save or invest in other areas.
#   2. **Less Financial Flexibility:** A higher fixed payment may strain your budget if unexpected expenses arise.
#
# #### **30-Year Mortgage**
# - **Pros:**
#   1. **Lower Monthly Payment:** Monthly payments are more affordable, leaving you with extra cash for other priorities like saving for retirement or an emergency fund.
#   2. **Greater Flexibility:** The lower payment allows for better cash flow management, keeping your finances more comfortable.
#   3. **Optional Prepayment:** You can always choose to make extra payments toward the principal if you want to pay off your mortgage faster.
#
# - **Cons:**
#   1. **Higher Total Interest Paid:** Over 30 years, you’ll pay significantly more in interest compared to a 15-year loan, even though the monthly payments are lower.
#   2. **Slower Equity Growth:** Less of your monthly payment goes toward the principal early on, so it will take longer to build equity in your home.
#
# #### **Which Option is Best for You?**
# - A **15-year mortgage** may be a good fit if:
#   - You’re comfortable with higher monthly payments.
#   - You want to pay off your home faster and save on interest.
#   - You have little or no significant debts (or you’ve already paid them off).
#
# - A **30-year mortgage** may be a better fit if:
#   - You want to keep your monthly payments lower for better cash flow.
#   - You want more financial flexibility to save, invest, or manage other expenses.
#   - You anticipate a need to prioritize savings for retirement, emergency funds, or future investments.
#
# For a home price of $350,000, if you put down $50,000 of your savings (14.3%), your loan amount would be roughly **$300,000**. Let’s estimate the monthly principal and interest payments for both mortgage terms:
#
# | Loan Term     | Rate (Approx.) | Monthly Payment* | Total Interest Paid (30 years) |
# |---------------|----------------|------------------|---------------------------------|
# | 15-Year Loan  | ~6.25%         | ~$2,588          | ~$166,000                       |
# | 30-Year Loan  | ~6.75%         | ~$1,944          | ~$400,000                       |
#
# *These are estimates and do not include property taxes, homeowners insurance, or private mortgage insurance (PMI).
#
# ---
#
# ### **Other Costs to Budget for When Buying a Home**
# When estimating whether you can afford a home, remember that the purchase price isn’t the only cost to consider. You’ll need to account for the following:
#
# #### 1. **Upfront Costs**
# - **Down Payment:** In your case, you’re putting down $50,000, which is slightly below the typical 20% required to avoid private mortgage insurance (PMI). We’ll address PMI below.
# - **Closing Costs:** These fees typically range from **2–5% of the home price** and cover things like loan origination fees, appraisal, inspections, title insurance, and attorney fees. On a $350,000 home, closing costs could be $7,000–$17,500 (on top of your down payment).
#   - Tip: In some cases, sellers may agree to pay a portion of your closing costs as part of the negotiation, or lenders may offer "no-closing-cost" options (though this often means a higher interest rate).
#
# #### 2. **Ongoing Costs**
# - **Private Mortgage Insurance (PMI):** If your down payment is less than 20%, most lenders will require you to pay PMI. This typically costs **0.5–1% of the loan amount per year** ($1,500–$3,000 annually for a $300,000 loan). PMI ends when you reach 20% equity in the home.
# - **Property Taxes:** Property taxes vary by location but can range from around **0.5% to 2.5% of the home's value annually**. In this case, a $350,000 home might incur property taxes of $3,500–$8,750 annually.
# - **Homeowners Insurance:** Coverage is typically required by lenders and can cost around $1,000–$2,000 annually, depending on the coverage and your property’s location.
# - **HOA Fees:** If the home is in a community with a homeowners association, you may also need to pay monthly or annual HOA fees for amenities or maintenance.
# - **Utilities & Maintenance:** Your home comes with ongoing maintenance costs, such as landscaping, plumbing, and repairs. Homeowners usually budget 1–3% of the home’s value annually for upkeep. For a $350,000 home, that’s about $3,500–$10,500 a year.
#
# #### 3. **Additional Considerations**
# - **Emergency Savings Fund:** After using $50,000 for your down payment, it’s essential to keep at least 3–6 months’ worth of expenses set aside for emergencies.
# - **Furniture & Appliances:** Your new home may require new furnishings, window treatments, or appliances, so budget accordingly.
#
# ---
#
# ### **Next Steps**
# 1. **Calculate Your Budget Comfortably:**
#    - Use a mortgage calculator to input both 15- and 30-year mortgage payments along with taxes, insurance, and PMI. Make sure you’ll still have enough leftover for your other financial goals (e.g., retirement savings).
#
# 2. **Shop for Pre-Approval:**
#    - Gather pre-approval quotes from multiple lenders. With your credit score of 720, you should qualify for competitive rates, but rates and terms can vary between lenders.
#
# 3. **Ask About First-Time Homebuyer Programs:**
#    - Many states and local governments offer assistance programs for first-time buyers, such as down payment grants or reduced rates on mortgage insurance.
#
# ---
#
# ### **Regulatory and Financial Disclaimer:**
# - This information is for educational purposes only and should not be considered financial or legal advice. Loan terms, interest rates, and other costs vary by lender and local regulations.
# - Always consult licensed professionals such as financial advisors and mortgage brokers to analyze your unique financial situation and needs when determining the best loan product for you.
#
# If you’d like more help budgeting for your new home or exploring first-time homebuyer programs, let me know—I’d be happy to provide more guidance!
#
# ✅ Final test successful!
#
# 🎯 Our Financial Services Advisor Agent is fully functional and ready to help customers with banking inquiries!

# %% [markdown]
# ## 5. Cleanup 🧹
# If you'd like to remove your agent from the service once finished, you can do so below. (In production, you might keep your agent around for stateful experiences!)

# %%
# Clean up resources using new Foundry API (delete ALL versions for this agent name)
if financial_advisor:
    agent_name = financial_advisor.name
    
    try:
        versions = list(project_client.agents.list_versions(agent_name=agent_name))
        print(f"🔎 Found {len(versions)} version(s) for '{agent_name}': {[v.version for v in versions]}")
        
        for version_item in versions:
            print(f"🗑️ Deleting version: {version_item.version}")
            project_client.agents.delete_version(
                agent_name=agent_name,
                agent_version=version_item.version
            )
        
        # Verify deletion (eventual consistency friendly)
        import time
        remaining_versions = []
        for attempt in range(1, 6):
            time.sleep(2)
            remaining_versions = list(project_client.agents.list_versions(agent_name=agent_name))
            if not remaining_versions:
                break
            print(
                f"⏳ Attempt {attempt}: still present -> {[v.version for v in remaining_versions]}"
            )
        
        if remaining_versions:
            print("⚠️ Some versions are still visible (may be eventual consistency/UI cache):")
            print([v.version for v in remaining_versions])
            print("💡 Hard refresh Foundry and check again in ~1 minute.")
        else:
            print("✅ All agent versions deleted. Agent should disappear from Foundry list.")
    except Exception as e:
        print(f"❌ Cleanup error: {e}")
else:
    print("ℹ️ No financial_advisor object found; nothing to delete.")
# Out:
# 🔎 Found 1 version(s) for 'financial-services-advisor': ['1']
# 🗑️ Deleting version: 1
# ✅ All agent versions deleted. Agent should disappear from Foundry list.

# %% [markdown]
# # Congratulations! 🏆
# You've successfully built a **Financial Services Advisor** that can:
# 1. **Respond** to basic banking, loan, and financial questions.
# 2. **Use disclaimers** to ensure regulatory compliance and encourage professional consultation.
# 3. **Provide** general banking product and savings information.
# 4. **Use** the synergy of **Microsoft Foundry** modules to power the conversation.
#
# ## Next Steps
# - Explore adding more advanced tools (like **FileSearchTool** or **CodeInterpreterTool**) to analyze loan documents or financial data.
# - Evaluate your AI's performance with **azure-ai-evaluation**!
# - Add **OpenTelemetry** or Azure Monitor for deeper insights.
# - Incorporate **function calling** if you want to handle things like loan calculations or account lookups.
#
# Happy banking automation! 💰

# %% [markdown]
# ## 🎯 Summary
#
# Congratulations! You've successfully:
#
# ✅ **Connected to Microsoft Foundry** - Established secure connection using authentication
# ✅ **Created an AI Agent** - Built a specialized Financial Services Advisor
# ✅ **Implemented Chat Functionality** - Created functions to interact with the agent
# ✅ **Tested Multiple Scenarios** - Verified the agent works for various banking questions
#
# ### Key Concepts Learned
#
# 1. **Azure AI Agent Service** - A managed service for building intelligent AI assistants
# 2. **Threads** - Conversation sessions that maintain context between messages
# 3. **Runs** - Agent processing operations that handle user queries and generate responses
# 4. **Messages** - Individual communications between users and agents
#
# ### 🔧 Key Takeaways
#
# - The **`create_thread_and_process_run()`** method is the simplest way to interact with agents
# - Agents automatically maintain conversation context within threads
# - The agent provides responsible AI disclaimers for financial advice
# - Error handling is crucial when working with AI services
