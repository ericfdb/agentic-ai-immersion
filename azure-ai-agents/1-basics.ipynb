# %% [markdown]
# # 🏦 Financial Services Advisor Agent Tutorial 💼
#
# Welcome to our **Financial Services Advisor Agent** tutorial, where you'll use **Microsoft Foundry** SDKs to create a banking and financial assistance AI agent. We'll:
#
# 1. **Initialize** our project using **azure-ai-projects**.
# 2. **Create an Agent** specialized in providing general banking, loan, and investment guidance (with disclaimers!).
# 3. **Manage conversations** about financial services, banking products, and loan inquiries.
# 4. **Showcase logging and tracing** with **OpenTelemetry**.
# 5. **Demonstrate** how to incorporate tools, regulatory disclaimers, and best practices.
#
# ### ⚠️ Important Financial Disclaimer ⚠️
# > **The financial information provided by this notebook is for general educational and demonstration purposes only and is not intended as financial, investment, legal, or tax advice.** Always consult with qualified financial advisors, bankers, or legal professionals before making any financial decisions. Past performance does not guarantee future results. All investments carry risk.
#
#
# ## Let's Get Started
# We'll walk you through each cell with notes. Let's begin!

# %% [markdown]
# ## 🔐 Authentication Setup
#
# Before running the next cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login --use-device-code
# ```
#
# This will provide you with a device code and URL to authenticate in your browser, which is useful for:
# - Remote development environments
# - Systems without a default browser
# - Corporate environments with strict security policies
#
# After successful authentication, you can proceed with the notebook cells below.

# %% [markdown]
# ## 1. Initial Setup
# We'll start by importing needed libraries, loading environment variables, and initializing an **AIProjectClient** so we can do all the agent-related actions. Let's do it! 🎉

# %%
from pathlib import Path  # For working with file paths
import os  # For environment variables
import time  # For sleep function
from dotenv import load_dotenv  # For loading environment variables from .env file
from azure.identity import InteractiveBrowserCredential  # For Azure authentication
from azure.ai.projects import AIProjectClient  # Main client for AI Projects
from azure.ai.projects.models import PromptAgentDefinition  # For new agent API

# Get the path to the .env file which is in the parent directory
notebook_path = Path().absolute()  # Get absolute path of current notebook
parent_dir = notebook_path.parent  # Get parent directory
load_dotenv(parent_dir.parent / '.env')  # Load environment variables from .env file

# Get tenant ID for authentication
tenant_id = os.environ.get("TENANT_ID")
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")

print(f"🔑 Using Tenant ID: {tenant_id}")

# Initialize the AI Project Client using simplified browser-based authentication
try:
    print("🌐 Using browser-based authentication to bypass Azure CLI cache issues...")
    
    # Use only InteractiveBrowserCredential with the specific tenant
    credential = InteractiveBrowserCredential(tenant_id=tenant_id)
    
    # Create the project client using endpoint
    project_client = AIProjectClient(
        endpoint=project_endpoint,
        credential=credential
    )
    print("✅ Successfully initialized AIProjectClient")
except Exception as e:
    # Print error message if client initialization fails
    print(f"❌ Error initializing project client: {str(e)}")
    print("💡 Please complete the browser authentication prompt that should appear")
# Out:
# 🔑 Using Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3
# 🌐 Using browser-based authentication to bypass Azure CLI cache issues...
# ✅ Successfully initialized AIProjectClient

# %% [markdown]
# ## 2. Creating our Financial Services Advisor Agent 🏦
#
# We'll create an Agent specialized in general banking and financial guidance. We'll explicitly mention disclaimers in its instructions, so it never forgets regulatory compliance! The instructions also ask the agent to focus on banking products, loan inquiries, and general financial guidance while always encouraging users to seek professional advice.

# %%
def create_financial_advisor_agent():
    """Create a financial services advisor agent with disclaimers and basic instructions using new Foundry API."""
    try:
        # Get the model name from environment variables, default to gpt-4o-mini if not set
        model_name = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o-mini")

        # Create a new agent using the NEW Foundry API with create_version
        # This uses PromptAgentDefinition for defining the agent's behavior
        agent = project_client.agents.create_version(
            agent_name="financial-services-advisor",
            description="Version 3.0.0 - Updated financial advisor",
            metadata={"semantic_version": "3.0.0"},
            definition=PromptAgentDefinition(
                model=model_name,
                instructions="""
                You are a friendly AI Financial Services Advisor for a retail bank.
                You provide general information about banking products, loans, and financial services, but always:
                1. Include regulatory and financial disclaimers.
                2. Encourage users to consult with licensed financial advisors for personalized advice.
                3. Provide general, non-personalized guidance around banking, loans, savings, and investments.
                4. Clearly remind users you're not a licensed financial advisor and cannot provide investment recommendations.
                5. Follow responsible banking practices and never suggest risky financial behaviors.
                6. Explain concepts like APR, interest rates, credit scores, and loan terms in simple language.
                """
            )
        )
        # Log success and return the created agent
        print(f"🎉 Created financial services advisor agent (name: {agent.name}, version: {agent.version})")
        return agent
    except Exception as e:
        # Handle any errors during agent creation
        print(f"❌ Error creating agent: {str(e)}")
        return None

# Create an instance of our financial services advisor agent
financial_advisor = create_financial_advisor_agent()
# Out:
# 🎉 Created financial services advisor agent (name: financial-services-advisor, version: 1)

# %% [markdown]
# ## 3. Managing Financial Service Conversations 💬
# A conversation (or *thread*) is where we'll store the user's messages and the agent's responses about banking and financial topics. Let's create a new thread dedicated to Financial Services Q&A.

# %%
# Function to create a new conversation for financial services discussions
def start_financial_conversation():
    """Create a new conversation for banking & financial discussions using new Foundry API."""
    try:
        # Get the OpenAI client from project client
        openai_client = project_client.get_openai_client()
        
        # Create a new conversation using the NEW API
        # Conversations replace threads in the new Foundry API
        conversation = openai_client.conversations.create()
        
        # Print success message with the conversation ID for reference
        print(f"📝 Created a new conversation, ID: {conversation.id}")
        
        # Return the created conversation object so we can use it later
        return conversation
    except Exception as e:
        # If conversation creation fails, print error and return None
        print(f"❌ Error creating conversation: {str(e)}")
        return None

# Initialize a new conversation that we'll use for our financial services Q&A
financial_conversation = start_financial_conversation()
# Out:
# 📝 Created a new conversation, ID: conv_1e52d8128b830bc1001h4fb4j8jcfKs6fbl3IPtPJ1srEnpAKf

# %% [markdown]
# ## 4. Asking Banking & Financial Questions 💳
# We'll create messages from the user about typical banking questions. For example, **"What factors affect my mortgage interest rate?"** or **"How do I improve my credit score?"**. We'll let our Financial Advisor Agent respond, always remembering the regulatory disclaimers!

# %%
# Function to chat with our financial services agent using the NEW Foundry API
def chat_with_financial_agent(user_question, conversation_id=None):
    """Chat with the financial services agent using the new responses API."""
    
    # Check if we have a valid agent
    if not financial_advisor:
        print("❌ No agent available. Please create an agent first.")
        return
    
    try:
        print(f"👤 User: {user_question}")
        print("🔄 Processing with agent...")
        
        # Get the OpenAI client from project client
        openai_client = project_client.get_openai_client()
        
        request_kwargs = {
            "extra_body": {
                "agent_reference": {
                    "type": "agent_reference",
                    "name": financial_advisor.name,
                    "version": financial_advisor.version,
                }
            },
            "input": user_question
        }
        
        # Attach conversation so the run is part of a persisted conversation context
        if conversation_id:
            request_kwargs["conversation"] = conversation_id
        
        # Use the NEW responses API with agent reference
        # This replaces the old create_thread_and_process_run method
        response = openai_client.responses.create(**request_kwargs)
        
        print("✅ Agent processing completed!")
        
        # Get the response text
        if response.output_text:
            print(f"🤖 Agent: {response.output_text}")
            return response.output_text
        else:
            print("❌ No response found from agent")
            return None
        
    except Exception as e:
        print(f"❌ Error chatting with agent: {str(e)}")
        # Debug: print more details about the error
        import traceback
        print("Full error traceback:")
        traceback.print_exc()
        return None

# Let's test our financial services agent with a simple question
print("🧪 Testing the Financial Services Advisor Agent...")
print("=" * 50)
# Out:
# 🧪 Testing the Financial Services Advisor Agent...
# ==================================================

# %% [markdown]
# ### Example Financial Services Queries
# Let's do some quick queries now to see the agent's disclaimers and how it handles typical banking and financial questions. We'll ask about **mortgages**, **credit scores**, and **savings strategies**.

# %%
# Test 1: Simple Banking Question (Already completed above)
print("Test 1: Simple Banking Question ✅")
print("-" * 30)

conversation_id = financial_conversation.id if financial_conversation else None
if not conversation_id:
    print("⚠️ No conversation available; responses will not be linked to a conversation.")

# Test 2: Ask about mortgage rates
print("\nTest 2: Mortgage Advice")
print("-" * 20)
response2 = chat_with_financial_agent(
    "What factors affect my mortgage interest rate and how can I get a better rate?",
    conversation_id=conversation_id
 )

print("\n" + "="*60 + "\n")

# Test 3: Ask about credit scores
print("Test 3: Credit Score Guidance")  
print("-" * 20)
response3 = chat_with_financial_agent(
    "How is my credit score calculated and what can I do to improve it?",
    conversation_id=conversation_id
 )

print("\n" + "="*60 + "\n")

# Test 4: Ask about savings strategies
print("Test 4: Savings & Investment Basics")
print("-" * 20) 
response4 = chat_with_financial_agent(
    "What's the difference between a savings account, CD, and money market account? Which is best for emergency funds?",
    conversation_id=conversation_id
 )

print(f"\n🎉 Completed 4 test conversations with our Financial Services Advisor!")
print(f"All responses received successfully! The agent is working great.")

# Show a summary
successful_tests = sum([1 for r in [True, response2, response3, response4] if r])
print(f"📊 Summary: {successful_tests}/4 tests passed successfully")
# Out:
# Test 1: Simple Banking Question ✅
# ------------------------------
#
# Test 2: Mortgage Advice
# --------------------
# 👤 User: What factors affect my mortgage interest rate and how can I get a better rate?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Many factors can influence the interest rate you receive on your mortgage. These factors are determined by both your financial situation and broader market conditions. Below, I’ll explain the main factors in simple terms and provide tips to help you potentially secure a better rate.
#
# ---
#
# ### **Factors That Affect Your Mortgage Interest Rate**
#
# 1. **Credit Score**
#    - **What It Is**: Your credit score indicates how reliable you’ve been with paying back borrowed money (like loans or credit cards).
#    - **Why It Matters**: Lenders use your credit score to determine how risky it is to lend to you. A higher score usually means lower risk, which can qualify you for a lower interest rate.
#    - **Tip**: Aim to maintain a good or excellent credit score (generally 700+). Check your credit reports regularly for errors, pay bills on time, and reduce your credit card balances.
#
# 2. **Loan-to-Value (LTV) Ratio**
#    - **What It Is**: This is the percentage of the home’s price you’re borrowing. For example, a 20% down payment means an LTV ratio of 80%.
#    - **Why It Matters**: The smaller your LTV ratio (i.e., the more equity or cash you put down), the less risky you are to the lender, which may lead to a better rate.
#    - **Tip**: Save for a larger down payment (e.g., 20% or more) to lower your LTV, reduce private mortgage insurance (PMI) costs, and get better rates.
#
# 3. **Debt-to-Income (DTI) Ratio**
#    - **What It Is**: This compares your total monthly debts to your income. Lenders use it to gauge if you can comfortably afford the loan.
#    - **Why It Matters**: A lower DTI ratio makes you a less risky borrower and can help secure a better rate.
#    - **Tip**: Pay down existing debt before applying for a mortgage. Avoid taking on new debt before or during the application process.
#
# 4. **Type of Interest Rate**
#    - **What It Is**: Mortgages offer fixed or adjustable interest rates. Fixed rates stay the same for the life of the loan, while adjustable rates (ARMs) may start lower but fluctuate over time.
#    - **Why It Matters**: Fixed rates provide stability, but ARM rates are generally lower initially.
#    - **Tip**: If you plan to stay in the home long term, a fixed-rate mortgage may be the better choice. For shorter-term ownership, an ARM could provide initial savings.
#
# 5. **Loan Term**
#    - **What It Is**: The length of time you take to pay off the loan (e.g., 15, 20, or 30 years).
#    - **Why It Matters**: Shorter loan terms often have lower interest rates but higher monthly payments. Longer terms have higher rates but lower payments.
#    - **Tip**: If you can afford higher payments, opt for a shorter term to save on interest costs over time.
#
# 6. **Market Conditions**
#    - **What It Is**: Interest rates are influenced by broader economic factors, like inflation, Federal Reserve policies, and demand in the bond market.
#    - **Why It Matters**: These are external factors you can’t control but can plan around.
#    - **Tip**: Stay informed about market conditions. Lock your rate when rates are low—your lender can explain rate locks.
#
# 7. **The Type of Mortgage**
#    - **What It Is**: Different loans (e.g., conventional, FHA, VA) have varying requirements and rates.
#    - **Why It Matters**: Government-backed loans may offer lower rates or looser credit requirements compared to conventional loans.
#    - **Tip**: Explore different mortgage options with your lender to find one that suits your financial situation.
#
# 8. **Location**
#    - **What It Is**: Rates may vary depending on where your property is located.
#    - **Why It Matters**: Some states, counties, or regions may have slightly higher or lower interest rates based on economic conditions or lending competition.
#    - **Tip**: Research whether rates in your area make ownership affordable.
#
# ---
#
# ### **How to Get a Better Rate**
#
# 1. **Improve Your Credit Score**
#    Pay bills on time, reduce debt, and avoid closing old credit accounts. A higher credit score often allows you to qualify for better rates.
#
# 2. **Save for a Larger Down Payment**
#    Putting down 20% or more can significantly improve your rate and eliminate private mortgage insurance (PMI), which adds to your costs.
#
# 3. **Shop Around**
#    Don’t settle for the first lender you speak to. Compare offers from multiple lenders (banks, credit unions, and online lenders) to find the best rate and terms.
#
# 4. **Consider Different Loan Terms**
#    A 15-year mortgage typically carries a lower interest rate compared to a 30-year loan. Evaluate whether a shorter term fits your budget.
#
# 5. **Pay Points to Buy Down the Rate**
#    You can pay upfront for "discount points" to lower your interest rate. Each point typically costs 1% of the loan amount and reduces the rate by a fraction of a percent.
#
# 6. **Lock Your Rate**
#    If rates are expected to go up while you’re in the process of buying, lock in your rate early. Work with your lender to ensure you get the terms you expect.
#
# 7. **Choose the Right Time to Apply**
#    Apply when your personal finances are in good shape, and watch market conditions for historically low rates.
#
# ---
#
# ### **Important Reminder**
# - Interest rates may be negotiable. Don’t hesitate to advocate for yourself with lenders. Ask about any discounts, such as for being an existing customer.
# - Borrow responsibly—understand all the terms of your mortgage before signing.
# - Always consult with a licensed financial advisor or mortgage expert for personalized advice tailored to your unique financial situation.
#
# ---
#
# If you’d like more specific guidance on any of these topics, let me know!
#
# ============================================================
#
# Test 3: Credit Score Guidance
# --------------------
# 👤 User: How is my credit score calculated and what can I do to improve it?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Your credit score is an important number that helps lenders understand your financial habits. It’s used to evaluate your creditworthiness (how reliable you are in repaying loans) and plays a big role in decisions around loans, credit cards, and even interest rates. Let me break it down for you and provide actionable steps to improve your score.
#
# ---
#
# ### **How Your Credit Score is Calculated**
# Your credit score (typically a FICO or VantageScore, the two most common scoring systems) is calculated based on several key factors. While the exact formula may vary slightly, here’s a general breakdown of what determines your score:
#
# 1. **Payment History (35%)**
#    - This is the most important factor.
#    - It tracks whether you make your payments on time for credit cards, loans, mortgages, or other debts.
#    - Missed, late, or defaulted payments negatively impact your score.
#
# 2. **Amounts Owed (30%)**
#    - This looks at how much debt you have compared to your total available credit, also called your credit utilization ratio.
#    - For example, if your credit limit is $10,000 and you have $3,000 in debt, your utilization is 30%.
#    - Keeping this ratio low (ideally below 30%) generally boosts your score.
#
# 3. **Length of Credit History (15%)**
#    - In general, the longer your credit history, the better.
#    - This includes the age of your oldest account, the average age of all your accounts, and how long it’s been since you last used these accounts.
#
# 4. **Credit Mix (10%)**
#    - This factor considers the variety of credit types you have, such as credit cards, mortgages, auto loans, or student loans.
#    - Lenders view a mix of credit types as a sign you can successfully manage different kinds of debt.
#
# 5. **New Credit (10%)**
#    - This tracks how often you apply for new credit.
#    - Each "hard inquiry" (like applying for a credit card or loan) can slightly lower your score temporarily.
#
# ---
#
# ### **How to Improve Your Credit Score**
# Improving your credit score takes time and consistent financial habits. Here are practical steps to boost it:
#
# #### 1. **Pay Bills On Time**
#    - **Why?** Late or missed payments are a major negative factor for your credit score.
#    - **How?** Set up automatic payments or reminders to ensure you don’t miss due dates.
#
# #### 2. **Lower Your Credit Utilization**
#    - **Why?** Using a lower percentage of your available credit helps demonstrate that you’re financially responsible.
#    - **How?**
#       - Aim to keep your credit utilization below 30% (and ideally below 10% for a bigger impact).
#       - If your credit limit is $5,000, try to keep your balance below $1,500.
#       - Consider paying off balances multiple times a month to keep usage low.
#
# #### 3. **Avoid Closing Older Accounts**
#    - **Why?** Closing an old credit account shortens your credit history, which can hurt your score.
#    - **How?** Keep older accounts open, even if you don’t use them frequently. Use them occasionally for small purchases and pay the balances off to keep the accounts active.
#
# #### 4. **Be Careful with New Credit Applications**
#    - **Why?** Each time you apply for credit, it creates a “hard inquiry,” which can temporarily lower your score.
#    - **How?** Only apply for new credit when absolutely necessary. If you're shopping for a loan (e.g., mortgage or auto loan), try to complete inquiries within a short time frame (usually 14–45 days) to limit the impact.
#
# #### 5. **Dispute Errors on Your Credit Report**
#    - **Why?** Errors like incorrect late payments or accounts that aren’t yours can drag your score down unfairly.
#    - **How?**
#       - Check your credit report for free at [AnnualCreditReport.com](https://www.annualcreditreport.com).
#       - Dispute inaccuracies with the credit bureau(s) reporting them (e.g., Equifax, Experian, or TransUnion).
#
# #### 6. **Pay Down Debt**
#    - **Why?** Paying off high balances reduces your credit utilization and shows lenders you’re responsible with money.
#    - **How?** Use strategies like the debt snowball (pay off smaller balances first for quick wins) or the debt avalanche (pay off highest-interest accounts first).
#
# #### 7. **Request a Credit Limit Increase**
#    - **Why?** A higher credit limit helps lower your credit utilization (as long as you don’t increase your spending).
#    - **How?** Ask your credit card issuer for a limit increase. Be mindful that this may result in a hard inquiry, so confirm beforehand.
#
# #### 8. **Consider Becoming an Authorized User**
#    - **Why?** Being added to someone else’s credit card account (such as a parent or partner) can boost your credit history and utilization—if the primary account holder is responsible with their credit.
#    - **How?** Discuss this with someone you trust, and make sure their account is in good standing.
#
# #### 9. **Use a Secured Credit Card (if credit is poor or limited)**
#    - **Why?** Secured credit cards require a deposit as collateral and can help you build your credit if used responsibly.
#    - **How?** Charge small amounts to the card and pay off the full balance each month.
#
# #### 10. **Be Patient**
#    - **Why?** Positive credit changes take time to reflect, but consistent good habits can steadily improve your score.
#    - **How?** Set long-term goals and track your progress. Your credit score will improve as you establish solid financial habits over time.
#
# ---
#
# ### **Key Reminders**
# - **Know your score**: Check your credit score and reports regularly. Many financial institutions and credit card providers offer free credit score monitoring.
# - **Be cautious of credit counselors**: If you need help managing debt, ensure the credit counseling service you work with is legitimate. Avoid scams!
# - **Improving credit takes time**: Changes to your score don’t happen overnight, especially when trying to build a longer credit history.
#
# ---
#
# ### **Resources**
# - Visit [AnnualCreditReport.com](https://www.annualcreditreport.com) to check your credit report for free once a year.
# - Consider consulting a certified financial counselor or a credit repair expert if your score is very low or if you’re overwhelmed by debt.
#
# Remember, I can provide general guidance, but for personalized advice tailored to your financial situation, contact a licensed financial advisor or credit expert. If you have more questions, just let me know!
#
# ============================================================
#
# Test 4: Savings & Investment Basics
# --------------------
# 👤 User: What's the difference between a savings account, CD, and money market account? Which is best for emergency funds?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Great question! Savings accounts, Certificates of Deposit (CDs), and Money Market Accounts (MMAs) are all different types of deposit accounts that can be used to save money, but they each work a little differently. I’ll explain the key differences and which might be best for an emergency fund.
#
# ---
#
# ### **1. Savings Account**
# A savings account is a basic, low-risk account where you can deposit money and earn interest over time.
#
# #### **Key Features:**
# - **Liquidity**: High. You can access your money easily when needed. Many accounts allow you to withdraw funds at any time via ATMs, online transfers, or in-branch visits.
# - **Interest Rates**: Typically low but variable. Online banks often offer higher interest rates than traditional banks.
# - **Minimum Balance Requirements**: Often low or none.
# - **Limits on Withdrawals**: Federal rules (Regulation D) typically limit certain types of withdrawals to six per month, though you can make unlimited ATM in-person withdrawals.
#
# #### **Best For:**
# - Emergency funds because money is easily accessible when you need it.
# - People who want a place to build savings without worrying about penalties for withdrawals.
#
# ---
#
# ### **2. Certificate of Deposit (CD)**
# A CD is a time-deposit account where you agree to lock your money away for a fixed period (e.g., 6 months, 1 year, 5 years, etc.) in exchange for a fixed interest rate.
#
# #### **Key Features:**
# - **Liquidity**: Low. You cannot access your money until the CD matures without paying an early withdrawal penalty.
# - **Interest Rates**: Higher than a savings account, especially for longer-term CDs, and rates are fixed for the term of the CD.
# - **Minimum Balance Requirements**: Often higher (e.g., $500 or more) compared to a standard savings account.
# - **Withdrawal Penalties**: Withdrawing the money early usually incurs a penalty (often several months’ worth of interest).
#
# #### **Best For:**
# - Money you don’t need to access in the near term.
# - People who want guaranteed returns and don't mind locking their money away for a specific period.
#
# ---
#
# ### **3. Money Market Account (MMA)**
# A money market account is a hybrid between a savings and a checking account. It typically offers higher interest rates than savings accounts and allows limited check writing and debit card access.
#
# #### **Key Features:**
# - **Liquidity**: Moderate. You’ll usually have easy access to your money via checks or a debit card, but federal rules (Regulation D) often limit certain types of withdrawals and transfers to six per month.
# - **Interest Rates**: Higher than traditional savings accounts and often tied to market rates. Rates may increase with a higher balance.
# - **Minimum Balance Requirements**: Can be higher than a savings account (some require $1,000 or more).
# - **Withdrawal/Transfer Limits**: Similar to savings accounts, certain types of transactions may be limited to six per month, though ATM withdrawals or checks shouldn't count toward that limit.
#
# #### **Best For:**
# - Emergency funds, for individuals who want slightly higher interest earnings while keeping funds relatively accessible.
# - People with higher account balances who can meet the minimum requirements.
#
# ---
#
# ### **Which Is Best for Emergency Funds?**
#
# Emergency funds should prioritize **liquidity** (easy access to cash) and **safety** over potential returns. While all three options are relatively safe, savings accounts and money market accounts are generally better suited for emergency funds due to their accessibility.
#
# #### **Recommendation for Emergency Funds**:
# 1. **Savings Accounts**:
#    - Best choice if you prioritize simplicity and easy access.
#    - Look for an account with a competitive interest rate (online banks often have higher rates than traditional ones).
#
# 2. **Money Market Accounts**:
#    - A strong option if you can meet higher minimum balance requirements and want the flexibility of check writing and debit card access.
#
# 3. **Avoid CDs for Emergency Funds**:
#    - CDs are less ideal because they lock up your money for a fixed term, making the funds harder to access in an emergency. If you do choose a CD for part of your emergency savings, opt for a **short-term CD** (e.g., 6–12 months) or a **CD ladder** for more flexibility.
#
# ---
#
# ### Additional Tips for Emergency Funds:
# - **Save at least 3–6 months’ worth of living expenses** in your emergency fund, depending on your circumstances (more if your income is variable or if you have dependents).
# - Check account terms for withdrawal penalties, fees, and minimum deposit requirements.
# - Use a **high-yield savings account** from an online bank to maximize returns while keeping the funds liquid.
# - Emergency funds are **not investments**—they’re your financial safety net, so prioritize security over risk or high returns.
#
# ---
#
# If you’d like specific examples of accounts or strategies (like creating a hybrid emergency savings plan), just let me know! Always remember to evaluate options carefully and consult a licensed financial advisor for personalized advice. :)
#
# 🎉 Completed 4 test conversations with our Financial Services Advisor!
# All responses received successfully! The agent is working great.
# 📊 Summary: 4/4 tests passed successfully

# %% [markdown]
# ## 5. Final Test: Complex Financial Question 🧹

# %%
# Function to chat with conversation context for multi-turn conversations
def chat_with_conversation_context(conversation_id, user_question):
    """Chat with the financial agent while maintaining conversation history."""
    
    if not financial_advisor:
        print("❌ No agent available.")
        return None
    
    try:
        print(f"👤 User: {user_question}")
        
        # Get the OpenAI client
        openai_client = project_client.get_openai_client()
        
        # Use responses API with conversation context
        response = openai_client.responses.create(
            conversation=conversation_id,
            extra_body={
                "agent_reference": {
                    "type": "agent_reference",
                    "name": financial_advisor.name,
                    "version": financial_advisor.version
                }
            },
            input=user_question
        )
        
        if response.output_text:
            print(f"🤖 Agent: {response.output_text}")
            return response.output_text
        else:
            print("❌ No response from agent")
            return None
            
    except Exception as e:
        print(f"❌ Error: {str(e)}")
        return None

# Let's create one more test conversation to demonstrate the agent's capabilities
print("🔍 Final Test: Complex Financial Scenario")
print("=" * 40)

conversation_id = financial_conversation.id if financial_conversation else None
final_response = chat_with_financial_agent(
    "I'm a 30-year-old first-time homebuyer with $50,000 saved for a down payment. I have a credit score of 720 and an annual income of $85,000. I'm looking at homes around $350,000. Should I consider a 15-year or 30-year mortgage, and what other costs should I budget for when buying a home?",
    conversation_id=conversation_id
)

if final_response:
    print(f"\n✅ Final test successful!")
    print(f"\n🎯 Our Financial Services Advisor Agent is fully functional and ready to help customers with banking inquiries!")
else:
    print(f"\n❌ Final test failed.")
# Out:
# 🔍 Final Test: Complex Financial Scenario
# ========================================
# 👤 User: I'm a 30-year-old first-time homebuyer with $50,000 saved for a down payment. I have a credit score of 720 and an annual income of $85,000. I'm looking at homes around $350,000. Should I consider a 15-year or 30-year mortgage, and what other costs should I budget for when buying a home?
# 🔄 Processing with agent...
# ✅ Agent processing completed!
# 🤖 Agent: Congratulations on saving for your down payment and planning for your first home! Buying a home is a big milestone, and it’s great that you’re carefully considering your options. Let me walk you through whether a **15-year or 30-year mortgage** may be better for your situation, plus the additional costs you should anticipate when purchasing a home.
#
# ---
#
# ### **1. 15-Year vs. 30-Year Mortgage**
#
# The choice between a 15-year and 30-year mortgage depends on your financial priorities: lowering long-term costs vs. minimizing monthly payments. Here’s how each stacks up:
#
# | **15-Year Mortgage**                  | **30-Year Mortgage**                 |
# |---------------------------------------|---------------------------------------|
# | **Monthly Payments**: Higher          | **Monthly Payments**: Lower          |
# | **Interest Rate**: Lower (because it’s a shorter term and less risk to lenders) | **Interest Rate**: Slightly higher    |
# | **Total Interest Paid Over the Loan**: Much less (saved by paying off principal faster) | **Total Interest Paid Over the Loan**: Higher due to the longer term |
# | **Loan Repayment Speed**: Much faster (you’ll own the home outright in half the time) | **Loan Repayment Speed**: Longer time to build equity, longer mortgage term |
#
# #### For Your Case:
# Let’s estimate some numbers based on a $300,000 mortgage (price of the home minus your $50,000 down payment). These are rough estimates using average interest rates as of now—rates will differ based on lender, credit score, and market conditions.
#
# | Loan Term | Interest Rate | Monthly Payment (Principal/Interest Only) | Total Interest Over Term |
# |-----------|---------------|-------------------------------------------|--------------------------|
# | 15-Year   | ~6.5%         | ~$2,610                                   | ~$70,000                 |
# | 30-Year   | ~7.0%         | ~$1,995                                   | ~$218,200                |
#
# Based on this example:
# - A **15-Year Mortgage**: You’ll pay significantly less in interest (savings of ~$148,000), and you’ll build equity (ownership in your house) much faster. However, the much higher monthly payment may stretch your budget and leave you with less cash for other expenses.
# - A **30-Year Mortgage**: You’ll have lower monthly payments, which leaves more cash available for other priorities like savings, investments, maintenance, or an emergency fund. However, you’ll pay much more interest over the life of the loan.
#
# ---
#
# **Which should you choose?**
# - Consider a **30-year mortgage** if:
#    - You want more flexibility in your budget to cover other expenses like emergencies, home repairs, or investments.
#    - You prefer lower monthly payments to avoid financial strain.
#    - You plan to make extra payments to pay off your mortgage sooner (as 30-year mortgages allow prepayment without penalty—check with your lender).
#
# - Consider a **15-year mortgage** if:
#    - You are confident that you can comfortably afford the higher monthly payments without jeopardizing other goals (retirement savings, emergency fund, etc.).
#    - Your primary goal is to save on interest and pay off your home quickly.
#    - You are not concerned with the trade-off of having less disposable income each month.
#
# Before deciding, work with a lender to get pre-approval and compare exact loan scenarios for your situation. A mortgage calculator can also help you visualize the differences.
#
# ---
#
# ### **2. Other Costs to Budget for When Buying a Home**
#
# Beyond your down payment and monthly mortgage payments, there are several upfront and ongoing costs to consider.
#
# #### **1. Upfront Costs**:
# - **Closing Costs** (2–6% of the home’s price):
#    - Includes lender fees, title insurance, appraisal, attorney fees, etc.
#    - On a $350,000 home, you could pay $7,000–$21,000 in closing costs.
#    - Ask the seller if they’re willing to pay part of your closing costs in a buyer’s market.
#
# - **Home Inspection** (~$300–$500):
#    - This is optional but highly recommended to ensure the home is free of major issues.
#
# - **Earnest Money Deposit** (~1–3% of the purchase price):
#    - This is a good-faith deposit you put down to show you’re serious about buying the home. It’s typically applied to your closing costs or down payment.
#
# #### **2. Ongoing Costs**:
# - **Property Taxes**:
#    - Typically 1–2% of the home’s value annually, depending on your location. For a $350,000 home, this could be around $3,500–$7,000 per year.
#    - Lenders usually include this in your monthly mortgage payment using an escrow account.
#
# - **Homeowner’s Insurance**:
#    - Average annual premiums range from $1,000–$1,500 depending on your home’s location, size, and features.
#
# - **Private Mortgage Insurance (PMI)** (if your down payment is less than 20%):
#    - This protects the lender if you default. PMI typically costs 0.3–1.5% of the loan amount annually, or $900–$4,500 on a $300,000 loan.
#    - Tip: Once your equity hits 20%, you can request to have PMI removed (if it’s a conventional loan).
#
# - **Home Maintenance/Repairs**:
#    - Set aside 1–3% of your home’s value annually for upkeep. For a $350,000 home, this could mean $3,500–$10,500 annually.
#
# - **HOA Fees** (if applicable):
#    - If the home is in a community with a homeowner’s association, you may pay monthly HOA dues. These can range from $100 to several hundred dollars per month.
#
# - **Utilities**:
#    - Budget for water, electricity, gas, internet, and trash services, which may be higher than in a rental since you'll be covering the entire property.
#
# #### **3. Future Costs**:
# - **Furniture/Appliances**:
#    - If your new home doesn’t come with all appliances (washer, dryer, fridge, etc.), budget for these as well.
#
# - **Moving Costs**:
#    - Moving costs vary depending on how far you’re relocating but can range from a few hundred to several thousand dollars.
#
# ---
#
# ### **3. Tips for First-Time Homebuyers**
# 1. **Get Pre-Approved for a Mortgage**: This helps you understand what loan amount you qualify for and how much home you can afford. It also shows sellers that you’re a serious buyer.
# 2. **Stick to Your Budget**: Avoid stretching beyond your financial comfort zone to avoid becoming house poor. Make sure your monthly housing expenses (including mortgage, taxes, and insurance) don’t exceed 25–30% of your gross monthly income.
# 3. **Don’t Deplete Your Savings**:
#    - Avoid using your entire $50,000 savings for the down payment. Keep some money for closing costs and still maintain an emergency fund (3–6 months of living expenses).
# 4. **Shop Around for Loans**: Different lenders may offer different interest rates, mortgage terms, or options. Compare offers to get the best deal.
# 5. **Work with a Trusted Realtor**: A good realtor will help you find homes that meet your needs and guide you through the buying process, especially if it’s your first home.
#
# ---
#
# ### **Summary: Recommendations for You**
# - A **30-year mortgage** might be a better fit if you expect to need a lower monthly payment or want to keep some financial flexibility.
# - You’ll need to budget for closing costs, property taxes, insurance, and other expenses on top of your mortgage payment.
# - Explore **down payment assistance programs** for first-time homebuyers in your state—these can help you maximize your buying power.
# - Always leave extra funds in your savings for emergencies and unexpected home expenses.
#
# Let me know if you’d like specific resources on first-time homebuyer programs or calculators to estimate your monthly payments. I’m happy to help!
#
# ✅ Final test successful!
#
# 🎯 Our Financial Services Advisor Agent is fully functional and ready to help customers with banking inquiries!

# %% [markdown]
# ## 5. Cleanup 🧹
# If you'd like to remove your agent from the service once finished, you can do so below. (In production, you might keep your agent around for stateful experiences!)

# %%
# Clean up resources using new Foundry API (delete ALL versions for this agent name)
if financial_advisor:
    agent_name = financial_advisor.name
    
    try:
        versions = list(project_client.agents.list_versions(agent_name=agent_name))
        print(f"🔎 Found {len(versions)} version(s) for '{agent_name}': {[v.version for v in versions]}")
        
        for version_item in versions:
            print(f"🗑️ Deleting version: {version_item.version}")
            project_client.agents.delete_version(
                agent_name=agent_name,
                agent_version=version_item.version
            )
        
        # Verify deletion (eventual consistency friendly)
        import time
        remaining_versions = []
        for attempt in range(1, 6):
            time.sleep(2)
            remaining_versions = list(project_client.agents.list_versions(agent_name=agent_name))
            if not remaining_versions:
                break
            print(
                f"⏳ Attempt {attempt}: still present -> {[v.version for v in remaining_versions]}"
            )
        
        if remaining_versions:
            print("⚠️ Some versions are still visible (may be eventual consistency/UI cache):")
            print([v.version for v in remaining_versions])
            print("💡 Hard refresh Foundry and check again in ~1 minute.")
        else:
            print("✅ All agent versions deleted. Agent should disappear from Foundry list.")
    except Exception as e:
        print(f"❌ Cleanup error: {e}")
else:
    print("ℹ️ No financial_advisor object found; nothing to delete.")
# Out:
# 🔎 Found 1 version(s) for 'financial-services-advisor': ['1']
# 🗑️ Deleting version: 1
# ✅ All agent versions deleted. Agent should disappear from Foundry list.

# %% [markdown]
# # Congratulations! 🏆
# You've successfully built a **Financial Services Advisor** that can:
# 1. **Respond** to basic banking, loan, and financial questions.
# 2. **Use disclaimers** to ensure regulatory compliance and encourage professional consultation.
# 3. **Provide** general banking product and savings information.
# 4. **Use** the synergy of **Microsoft Foundry** modules to power the conversation.
#
# ## Next Steps
# - Explore adding more advanced tools (like **FileSearchTool** or **CodeInterpreterTool**) to analyze loan documents or financial data.
# - Evaluate your AI's performance with **azure-ai-evaluation**!
# - Add **OpenTelemetry** or Azure Monitor for deeper insights.
# - Incorporate **function calling** if you want to handle things like loan calculations or account lookups.
#
# Happy banking automation! 💰

# %% [markdown]
# ## 🎯 Summary
#
# Congratulations! You've successfully:
#
# ✅ **Connected to Microsoft Foundry** - Established secure connection using authentication
# ✅ **Created an AI Agent** - Built a specialized Financial Services Advisor
# ✅ **Implemented Chat Functionality** - Created functions to interact with the agent
# ✅ **Tested Multiple Scenarios** - Verified the agent works for various banking questions
#
# ### Key Concepts Learned
#
# 1. **Azure AI Agent Service** - A managed service for building intelligent AI assistants
# 2. **Threads** - Conversation sessions that maintain context between messages
# 3. **Runs** - Agent processing operations that handle user queries and generate responses
# 4. **Messages** - Individual communications between users and agents
#
# ### 🔧 Key Takeaways
#
# - The **`create_thread_and_process_run()`** method is the simplest way to interact with agents
# - Agents automatically maintain conversation context within threads
# - The agent provides responsible AI disclaimers for financial advice
# - Error handling is crucial when working with AI services
