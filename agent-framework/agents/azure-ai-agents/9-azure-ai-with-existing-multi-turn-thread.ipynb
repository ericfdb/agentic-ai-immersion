# %% [markdown]
# ## 🔐 Prerequisites
#
# Before running the first cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login
# ```
#
# or
#
# ```bash
# az login --use-device-code
# ```

# %% [markdown]
# # 💬 Azure AI Agent with Thread Management - Multi-Turn Conversations 🏦
#
# This notebook demonstrates working with conversation threads using `AzureAIProjectAgentProvider` for multi-turn conversations like loan application discussions and financial planning sessions.
#
# ## Features Covered:
# - Creating and managing persistent conversation threads
# - Using `agent.get_new_thread()` for thread management
# - Thread lifecycle management (create, use, delete)
# - Multi-turn conversation continuity for banking discussions
# - Thread initialization and validation with `store=False` option
#
# ### ⚠️ Important Note ⚠️
# > **Threads maintain conversation context across multiple interactions. This is essential for complex banking discussions like loan applications or investment planning.**

# %% [markdown]
# ## Prerequisites
#
# Before running this notebook, ensure you have:
#
# 1. **Azure AI Project**: Access to an Microsoft Foundry project with deployed models
# 2. **Authentication**: Azure CLI installed and authenticated (`az login --use-device-code`)
# 3. **Environment Variables**: Set up your `.env` file with:
#    - `AI_FOUNDRY_PROJECT_ENDPOINT`
#    - `AZURE_AI_MODEL_DEPLOYMENT_NAME`
# 4. **Dependencies**: Required agent-framework packages installed
#
# If you need to use a different tenant:
# ```bash
# az login --tenant <tenant-id>
# ```
#
# This example demonstrates how to work with existing threads to maintain conversation continuity in banking scenarios.

# %% [markdown]
# ## Import Libraries
#
# Import the required libraries using the `AzureAIAgentsProvider` API:

# %%
import os
from pathlib import Path
from random import randint, uniform
from typing import Annotated

from agent_framework.azure import AzureAIAgentsProvider
from azure.ai.agents.aio import AgentsClient
from azure.identity.aio import AzureCliCredential
from pydantic import Field
from dotenv import load_dotenv

# Load environment variables
load_dotenv('../../.env')

# Verify environment setup
endpoint = os.getenv('AI_FOUNDRY_PROJECT_ENDPOINT')
model = os.getenv('AZURE_AI_MODEL_DEPLOYMENT_NAME')

print("🔧 Environment Configuration:")
print(f"✅ Project Endpoint: {endpoint[:50]}..." if endpoint else "❌ AI_FOUNDRY_PROJECT_ENDPOINT not set")
print(f"✅ Model Deployment: {model}" if model else "❌ AZURE_AI_MODEL_DEPLOYMENT_NAME not set")
# Out:
# 🔧 Environment Configuration:
# ✅ Project Endpoint: https://demopocaifoundry.services.ai.azure.com/api...
# ✅ Model Deployment: gpt-4o

# %% [markdown]
# ## Check Environment Variables
#
# Verify that the required environment variables are set:

# %%
# Check required environment variables
endpoint = os.getenv('AI_FOUNDRY_PROJECT_ENDPOINT')
if endpoint:
    print(f"✅ AI_FOUNDRY_PROJECT_ENDPOINT: {endpoint}")
else:
    print("❌ AI_FOUNDRY_PROJECT_ENDPOINT: Not set")
    print("⚠️  Please set the AI_FOUNDRY_PROJECT_ENDPOINT environment variable")
# Out:
# ✅ AI_FOUNDRY_PROJECT_ENDPOINT: https://demopocaifoundry.services.ai.azure.com/api/projects/demoproject

# %% [markdown]
# ## Define Function Tools 🏦
#
# Let's define banking functions for our loan application discussions:

# %%
def get_loan_prequalification(
    loan_amount: Annotated[float, Field(description="Requested loan amount in dollars.")],
    credit_score: Annotated[int, Field(description="Customer's credit score.")],
    annual_income: Annotated[float, Field(description="Customer's annual income in dollars.")],
) -> str:
    """Check loan prequalification status based on customer data."""
    # Simple prequalification logic for demo
    dti = loan_amount / (annual_income * 30)  # Simplified debt-to-income estimate
    
    if credit_score >= 700 and dti < 0.43:
        status = "Pre-Qualified ✅"
        rate = "5.99% - 6.75%"
    elif credit_score >= 650 and dti < 0.50:
        status = "Conditionally Pre-Qualified ⚠️"
        rate = "7.25% - 8.50%"
    else:
        status = "Additional Review Required 📋"
        rate = "8.50% - 12.00%"
    
    return f"""Loan Pre-Qualification Result:
    Requested Amount: ${loan_amount:,.2f}
    Credit Score: {credit_score}
    Annual Income: ${annual_income:,.2f}
    Status: {status}
    Estimated Rate Range: {rate}"""


def get_required_documents(
    loan_type: Annotated[str, Field(description="Type of loan: mortgage, auto, personal")],
) -> str:
    """Get list of required documents for loan application."""
    docs = {
        "mortgage": [
            "Government-issued ID",
            "Pay stubs (last 30 days)",
            "W-2 forms (last 2 years)",
            "Tax returns (last 2 years)",
            "Bank statements (last 2 months)",
            "Proof of assets",
            "Property information"
        ],
        "auto": [
            "Government-issued ID",
            "Proof of income",
            "Proof of insurance",
            "Vehicle information (VIN, mileage)"
        ],
        "personal": [
            "Government-issued ID",
            "Proof of income",
            "Proof of residence"
        ]
    }
    loan_type = loan_type.lower()
    if loan_type in docs:
        doc_list = "\n    - ".join(docs[loan_type])
        return f"Required Documents for {loan_type.title()} Loan:\n    - {doc_list}"
    return "Please specify: mortgage, auto, or personal loan"

# %% [markdown]
# ## Create and Use Existing Thread 💬
#
# This example shows how to:
# 1. Create a thread that persists for the conversation
# 2. Use `agent.get_new_thread(service_thread_id=...)` to continue conversations
# 3. Properly clean up thread resources
#
# **Key API Methods**:
# - `agent.get_new_thread()` - Creates new thread (with optional `store=False`)
# - `agent.get_new_thread(service_thread_id=...)` - Uses existing thread

# %%
async def main() -> None:
    print("=== 💬 Azure AI Agent with Thread Management - Loan Application ===")

    async with (
        AzureCliCredential() as credential,
        AgentsClient(
            endpoint=os.environ["AI_FOUNDRY_PROJECT_ENDPOINT"],
            credential=credential
        ) as agents_client,
        AzureAIAgentsProvider(agents_client=agents_client) as provider,
    ):
        # Create a thread that will persist for the loan discussion
        created_thread = await agents_client.threads.create()
        print(f"✅ Created conversation thread: {created_thread.id}")

        try:
            agent = await provider.create_agent(
                name="LoanApplicationAdvisor",
                instructions="""You are a Loan Application Advisor. Help customers through the loan application process.
                Remember context from earlier in the conversation to provide personalized guidance.
                Be professional and thorough in explaining requirements.""",
                tools=[get_loan_prequalification, get_required_documents],
            )
            
            # Use existing thread for conversation continuity
            thread = agent.get_new_thread(service_thread_id=created_thread.id)
            assert thread.is_initialized
            print(f"✅ Thread initialized: {thread.is_initialized}")
            print(f"   Thread ID: {thread.service_thread_id}")
            
            # First message in loan application discussion
            query = "I'm interested in applying for a mortgage. Can you check if I'd prequalify for $350,000 with a credit score of 720 and annual income of $95,000?"
            print(f"\n🤔 Customer: {query}")
            result = await agent.run(query, thread=thread)
            print(f"🏦 Advisor: {result}")
            
        finally:
            # Clean up the thread
            await agents_client.threads.delete(created_thread.id)
            print(f"\n🗑️ Deleted thread: {created_thread.id}")

# %% [markdown]
# ## 🚀 Execute the Initial Loan Discussion

# %%
await main()
# Out:
# === 💬 Azure AI Agent with Thread Management - Loan Application ===
# ✅ Created conversation thread: thread_6SBWt8ZFbt3wlENySbqzKy7X
# ✅ Thread initialized: True
#    Thread ID: thread_6SBWt8ZFbt3wlENySbqzKy7X
#
# 🤔 Customer: I'm interested in applying for a mortgage. Can you check if I'd prequalify for $350,000 with a credit score of 720 and annual income of $95,000?
# 🏦 Advisor: Great news! Based on the details you provided, you are pre-qualified for a mortgage of $350,000. Here are the details:
#
# - **Requested Loan Amount:** $350,000
# - **Credit Score:** 720
# - **Annual Income:** $95,000
# - **Pre-Qualification Status:** Pre-Qualified ✅
# - **Estimated Interest Rate Range:** 5.99% - 6.75%
#
# Would you like me to guide you through the next steps, such as obtaining a list of required documents and starting the application process?
#
# 🗑️ Deleted thread: thread_6SBWt8ZFbt3wlENySbqzKy7X

# %% [markdown]
# ## 🔄 Multi-Turn Loan Application Flow with Thread Continuity

# %%
async def multi_turn_loan_application() -> None:
    """
    Demonstrates a complete multi-turn loan application conversation
    where thread context maintains the discussion history.
    """
    print("=== 💬 Multi-Turn Loan Application Workflow ===")
    
    async with (
        AzureCliCredential() as credential,
        AgentsClient(
            endpoint=os.environ["AI_FOUNDRY_PROJECT_ENDPOINT"],
            credential=credential
        ) as agents_client,
        AzureAIAgentsProvider(agents_client=agents_client) as provider,
    ):
        # Create persistent thread for entire loan application journey
        thread_info = await agents_client.threads.create()
        print(f"✅ Started loan application session: {thread_info.id}")
        
        try:
            advisor = await provider.create_agent(
                name="LoanApplicationAdvisor",
                instructions="""You are a comprehensive Loan Application Advisor. Guide customers through:
                1. Understanding loan options
                2. Prequalification assessment  
                3. Document requirements
                4. Next steps in the application process
                
                Remember the conversation context and reference earlier information when helpful.
                Be encouraging while being realistic about qualifications.""",
                tools=[get_loan_prequalification, get_required_documents],
            )
            
            # Use persistent thread
            thread = advisor.get_new_thread(service_thread_id=thread_info.id)
            
            # Loan application conversation flow
            conversation = [
                "Hi, I'm looking to buy my first home and need information about mortgage options.",
                "Can you check if I'd prequalify? My credit score is 680, annual income is $72,000, and I'm looking at homes around $280,000.",
                "Based on my prequalification status, what documents would I need for a conventional mortgage?",
                "Given my situation, would you recommend I improve my credit score first before applying?"
            ]
            
            for i, message in enumerate(conversation, 1):
                print(f"\n📩 Turn {i} - Customer: {message}")
                response = await advisor.run(message, thread=thread)
                print(f"🏦 Advisor: {response}")
                print("-" * 50)
                
        finally:
            await agents_client.threads.delete(thread_info.id)
            print(f"\n✅ Loan application session completed and cleaned up")

# %% [markdown]
# ## 🚀 Execute Multi-Turn Loan Application

# %%
await multi_turn_loan_application()
# Out:
# === 💬 Multi-Turn Loan Application Workflow ===
# ✅ Started loan application session: thread_M4ei7DhEn8wsGKnUZRogYcaD
#
# 📩 Turn 1 - Customer: Hi, I'm looking to buy my first home and need information about mortgage options.
# 🏦 Advisor: Congratulations on planning to purchase your first home! Navigating the world of mortgages can feel a bit overwhelming, but I’m here to guide you step by step. Let’s break this down into manageable pieces:
#
# ### 1. **Understanding Mortgage Loan Options**
# There are several types of mortgage loans available, and the best fit for you will depend on your financial situation and goals. Here are the most common options:
#
# - **Conventional Loans:** These are not insured by the federal government. They typically require a higher credit score and down payment but can have more flexible terms.
# - **FHA Loans:** Backed by the Federal Housing Administration, these are great for first-time homebuyers since they allow for lower credit scores and smaller down payments.
# - **VA Loans:** Exclusively for veterans, active-duty service members, and their spouses, these offer favorable terms, including no down payment and no private mortgage insurance (PMI).
# - **USDA Loans:** Designed for rural and suburban homebuyers, these offer low- or no-down-payment options for people meeting income limits.
# - **Jumbo Loans:** For homes that exceed the conforming loan limits set by the Federal Housing Finance Agency (usually higher-priced homes).
#
# #### Key Factors in Choosing a Mortgage:
# - Your credit score
# - The amount you can afford as a down payment
# - Your debt-to-income ratio (total debts compared to income)
# - Length of time you plan to stay in the home
#
# Would you like me to help you assess which mortgage might suit you best?
#
# ### 2. **Prequalification**
# Prequalification gives you an estimate of how much loan you may be approved for based on your financial details. Prequalification considers:
# - Loan amount desired
# - Credit score
# - Annual income
#
# If you’d like, I can assist with a quick assessment of your prequalification status for a mortgage loan.
#
# ### 3. **Document Requirements**
# Mortgage loans typically have detailed documentation requirements. These include:
# - Proof of income (e.g., pay stubs, W-2s, tax returns)
# - Proof of assets (bank statements, retirement accounts, etc.)
# - Credit history
# - Identification (driver’s license or passport)
# - Employment verification
# - Debt details (e.g., loan statements, credit card bills)
#
# I can get a detailed list of documents typically needed for mortgage loans if you'd like.
#
# ### 4. **Next Steps in the Process**
# Here’s an overview of what comes next:
# 1. Determine your budget (including down payment and monthly affordability).
# 2. Get prequalified with specific financial details (optional, to guide your home search).
# 3. Gather necessary documents for the lender.
# 4. Apply for a mortgage loan.
# 5. Work with the lender to secure approval while searching for your home.
#
# Let me know which steps you’d like to focus on first! If you want, we can start with prequalification or reviewing documentation requirements.
# --------------------------------------------------
#
# 📩 Turn 2 - Customer: Can you check if I'd prequalify? My credit score is 680, annual income is $72,000, and I'm looking at homes around $280,000.
# 🏦 Advisor: Based on your details, here’s the result of your prequalification:
#
# - **Loan Amount Requested:** $280,000
# - **Credit Score:** 680
# - **Annual Income:** $72,000
# - **Status:** **Conditionally Pre-Qualified** ⚠️
# - **Estimated Interest Rate Range:** 7.25% - 8.50%
#
# ### What "Conditionally Pre-Qualified" Means:
# You meet some of the basic criteria for a mortgage but may need to satisfy specific conditions, such as:
# - Providing a larger down payment (typically 5%-20%, depending on the lender).
# - Clarifying/decreasing existing debts to meet the debt-to-income ratio requirements.
# - Addressing any other factors in your financial profile upon closer review by a lender.
#
# ### Interest Rate and Terms:
# Your estimated interest rate range reflects the fact that your credit score is in the "good" range but not extremely high. A stronger credit score could reduce your interest rate, and thus your monthly payment.
#
# Would you like guidance on any of the following?
# 1. Down payment options or how to reduce interest rates
# 2. Getting the required documents ready
# 3. Finding the right type of mortgage based on these results
# --------------------------------------------------
#
# 📩 Turn 3 - Customer: Based on my prequalification status, what documents would I need for a conventional mortgage?
# 🏦 Advisor: For a conventional mortgage, here is the list of documents you’ll typically need to gather:
#
# 1. **Government-issued ID** - A valid form of identification, such as a driver’s license or passport.
# 2. **Pay Stubs** - Proof of income from the last 30 days showing year-to-date earnings.
# 3. **W-2 Forms** - Your W-2s from the previous 2 years to verify income and employment.
# 4. **Tax Returns** - Complete federal tax returns covering the past 2 years.
# 5. **Bank Statements** - Statements from the last 2 months for all accounts (checking, savings, etc.).
# 6. **Proof of Assets** - Documentation showing other assets, like retirement accounts, investment accounts, or down payment funds.
# 7. **Property Information** - If you’ve chosen a property, documents such as purchase contracts, property appraisals, or listings may be required.
#
# It’s a good idea to start gathering these now to streamline the process once you’re ready to formally apply. If you have any questions about specific documents or need tips to strengthen your application, let me know!
#
# Would you like recommendations on how to prepare these documents or any help estimating your down payment?
# --------------------------------------------------
#
# 📩 Turn 4 - Customer: Given my situation, would you recommend I improve my credit score first before applying?
# 🏦 Advisor: Great question! While you are **conditionally prequalified** for a mortgage based on your current credit score of 680, improving it could result in substantial benefits. Here's a breakdown of whether you should wait to apply while improving your credit:
#
# ---
#
# ### **What Raising Your Credit Score Could Do for You**
# 1. **Lower Interest Rates**
#    Mortgage lenders typically offer better interest rates to borrowers with higher credit scores. A small increase in your score could drop your interest rate below the estimated 7.25%-8.50% range, reducing your monthly payment and long-term costs.
#    For example:
#    - On a $280,000 loan, lowering your rate by 0.5% could save you about **$80-$100/month**.
#
# 2. **Stronger Loan Approval Terms**
#    A higher credit score could also result in less scrutiny of your financial profile (like requiring less down payment) and a smoother approval process.
#
# 3. **Savings on Insurance**
#    Private Mortgage Insurance (PMI) is typically required if you put less than 20% down. The amount you pay for PMI is also influenced by your credit score.
#
# ---
#
# ### **Does It Make Sense for You to Improve Now?**
# - **How urgent is buying your home?**
#    - If you're flexible on timing, it may be worth waiting and working to improve your credit over the next 6-12 months.
#    - If you need a home soon, you can still move forward and focus on securing favorable terms by shopping around with different lenders.
#
# - **Credit Improvement Potential**
#    - A credit score of 680 is considered "good," but crossing into the **700+ range** moves you into "very good" territory, which could result in noticeable benefits.
#    - If you believe you can raise your score by paying off debts, reducing credit utilization, or addressing late payments, it may be worth the short-term delay.
#
# ---
#
# ### **Recommendations for Improving Your Credit**
# 1. **Reduce Credit Utilization**: Aim to keep your credit card balances below 30% of their limits.
# 2. **Pay Bills on Time**: Continue to make all payments by their due dates—it has the biggest impact on your score.
# 3. **Review Your Credit Report**: Ensure there are no errors or negative marks that can be disputed.
# 4. **Avoid New Credit**: Don’t open or close credit accounts while trying to increase your score.
# 5. **Build a History**: If you have older accounts, keep them active to show a lengthy credit history.
#
# ---
#
# ### **My Advice for You**
# If you’re not in a rush, raising your score just 20-40 points could help you save thousands of dollars over the life of the loan. I’d recommend spending a few months improving your score before applying if possible.
#
# However, if the housing market or your personal timeline doesn’t allow for a delay, you can proceed now! Many lenders work with buyers at your score, and I can also guide you on reducing upfront costs to make the application process more comfortable.
#
# Let me know how you’d like to move forward! Would you like me to help strategize building your credit, or do you feel ready to apply now?
# --------------------------------------------------
#
# ✅ Loan application session completed and cleaned up

# %% [markdown]
# ## 📝 Key Takeaways
#
# ### Thread Management in Applications
#
# 1. **Thread Persistence**: Threads maintain conversation context across multiple interactions, essential for complex multi-turn discussions
#
# 2. **Creating Threads**: Use `AgentsClient` to create threads before agent interactions:
#    ```python
#    created_thread = await agents_client.threads.create()
#    ```
#
# 3. **Using Existing Threads**: Connect agent to existing thread for conversation continuity:
#    ```python
#    thread = agent.get_new_thread(service_thread_id=created_thread.id)
#    ```
#
# 4. **Thread Lifecycle**: Always clean up threads when conversation is complete:
#    ```python
#    await agents_client.threads.delete(thread_id)
#    ```
#
# ### Use Case Benefits
#
# - **Compliance**: Persistent threads create audit trails for regulatory compliance
# - **Customer Experience**: Customers don't need to repeat information
# - **Context-Aware Responses**: Agents can reference earlier parts of the conversation
# - **Multi-Step Processes**: Perfect for loan applications, account onboarding, and consultations
#
# ### ⚠️ Disclaimer
# This example uses simulated data for demonstration purposes. In production:
# - Connect to actual backend systems
# - Implement proper authentication and authorization
# - Follow all regulatory requirements
# - Ensure compliance for sensitive data
