# %% [markdown]
# # 🏦 Investment Portfolio Review with Streaming Workflow
#
# ## Overview
#
# This notebook demonstrates **streaming workflows** using Azure OpenAI Chat Agents for a **portfolio review** scenario. Watch real-time responses as two specialized agents analyze an investment portfolio.
#
# ### 💼 Industry Use Case: Portfolio Analysis Pipeline
#
# A customer requests a review of their investment portfolio:
# 1. **Portfolio Analyst Agent** - Analyzes the portfolio composition and performance
# 2. **Risk Advisor Agent** - Evaluates risk factors and provides recommendations (streaming output)
#
# ### ⚠️ Important Financial Disclaimer
# > **This notebook is for educational and demonstration purposes only.** The investment analysis shown is simplified and should not be used for actual investment decisions. Always consult licensed financial advisors.
#
# ### Key Concepts
#
# | Concept | Description |
# |---------|-------------|
# | **Azure OpenAI Integration** | Direct Azure OpenAI Service connectivity |
# | **Real-time Streaming** | `AgentRunUpdateEvent` provides token-by-token updates |
# | **output_response=True** | Marks terminal agent whose output is captured |
# | **WorkflowBuilder** | Fluent API for agent workflow construction |
#
# ### Architecture
#
# ```
# Customer Portfolio Request
#     ↓
# Portfolio Analyst Agent (composition analysis)
#     ↓ streaming
# Risk Advisor Agent (risk assessment & recommendations)
#     ↓ streaming
# Final Investment Guidance
# ```
#
# ## Prerequisites
#
# - ✅ Azure OpenAI Service configured
# - ✅ Environment variables: `AZURE_OPENAI_ENDPOINT`, `AZURE_OPENAI_CHAT_DEPLOYMENT_NAME`
# - ✅ Azure CLI authentication: Run `az login`

# %% [markdown]
# ## 1️⃣ Setup and Imports

# %%
import asyncio

from agent_framework import AgentRunUpdateEvent, WorkflowBuilder, WorkflowOutputEvent
from agent_framework.azure import AzureOpenAIChatClient
from azure.identity import AzureCliCredential
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv('../../.env')
# Out:
# True

# %%
# Create Azure OpenAI chat client
endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
deployment_name = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")
chat_client = AzureOpenAIChatClient(
    deployment_name=deployment_name,
    endpoint=endpoint,
    credential=AzureCliCredential()
)
print("✅ Azure OpenAI Chat Client created")
# Out:
# ✅ Azure OpenAI Chat Client created

# %% [markdown]
# ## 2️⃣ Create Portfolio Analysis Agents
#
# ### 📊 Portfolio Analyst Agent
# - Analyzes portfolio composition and allocation
# - Evaluates diversification and performance
# - First in the sequence
#
# ### ⚠️ Risk Advisor Agent
# - Assesses risk factors based on analyst's findings
# - Provides actionable recommendations
# - Terminal agent with `output_response=True`

# %%
# Portfolio Analyst Agent - Analyzes portfolio composition
portfolio_analyst = chat_client.as_agent(
    instructions=(
        "You are a Portfolio Analyst at an investment firm.\n"
        "When reviewing a portfolio:\n"
        "1. Analyze asset allocation (stocks, bonds, cash, alternatives)\n"
        "2. Evaluate sector diversification\n"
        "3. Note concentration risks\n"
        "4. Comment on overall portfolio balance\n"
        "Keep your analysis concise and data-driven."
    ),
    name="portfolio_analyst",
)
print("✅ Portfolio Analyst Agent created")
# Out:
# ✅ Portfolio Analyst Agent created

# %%
# Risk Advisor Agent - Evaluates risk and provides recommendations
risk_advisor = chat_client.as_agent(
    instructions=(
        "You are a Risk Advisor at an investment firm.\n"
        "Based on the portfolio analysis:\n"
        "1. Assess overall risk level (Conservative/Moderate/Aggressive)\n"
        "2. Identify key risk factors\n"
        "3. Provide 2-3 specific recommendations to improve the portfolio\n"
        "4. Include standard investment disclaimers\n"
        "Be concise and actionable."
    ),
    name="risk_advisor",
)
print("✅ Risk Advisor Agent created")
# Out:
# ✅ Risk Advisor Agent created

# %% [markdown]
# ## 3️⃣ Build Streaming Workflow

# %%
# Build workflow: Portfolio Analyst → Risk Advisor
workflow = (
    WorkflowBuilder()
    .add_agent(portfolio_analyst, id="PortfolioAnalyst")
    .add_agent(risk_advisor, id="RiskAdvisor", output_response=True)
    .set_start_executor(portfolio_analyst)
    .add_edge(portfolio_analyst, risk_advisor)
    .build()
)
print("✅ Workflow built: Portfolio Analyst → Risk Advisor")
# Out:
# C:\Users\gabhardwaj\AppData\Local\Temp\ipykernel_5148\4005554970.py:4: DeprecationWarning: Use register_agent() for lazy initialization instead.
#   .add_agent(portfolio_analyst, id="PortfolioAnalyst")
# Adding an agent instance directly to WorkflowBuilder is not recommended, because workflow instances created from the builder will share the same agent instance. Consider using register_agent() for lazy initialization instead.
# C:\Users\gabhardwaj\AppData\Local\Temp\ipykernel_5148\4005554970.py:5: DeprecationWarning: Use register_agent() for lazy initialization instead.
#   .add_agent(risk_advisor, id="RiskAdvisor", output_response=True)
# Adding an agent instance directly to WorkflowBuilder is not recommended, because workflow instances created from the builder will share the same agent instance. Consider using register_agent() for lazy initialization instead.
# ✅ Workflow built: Portfolio Analyst → Risk Advisor

# %% [markdown]
# ## 4️⃣ Submit Portfolio for Review with Streaming
#
# Watch both agents analyze the portfolio in real-time!

# %%
# Customer portfolio review request
portfolio_request = """
Please review my investment portfolio:

PORTFOLIO SUMMARY
=================
Total Value: $250,000

ASSET ALLOCATION:
- US Large Cap Stocks: 45% ($112,500)
- US Small Cap Stocks: 15% ($37,500)
- International Stocks: 10% ($25,000)
- Bonds: 20% ($50,000)
- Cash: 10% ($25,000)

TOP HOLDINGS:
1. Apple (AAPL) - 12%
2. Microsoft (MSFT) - 10%
3. Amazon (AMZN) - 8%
4. Nvidia (NVDA) - 7%
5. Tesla (TSLA) - 5%

INVESTOR PROFILE:
- Age: 35
- Risk Tolerance: Moderate
- Time Horizon: 20+ years (retirement)
"""

print("📊 PORTFOLIO REVIEW REQUEST")
print("=" * 60)
print(portfolio_request)
print("=" * 60 + "\n")

last_executor_id: str | None = None

events = workflow.run_stream(portfolio_request)
async for event in events:
    if isinstance(event, AgentRunUpdateEvent):
        eid = event.executor_id
        if eid != last_executor_id:
            if last_executor_id is not None:
                print()
            agent_emoji = "📊" if "Analyst" in eid else "⚠️"
            print(f"\n{agent_emoji} {eid}:", end=" ", flush=True)
            last_executor_id = eid
        print(event.data, end="", flush=True)
    elif isinstance(event, WorkflowOutputEvent):
        print("\n\n" + "=" * 60)
        print("📋 FINAL INVESTMENT GUIDANCE")
        print("=" * 60)
        print(event.data)

print("\n" + "=" * 60)
print("✅ Portfolio review complete!")
print("\n⚠️ DISCLAIMER: This analysis is for educational purposes only.")
print("   Always consult a licensed financial advisor for investment decisions.")
# Out:
# 📊 PORTFOLIO REVIEW REQUEST
# ============================================================
#
# Please review my investment portfolio:
#
# PORTFOLIO SUMMARY
# =================
# Total Value: $250,000
#
# ASSET ALLOCATION:
# - US Large Cap Stocks: 45% ($112,500)
# - US Small Cap Stocks: 15% ($37,500)
# - International Stocks: 10% ($25,000)
# - Bonds: 20% ($50,000)
# - Cash: 10% ($25,000)
#
# TOP HOLDINGS:
# 1. Apple (AAPL) - 12%
# 2. Microsoft (MSFT) - 10%
# 3. Amazon (AMZN) - 8%
# 4. Nvidia (NVDA) - 7%
# 5. Tesla (TSLA) - 5%
#
# INVESTOR PROFILE:
# - Age: 35
# - Risk Tolerance: Moderate
# - Time Horizon: 20+ years (retirement)
#
# ============================================================
#
#
# 📊 PortfolioAnalyst: **Portfolio Analysis:**
#
# 1. **Asset Allocation**:
#    - **Stocks (70%)**: The heavier allocation to equities (US Large Cap 45%, US Small Cap 15%, International 10%) aligns with a moderate risk tolerance and long time horizon. However, international exposure (10%) is below typical recommendations (15%-20%) for diversification.
#    - **Bonds (20%)**: A conservative position in fixed income balances equity risk, which is appropriate for a moderate investor.
#    - **Cash (10%)**: Holding 10% in cash is slightly high for a 20+ year horizon, where deploying more into growth-oriented areas might improve long-term returns.
#
# 2. **Sector Diversification**:
#    - The portfolio is heavily concentrated in technology (AAPL, MSFT, AMZN, NVDA, TSLA), with approximately 42% of total assets in just five stocks. Adding exposure to other sectors (e.g., healthcare, consumer staples) would enhance diversification.
#
# 3. **Concentration Risks**:
#    - The top five holdings comprise a significant 42% of the portfolio, creating concentration risk. AAPL (12%) and MSFT (10%) exceed the typical recommendation of keeping individual stocks below 5%-10% of total portfolio value.
#
# 4. **Overall Balance**:
#    - The portfolio is growth-oriented but skewed heavily toward US equities (70%) and, more specifically, large-cap technology stocks. Greater diversification across asset classes (more international exposure, alternative investments if desired) and sectors would improve balance and reduce risk.
#
# **Recommendations**:
#    - Increase international stock allocation (closer to 15%-20%) for geographical diversification.
#    - Reduce concentrated positions in top technology names to lower single-stock risk.
#    - Consider reallocating a portion of cash toward underweighted asset classes or sectors with growth potential.
#    - Maintain bond exposure as a buffer against volatility.
#
# The portfolio is well-aligned with the investor’s age, risk tolerance, and time horizon but would benefit from improved diversification to better manage risk while still taking advantage of long-term growth opportunities.
#
# ⚠️ RiskAdvisor: **Portfolio Risk Assessment:**
# - **Risk Level:** Moderate (Growth-focused but concentrated in tech and U.S. equities)
#
# **Key Risk Factors:**
# 1. High concentration in U.S. large-cap tech stocks (42% in top holdings).
# 2. Low international exposure adds geographical risk.
# 3. Excess cash drag (10%) could hinder long-term growth.
#
# **Recommendations:**
# 1. **Diversify Sector Exposure:** Reduce AAPL/MSFT positions to below 8% each and reinvest in underrepresented sectors such as healthcare or consumer staples for stability and growth.
# 2. **Increase International Allocation:** Raise international stocks to 15%-20% for better geographical balance—consider emerging markets ETFs or funds.
# 3. **Deploy Excess Cash:** Allocate some cash toward higher-growth opportunities or dollar-cost average into broadly diversified equity or bond funds.
#
# **Investment Disclaimer:** Past performance is not indicative of future results. All investments carry risks, including the risk of loss. Consider consulting a financial advisor for personalized advice tailored to your specific circumstances.
#
# ============================================================
# 📋 FINAL INVESTMENT GUIDANCE
# ============================================================
# **Portfolio Risk Assessment:**
# - **Risk Level:** Moderate (Growth-focused but concentrated in tech and U.S. equities)
#
# **Key Risk Factors:**
# 1. High concentration in U.S. large-cap tech stocks (42% in top holdings).
# 2. Low international exposure adds geographical risk.
# 3. Excess cash drag (10%) could hinder long-term growth.
#
# **Recommendations:**
# 1. **Diversify Sector Exposure:** Reduce AAPL/MSFT positions to below 8% each and reinvest in underrepresented sectors such as healthcare or consumer staples for stability and growth.
# 2. **Increase International Allocation:** Raise international stocks to 15%-20% for better geographical balance—consider emerging markets ETFs or funds.
# 3. **Deploy Excess Cash:** Allocate some cash toward higher-growth opportunities or dollar-cost average into broadly diversified equity or bond funds.
#
# **Investment Disclaimer:** Past performance is not indicative of future results. All investments carry risks, including the risk of loss. Consider consulting a financial advisor for personalized advice tailored to your specific circumstances.
#
# ============================================================
# ✅ Portfolio review complete!
#
# ⚠️ DISCLAIMER: This analysis is for educational purposes only.
#    Always consult a licensed financial advisor for investment decisions.
