# %% [markdown]
# # 📊 Agent Telemetry & Tracing for Wealth Management Advisory
#
# This notebook demonstrates how to implement **telemetry and tracing** for AI agents using Azure Monitor and OpenTelemetry. We'll build a **Wealth Management Advisory Agent** that provides investment guidance while capturing detailed traces for monitoring, debugging, and compliance.
#
# ## 🎯 Learning Objectives
#
# 1. **Configure Azure Monitor** for agent telemetry
# 2. **Enable content recording** to capture prompts and responses
# 3. **Create custom trace spans** for business-specific context
# 4. **View traces** in Microsoft Foundry and Application Insights
# 5. **Understand trace data** for compliance and debugging
#
# ## 💼 Industry Use Case: Wealth Management Advisory
#
# In wealth management, telemetry is critical for:
# - **Regulatory Compliance**: Track all advisor-client interactions
# - **Audit Trail**: Maintain records of investment recommendations
# - **Performance Monitoring**: Measure response times and quality
# - **Risk Management**: Detect anomalies in agent behavior
#
# ### ⚠️ Financial Disclaimer
# > **The financial information provided is for educational purposes only and is not investment advice.** Always consult with qualified financial advisors before making investment decisions.
#
# <img src="./seq-diagrams/1-observability.png" width="75%"/>

# %% [markdown]
# ## 🔐 Authentication Setup
#
# Before running this notebook, authenticate with Azure CLI:
#
# ```bash
# az login --use-device-code
# ```
#
# This provides browser-based authentication useful for remote environments and corporate security policies.

# %% [markdown]
# ## 1. Environment Setup & Configuration
#
# We'll load environment variables and set up the telemetry configuration **before** creating any clients.

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

# Load environment variables from .env file
notebook_path = Path().absolute()
env_path = notebook_path.parent / '.env'
load_dotenv(env_path)

# Verify required environment variables
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")
tenant_id = os.environ.get("TENANT_ID")
model_deployment = os.environ.get("AZURE_AI_MODEL_DEPLOYMENT_NAME", "gpt-4o")

if not project_endpoint:
    raise ValueError("🚨 AI_FOUNDRY_PROJECT_ENDPOINT not set in .env")

print(f"🔑 Tenant ID: {tenant_id}")
print(f"📍 Project Endpoint: {project_endpoint[:50]}...")
print(f"🤖 Model Deployment: {model_deployment}")
# Out:
# 🔑 Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3
# 📍 Project Endpoint: https://demopocaifoundry.services.ai.azure.com/api...
# 🤖 Model Deployment: gpt-4o

# %% [markdown]
# ## 2. Enable Content Recording for Telemetry
#
# **Important**: Set the environment variable to capture message content (prompts and responses) **before** any instrumentation. This is essential for compliance auditing in FSI.
#
# ⚠️ **Privacy Note**: Content recording may capture personal data. Use with caution in production.

# %%
# Enable content recording BEFORE any instrumentation
os.environ["AZURE_TRACING_GEN_AI_CONTENT_RECORDING_ENABLED"] = "true"

print("✅ Content recording enabled for telemetry")
print("📝 Prompts and responses will be captured in traces")
# Out:
# ✅ Content recording enabled for telemetry
# 📝 Prompts and responses will be captured in traces

# %% [markdown]
# ## 3. Configure Azure Monitor Tracing
#
# Azure Monitor with OpenTelemetry provides:
# - Distributed tracing across agent calls
# - Performance metrics and latency tracking
# - Integration with Application Insights
# - Visualization in Microsoft Foundry portal

# %%
from azure.monitor.opentelemetry import configure_azure_monitor
from azure.identity import AzureCliCredential
from azure.ai.projects import AIProjectClient
from opentelemetry import trace

# First, create a temporary client to get the Application Insights connection string
temp_credential = AzureCliCredential(tenant_id=tenant_id)
temp_client = AIProjectClient(endpoint=project_endpoint, credential=temp_credential)

# Get Application Insights connection string from the AI Project
# Using the correct method from Azure SDK samples
app_insights_connection = os.environ.get("APPLICATIONINSIGHTS_CONNECTION_STRING")

if not app_insights_connection:
    # Get connection string from AI Project telemetry (correct method name)
    try:
        app_insights_connection = temp_client.telemetry.get_application_insights_connection_string()
        print(f"✅ Retrieved Application Insights connection from AI Project")
    except Exception as e:
        print(f"⚠️ Could not get connection string from project: {e}")

# Configure Azure Monitor for tracing
if app_insights_connection:
    configure_azure_monitor(connection_string=app_insights_connection)
    print(f"✅ Azure Monitor configured with Application Insights")
else:
    print("⚠️ No Application Insights connection - traces will not be exported")
    print("   Add APPLICATIONINSIGHTS_CONNECTION_STRING to .env or configure in AI Foundry")

# Get a tracer for creating custom spans
tracer = trace.get_tracer("wealth-management-advisor")
print(f"✅ Tracer initialized: wealth-management-advisor")
# Out:
# ✅ Retrieved Application Insights connection from AI Project
# ✅ Azure Monitor configured with Application Insights
# ✅ Tracer initialized: wealth-management-advisor

# %% [markdown]
# ## 4. Initialize AI Project Client with Tracing
#
# Now we create the AIProjectClient. With Azure Monitor configured, all agent calls will be automatically traced.

# %%
from azure.ai.projects.models import PromptAgentDefinition

# Reuse the client created during telemetry setup (with tracing now configured)
project_client = temp_client
credential = temp_credential

print("✅ AIProjectClient ready with tracing enabled")
# Out:
# ✅ AIProjectClient ready with tracing enabled

# %% [markdown]
# ## 5. Create Wealth Management Advisory Agent
#
# We'll create an agent specialized in wealth management that provides investment guidance with appropriate disclaimers. The agent creation and all interactions will be traced.

# %%
def create_wealth_advisor_agent():
    """Create a wealth management advisory agent with compliance-focused instructions."""
    
    # Create a custom span for agent creation
    with tracer.start_as_current_span("create_wealth_advisor") as span:
        span.set_attribute("agent.type", "wealth_management")
        span.set_attribute("agent.model", model_deployment)
        
        try:
            agent = project_client.agents.create_version(
                agent_name="wealth-management-advisor",
                definition=PromptAgentDefinition(
                    model=model_deployment,
                    instructions="""
                    You are a Wealth Management Advisory Assistant for high-net-worth clients.
                    
                    Your responsibilities:
                    1. Provide educational information about investment strategies, asset allocation, and portfolio diversification.
                    2. Explain financial concepts like risk tolerance, market volatility, tax-efficient investing, and estate planning.
                    3. Discuss different asset classes: equities, fixed income, alternatives, and real estate.
                    4. Always include appropriate disclaimers about investment risks.
                    5. Recommend consulting with a licensed financial advisor for personalized advice.
                    6. Never provide specific stock picks or guarantee investment returns.
                    7. Consider client risk profiles when discussing investment options.
                    
                    IMPORTANT DISCLAIMERS:
                    - Past performance does not guarantee future results
                    - All investments carry risk including potential loss of principal
                    - This is educational information, not personalized investment advice
                    """
                )
            )
            
            # Add trace attributes for successful creation
            span.set_attribute("agent.name", agent.name)
            span.set_attribute("agent.version", agent.version)
            span.set_attribute("agent.status", "created")
            
            print(f"🎉 Created Wealth Management Advisor (name: {agent.name}, version: {agent.version})")
            return agent
            
        except Exception as e:
            span.set_attribute("agent.status", "failed")
            span.set_attribute("error.message", str(e))
            print(f"❌ Error creating agent: {e}")
            return None

# Create the wealth advisor agent
wealth_advisor = create_wealth_advisor_agent()
# Out:
# 🎉 Created Wealth Management Advisor (name: wealth-management-advisor, version: 1)

# %% [markdown]
# ## 6. Chat Function with Custom Tracing
#
# We'll create a chat function that adds business-specific trace attributes for compliance and monitoring. Each client interaction will include:
# - Client profile information
# - Query category (portfolio, retirement, tax, etc.)
# - Response metrics

# %%
import time

def chat_with_wealth_advisor(user_question: str, client_id: str = "CLIENT-001", query_category: str = "general"):
    """
    Chat with the wealth advisor agent with full tracing.
    
    Args:
        user_question: The client's question
        client_id: Client identifier for compliance tracking
        query_category: Category of query (portfolio, retirement, tax, risk, general)
    """
    
    if not wealth_advisor:
        print("❌ No agent available. Please create an agent first.")
        return None
    
    # Create a custom span for the advisory interaction
    with tracer.start_as_current_span("wealth_advisory_interaction") as span:
        # Add business-specific attributes for compliance
        span.set_attribute("client.id", client_id)
        span.set_attribute("query.category", query_category)
        span.set_attribute("query.length", len(user_question))
        span.set_attribute("agent.name", wealth_advisor.name)
        
        start_time = time.time()
        
        try:
            print(f"👤 Client [{client_id}]: {user_question}")
            print(f"📂 Category: {query_category}")
            print("🔄 Processing...")
            
            # Get the OpenAI client from project client
            openai_client = project_client.get_openai_client()
            
            # Call the agent - this is automatically traced
            response = openai_client.responses.create(
                extra_body={
                    "agent": {
                        "type": "agent_reference",
                        "name": wealth_advisor.name,
                        "version": wealth_advisor.version
                    }
                },
                input=user_question
            )
            
            # Calculate response time
            response_time = time.time() - start_time
            
            # Add response metrics to trace
            span.set_attribute("response.time_ms", int(response_time * 1000))
            span.set_attribute("response.status", "success")
            
            if response.output_text:
                span.set_attribute("response.length", len(response.output_text))
                print(f"\n🤖 Advisor: {response.output_text}")
                print(f"\n⏱️ Response time: {response_time:.2f}s")
                return response.output_text
            else:
                span.set_attribute("response.status", "empty")
                print("❌ No response from advisor")
                return None
                
        except Exception as e:
            response_time = time.time() - start_time
            span.set_attribute("response.time_ms", int(response_time * 1000))
            span.set_attribute("response.status", "error")
            span.set_attribute("error.message", str(e))
            print(f"❌ Error: {e}")
            return None

print("✅ Chat function with tracing defined")
# Out:
# ✅ Chat function with tracing defined

# %% [markdown]
# ## 7. Test Advisory Interactions with Tracing
#
# Let's run several advisory interactions. Each will generate traces that you can view in Microsoft Foundry or Application Insights.

# %%
print("🧪 Testing Wealth Management Advisory with Telemetry")
print("=" * 60)

# Test 1: Portfolio Allocation Question
print("\n📊 Test 1: Portfolio Allocation")
print("-" * 40)
response1 = chat_with_wealth_advisor(
    user_question="I'm 45 years old with a moderate risk tolerance. How should I think about allocating my portfolio between stocks and bonds?",
    client_id="HNW-2024-001",
    query_category="portfolio"
)
# Out:
# 🧪 Testing Wealth Management Advisory with Telemetry
# ============================================================
#
# 📊 Test 1: Portfolio Allocation
# ----------------------------------------
# 👤 Client [HNW-2024-001]: I'm 45 years old with a moderate risk tolerance. How should I think about allocating my portfolio between stocks and bonds?
# 📂 Category: portfolio
# 🔄 Processing...
# ❌ Error: Error code: 400 - {'error': {'code': 'invalid_payload', 'message': "The 'agent' property is deprecated. Use 'agent_reference' instead.", 'param': 'agent', 'type': 'invalid_request_error', 'details': [], 'additionalInfo': {'request_id': '2f01ff9cea2731a1ed77947cca7f5051'}}}

# %%
# Test 2: Retirement Planning Question
print("\n🏖️ Test 2: Retirement Planning")
print("-" * 40)
response2 = chat_with_wealth_advisor(
    user_question="What's the difference between a Traditional IRA and a Roth IRA? Which might be better for someone in a high tax bracket?",
    client_id="HNW-2024-002",
    query_category="retirement"
)
# Out:
# 🏖️ Test 2: Retirement Planning
# ----------------------------------------
# 👤 Client [HNW-2024-002]: What's the difference between a Traditional IRA and a Roth IRA? Which might be better for someone in a high tax bracket?
# 📂 Category: retirement
# 🔄 Processing...
#
# 🤖 Advisor: Great question! Understanding the differences between a **Traditional IRA** and a **Roth IRA** is crucial for tax-efficient retirement planning. Here’s a breakdown of the two, followed by considerations for someone in a high tax bracket:
#
# ---
#
# ### **Traditional IRA**
# 1. **Tax Treatment**:
#    - Contributions are often **tax-deductible** (subject to income and workplace retirement plan participation). This means you may reduce your taxable income in the year of contribution.
#    - Growth is **tax-deferred**, meaning you don’t pay taxes on dividends, interest, or capital gains while the money is in the account.
#    - **Withdrawals** in retirement are taxed as ordinary income.
#
# 2. **Income Limits**:
#    - No income limits to contribute, but the deductibility of contributions may phase out at higher incomes.
#
# 3. **Required Minimum Distributions (RMDs)**:
#    - You must start taking RMDs at age 73 (as of 2023), whether you need the funds or not.
#
# 4. **Best For**:
#    - Individuals who expect to be in a lower tax bracket in retirement, as they’ll pay less tax on withdrawals than they saved when deferring taxes initially.
#
# ---
#
# ### **Roth IRA**
# 1. **Tax Treatment**:
#    - Contributions are made with **after-tax dollars**, so there’s no immediate tax deduction.
#    - Growth is **tax-free**, and qualified withdrawals (e.g., after age 59½ and meeting a five-year holding period) are also tax-free.
#    - No taxes on earnings or withdrawals in retirement, so Roth dollars are particularly beneficial in a high-tax future.
#
# 2. **Income Limits**:
#    - Contributions are phased out or eliminated for high-income earners (e.g., in 2023, single filers with modified adjusted gross income over $153,000 and married filers over $228,000 can’t contribute directly). However, you may explore a **Backdoor Roth IRA** strategy (consult a tax advisor for details).
#
# 3. **Required Minimum Distributions (RMDs)**:
#    - None for the original account holder during their lifetime, making it attractive for long-term tax-free growth or estate planning.
#
# 4. **Best For**:
#    - People who expect to be in the same or a higher tax bracket during retirement, since they’re locking in today’s tax rate on contributions.
#
# ---
#
# ### **Which Might Be Better for Someone in a High Tax Bracket?**
#
# If you’re in a high tax bracket today, here are some considerations when deciding between the two accounts:
#
# 1. **Traditional IRA**:
#    - You might prioritize immediate tax deductions if you want to reduce your current taxable income, as this can create significant savings when you're in a high tax bracket.
#    - However, remember that the tax rate on future withdrawals depends on what tax bracket you fall into during retirement. If you think your income/tax rate will decrease in retirement, the Traditional IRA could be advantageous.
#
# 2. **Roth IRA**:
#    - If future taxes are likely to increase (either personally or due to rising tax laws), a Roth IRA can protect you from paying those higher rates on both earnings and withdrawals in retirement.
#    - While you don’t get a tax benefit now, the tax-free growth and withdrawals in the future could potentially save more, especially if you anticipate a high level of taxable income even during retirement.
#
# 3. **Strategic Approach**:
#    - Some high-income earners may pursue a combination of accounts: making deductible contributions to a Traditional IRA if eligible, utilizing employer-sponsored plans like a 401(k) with employer matches, and considering a **Backdoor Roth IRA** conversion for additional Roth funds.
#
# ---
#
# ### **Key Considerations for High-Income Earners**:
# - Be mindful of **current vs. future tax rates**.
# - Explore **Backdoor Roth IRA** conversions if ineligible to contribute directly to a Roth IRA.
# - Complement these IRAs with employer-sponsored or other tax-advantaged plans, like a 401(k), to maximize tax efficiency.
# - Assess **estate planning goals**: Roth IRAs can be tax-efficient for passing wealth to heirs since RMDs don’t apply to the original owner.
#
# ---
#
# ### **Conclusion**:
# The best choice depends on your specific financial circumstances, tax planning goals, and retirement outlook. For someone in a high tax bracket, the decision often balances between enjoying a tax deduction today (Traditional IRA) versus securing tax-free growth for the future (Roth IRA). Consulting with a licensed financial advisor or tax professional can help tailor a strategy to your unique situation.
#
# ---
#
# **Disclaimers**:
# - Tax laws and contribution limits can change. Stay updated to comply with current rules.
# - All investments carry risks. Consider speaking with a licensed financial advisor for tailored guidance.
#
#
#
# ⏱️ Response time: 15.26s

# %%
# Test 3: Tax-Efficient Investing
print("\n💰 Test 3: Tax-Efficient Investing")
print("-" * 40)
response3 = chat_with_wealth_advisor(
    user_question="What strategies can help minimize taxes on investment gains? I have both taxable and tax-advantaged accounts.",
    client_id="HNW-2024-003",
    query_category="tax"
)
# Out:
# 💰 Test 3: Tax-Efficient Investing
# ----------------------------------------
# 👤 Client [HNW-2024-003]: What strategies can help minimize taxes on investment gains? I have both taxable and tax-advantaged accounts.
# 📂 Category: tax
# 🔄 Processing...
#
# 🤖 Advisor: Minimizing taxes on investment gains is an important element of effective wealth management. Here are strategies to help reduce your tax burden while staying compliant with tax laws. Remember, these strategies should be reviewed with your financial and tax advisors to ensure they align with your specific circumstances:
#
# ---
#
# ### 1. **Utilize Tax-Advantaged Accounts**
#    - **Retirement Accounts:** Contributions to accounts like 401(k)s, IRAs (Traditional or Roth), and similar retirement vehicles can provide significant tax benefits.
#      - *Traditional IRA/401(k):* Contributions may be tax-deductible, and earnings grow tax-deferred until withdrawal.
#      - *Roth IRA/401(k):* Contributions are made with after-tax dollars, but qualified withdrawals in retirement are tax-free.
#    - **Health Savings Account (HSA):**
#      - Offers triple tax benefits: contributions are tax-deductible or pre-tax, earnings grow tax-free, and withdrawals for qualified medical expenses are also tax-free.
#
# ---
#
# ### 2. **Asset Location**
#    - Hold tax-inefficient investments in tax-advantaged accounts and tax-efficient investments in taxable accounts.
#      - **Tax-Inefficient Investments:** Bonds, Real Estate Investment Trusts (REITs), and actively managed funds tend to generate significant taxable income. Consider holding these in tax-advantaged accounts to avoid high annual tax bills.
#      - **Tax-Efficient Investments:** Broad stock index funds, ETFs, and municipal bonds typically generate lower taxable income, making them better suited for taxable accounts.
#
# ---
#
# ### 3. **Tax-Loss Harvesting**
#    - Offset taxable capital gains by selling investments at a loss. Losses can also offset up to $3,000 of ordinary income annually.
#    - Keep IRS rules in mind, including the **"wash sale rule,"** which disallows tax benefits if you repurchase the same or a substantially identical security within 30 days before or after the sale.
#
# ---
#
# ### 4. **Be Strategic About Capital Gains**
#    - Take advantage of lower long-term capital gains tax rates by holding securities for more than a year before selling.
#    - Consider spreading the realization of large gains over multiple tax years to avoid higher tax brackets.
#
# ---
#
# ### 5. **Maximize Tax-Deductible Contributions**
#    - Max out contributions to deductible retirement accounts such as a 401(k) or IRA to reduce current-year taxable income.
#    - Self-employed individuals may consider options like SEP IRAs or Solo 401(k)s for higher limits on deductible contributions.
#
# ---
#
# ### 6. **Invest in Tax-Free or Tax-Advantaged Securities**
#    - **Municipal Bonds:** These bonds generate interest that is typically exempt from federal taxes and, in some cases, state and local taxes (if issued in your state of residence).
#    - **Qualified Opportunity Zones:** Investments in these zones may allow for tax deferral or exclusion of capital gains.
#
# ---
#
# ### 7. **Reinvest Dividends in Tax-Advantaged Accounts**
#    - If possible, hold dividend-paying assets in tax-favored accounts, as these dividends are typically taxed in taxable accounts at ordinary income or qualified dividend rates.
#
# ---
#
# ### 8. **Consider Charitable Giving**
#    - **Donor-Advised Funds (DAFs):** Contribute appreciated securities to a DAF to avoid capital gains tax while gaining a charitable contribution deduction.
#    - **Qualified Charitable Distributions (QCDs):** If you’re 70½ or older, make direct charitable donations from your IRA to meet required minimum distributions (RMDs) while avoiding taxation.
#
# ---
#
# ### 9. **Monitor Rebalancing for Tax Implications**
#    - Rebalancing your portfolio to maintain your desired asset allocation can trigger taxable events in non-tax-advantaged accounts. To minimize taxes:
#      - Prioritize rebalancing within tax-advantaged accounts.
#      - Use new cash contributions to buy underweighted assets instead of selling overweighted ones.
#
# ---
#
# ### 10. **Plan Withdrawals Strategically in Retirement**
#    - Use a tax-efficient withdrawal strategy, such as:
#      - Drawing from taxable accounts first to allow tax-deferred accounts to continue growing.
#      - Managing withdrawals to avoid moving into a higher tax bracket.
#    - Consider Roth IRA conversions strategically if you expect future tax rates to be higher.
#
# ---
#
# ### Additional Tips
# - Keep detailed investment records for accurate reporting of cost basis and holding periods.
# - Be mindful of annual tax changes that may affect investment strategies.
# - Consider state and local taxes, as they can significantly impact your overall tax liability.
#
# ---
#
# ### Final Notes and Disclaimer
# Each of these strategies has specific rules, limitations, and potential consequences that should be carefully reviewed. Always consult with a tax advisor or licensed financial professional to tailor these strategies to your individual goals, circumstances, and tax planning needs.
#
# **Disclaimer:** This information is educational in nature and not intended as tax or investment advice. Tax laws are subject to change, and individual circumstances vary. Please consult with a tax professional or financial advisor for advice specific to your situation. Past performance is not a guarantee of future results, and all investments carry the risk of loss, including the loss of principal.
#
# ⏱️ Response time: 15.17s

# %%
# Test 4: Risk Assessment
print("\n⚠️ Test 4: Risk Assessment")
print("-" * 40)
response4 = chat_with_wealth_advisor(
    user_question="With current market volatility, should I be concerned about my equity exposure? How do I evaluate if my portfolio risk is appropriate?",
    client_id="HNW-2024-001",  # Same client, different query
    query_category="risk"
)
# Out:
# ⚠️ Test 4: Risk Assessment
# ----------------------------------------
# 👤 Client [HNW-2024-001]: With current market volatility, should I be concerned about my equity exposure? How do I evaluate if my portfolio risk is appropriate?
# 📂 Category: risk
# 🔄 Processing...
#
# 🤖 Advisor: Market volatility can understandably create concern about your equity exposure, but it’s important to evaluate your portfolio in the context of your long-term goals, risk tolerance, and investment time horizon. Here are a few considerations to help you assess whether your portfolio risk is appropriate:
#
# ---
#
# ### 1. **Understand Your Risk Tolerance**
#    - **Risk tolerance** refers to your ability and willingness to endure fluctuations in portfolio value. Ask yourself:
#      - How do I feel when I see significant drops in the market?
#      - Would I stay invested, or would I sell due to fear?
#    - If you’re losing sleep over volatility, your equity exposure might be too high relative to your comfort level.
#
# ---
#
# ### 2. **Review Your Time Horizon**
#    - **How soon will you need the funds you’ve invested?**
#      - If your time horizon is long (e.g., 10 or more years), you may have more ability to ride out short-term volatility in equities.
#      - If you need funds sooner, you may want to revisit the allocation toward less volatile asset classes, such as fixed income investments or cash alternatives.
#
# ---
#
# ### 3. **Revisit Your Asset Allocation**
#    - Asset allocation (the mix of equities, fixed income, real estate, and other asset classes) is a key driver of portfolio performance and risk.
#      - Equities tend to be higher risk but offer potential for higher returns.
#      - Fixed income often provides stability but with lower return potential.
#    - Market volatility may mean it’s time to rebalance your portfolio if one asset class has grown disproportionately large compared to your original plan. For example, if equities have outperformed, your portfolio might need trimming to bring it back to your target allocation.
#
# ---
#
# ### 4. **Diversify Within Asset Classes**
#    - Are your equities spread across different sectors, geographical regions, and market capitalizations? Diversification helps reduce the impact of specific risks (e.g., a downturn in one particular sector or country).
#    - Avoid over-concentration in individual companies or industries.
#
# ---
#
# ### 5. **Evaluate Liquidity Needs**
#    - If you anticipate needing cash in the short term, ensure you aren't overly reliant on equities, which may experience large swings in value.
#
# ---
#
# ### 6. **Stress-Test Your Portfolio**
#    - Consider how your portfolio might perform in a severe market downturn:
#      - Would such a decline impact your ability to meet financial goals?
#      - Stress-testing your portfolio with worst-case scenario models can help determine if you’re comfortable with the potential downside.
#
# ---
#
# ### 7. **Focus on Your Long-Term Plan**
#    - Market volatility is a normal part of investing in equities. Historically, equities have rebounded from dips over the long term, but patience is needed. Reacting emotionally to short-term movements may harm long-term success.
#
# ---
#
# ### 8. **Consult with a Financial Advisor**
#    - A licensed financial advisor can perform a detailed risk assessment, review your investment goals, and help you determine whether your equity exposure aligns with your financial plan.
#
# ---
#
# ### DISCLAIMER:
# Past performance is not indicative of future results. All investments, including equities, carry risks, including the loss of principal. This information is for educational purposes only and not personalized investment advice. Consider consulting with a qualified financial professional to develop a tailored strategy.
#
# ⏱️ Response time: 12.05s

# %% [markdown]
# ## 8. Retrieve and Display Trace Information
#
# You can view traces in multiple places:
#
# 1. **Microsoft Foundry Portal**: Navigate to your project > Tracing
# 2. **Application Insights**: Transaction Search > Filter by operation name
# 3. **Programmatically**: Using the OpenTelemetry SDK
#
# Let's get the current trace context:

# %%
from opentelemetry import trace
from opentelemetry.trace import format_trace_id, format_span_id

# Create a sample span to demonstrate trace ID retrieval
with tracer.start_as_current_span("trace_info_demo") as span:
    context = span.get_span_context()
    trace_id = format_trace_id(context.trace_id)
    span_id = format_span_id(context.span_id)
    
    print("📊 Current Trace Information")
    print("=" * 50)
    print(f"Trace ID: {trace_id}")
    print(f"Span ID: {span_id}")
    print(f"\n🔍 View traces in Microsoft Foundry:")
    print(f"   1. Open your AI Foundry project")
    print(f"   2. Navigate to 'Tracing' section")
    print(f"   3. Search for trace ID: {trace_id}")
    print(f"\n📈 View in Application Insights:")
    print(f"   1. Open Application Insights in Azure Portal")
    print(f"   2. Go to 'Transaction search'")
    print(f"   3. Filter by 'wealth-management-advisor'")
# Out:
# 📊 Current Trace Information
# ==================================================
# Trace ID: 0cc7767ea936e1a075308c863a923d0e
# Span ID: 1aa5a04e09a63dc2
#
# 🔍 View traces in Microsoft Foundry:
#    1. Open your AI Foundry project
#    2. Navigate to 'Tracing' section
#    3. Search for trace ID: 0cc7767ea936e1a075308c863a923d0e
#
# 📈 View in Application Insights:
#    1. Open Application Insights in Azure Portal
#    2. Go to 'Transaction search'
#    3. Filter by 'wealth-management-advisor'

# %% [markdown]
# ## 9. Test Summary
#
# Let's summarize the tests and telemetry captured:

# %%
print("\n" + "=" * 60)
print("📊 TELEMETRY TEST SUMMARY")
print("=" * 60)

tests = [
    ("Portfolio Allocation", response1),
    ("Retirement Planning", response2),
    ("Tax-Efficient Investing", response3),
    ("Risk Assessment", response4)
]

successful = sum(1 for _, r in tests if r is not None)

print(f"\n✅ Successful interactions: {successful}/4")
print(f"\n📝 Telemetry captured for each interaction:")
print("   • Client ID (for compliance tracking)")
print("   • Query category (portfolio, retirement, tax, risk)")
print("   • Response time (performance monitoring)")
print("   • Full prompt and response content (audit trail)")
print("   • Error details (if any occurred)")

print(f"\n🎯 FSI Compliance Benefits:")
print("   • Complete audit trail of client interactions")
print("   • Regulatory reporting capabilities")
print("   • Performance SLA monitoring")
print("   • Anomaly detection for risk management")

# %% [markdown]
# ## 10. Cleanup
#
# Optionally delete the agent when finished. In production, you'd typically keep agents running.

# %%
# Uncomment to delete the agent
# if wealth_advisor:
#     project_client.agents.delete_version(
#         agent_name=wealth_advisor.name, 
#         agent_version=wealth_advisor.version
#     )
#     print("🗑️ Deleted Wealth Management Advisor agent")

print("✅ Notebook completed - Agent retained for further use")

# %% [markdown]
# ## 🎯 Summary
#
# In this notebook, you learned how to:
#
# ✅ **Configure Azure Monitor** for agent telemetry with OpenTelemetry
# ✅ **Enable content recording** to capture prompts and responses for compliance
# ✅ **Create custom trace spans** with business-specific attributes
# ✅ **Build a Wealth Management Advisor** with full observability
# ✅ **Track client interactions** with compliance-ready telemetry
#
# ### 🔧 Key APIs Used
#
# | API | Purpose |
# |-----|--------|
# | `configure_azure_monitor()` | Set up Azure Monitor exporter |
# | `trace.get_tracer()` | Get a tracer for custom spans |
# | `tracer.start_as_current_span()` | Create custom trace spans |
# | `span.set_attribute()` | Add business context to traces |
# | `format_trace_id()` | Get readable trace ID for debugging |
#
# ### 📚 Next Steps
#
# 1. **View traces** in Microsoft Foundry portal or Application Insights
# 2. **Set up alerts** for anomalous response times or error rates
# 3. **Create dashboards** for compliance reporting
# 4. **Explore evaluation** in `2-evaluation.ipynb` to assess agent quality
#
# ### 📖 Related Resources
#
# - [Microsoft Foundry Observability](https://learn.microsoft.com/en-us/azure/ai-foundry/concepts/observability)
# - [Azure Monitor OpenTelemetry](https://learn.microsoft.com/en-us/azure/azure-monitor/app/opentelemetry-overview)
# - [OpenTelemetry Python](https://opentelemetry.io/docs/instrumentation/python/)
